# %% [markdown]
# # Reservoirs tables - GloFAS5
# ***
#
# **Author:** Chus Casado Rodríguez<br>
# **Date:** 19-08-2025<br>
#
# **Introduction:**<br>
#
# * [x] 100-year return period of inflow
# * [x] average inflow
# * [x] environmental flow
# * [x] storage capacity
# * [x] catchment area
# * [x] reservoir area: it would be necessary if we want to model the reservoir surface area
# * [ ] elevation crest: it would be necessary if we want to model the reservoir level
# * [ ] dam height: it would be necessary if we want to model the reservoir level

# %%
import numpy as np
import pandas as pd
import xarray as xr
import rioxarray as rxr
import geopandas as gpd
import cartopy.feature as cfeature
import cartopy.crs as ccrs
from pathlib import Path
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from datetime import datetime

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from reservoirs_lshm.utils.plots import compare_attributes
from reservoirs_lshm.utils.ncextract import extract_timeseries
# from reservoirs_lshm.utils.utils import return_period

# %% [markdown]
# ## Configuration

# %%
# paths
PATH_GLOFAS4 = Path('Z:/nahaUsers/casadje/GloFASv4')
PATH_GLOFAS5 = Path('Z:/nahaUsers/casadje/GloFASv5')
PATH_GDW = Path('Z:/nahaUsers/casadje/datasets/reservoirs/GDW/GDW_v1_0_shp')
PATH_GRAND = Path('Z:/nahaUsers/casadje/datasets/reservoirs/GRanD/v1_3')
PATH_GLWD = Path('Z:/nahaUsers/casadje/datasets/lakes/GLWD')
PATH_ICOLD= Path('Z:/nahaUsers/casadje/datasets/reservoirs/ICOLD/2023')
PATH_OUT = PATH_GLOFAS5 / 'reservoirs' / 'tables'
PATH_PLOTS = PATH_OUT / 'plots'
PATH_PLOTS.mkdir(parents=True, exist_ok=True)
print(f'Results will be saved in {PATH_OUT}')

# minimum storage capacity included in GloFAS
MIN_VOLUME = 100 # hm³
MIN_CATCHMENT = 500 # km²
MIN_AREA = None # 50 # km2
MIN_DOR = 0.08 #
# Out:
# Results will be saved in Z:\nahaUsers\casadje\GloFASv5\reservoirs\tables

# %% [markdown]
# ## Data
#
# ### GloFAS5

# %%
# import relocated reservoirs
glofas5 = gpd.read_file(PATH_GLOFAS5 / 'reservoirs' / 'tables' / 'ReservoirGlofas+GDW.shp')

# select columns
id_cols = [col for col in glofas5.columns if 'id' in col.lower()]
glofas5[id_cols] = glofas5[id_cols].replace(0, np.nan)
for col in id_cols:
    try:
        glofas5[col] = glofas5[col].astype('Int64')
    except:
        print(f'Could not convert to In64 column {col}')

# assing index
glofas5.set_index('GDW_ID', drop=True, inplace=True)
glofas5.sort_index(axis=0, inplace=True)
idx_name = glofas5.index.name

print(glofas5.shape)
# Out:
# (1710, 17)

# %%
# points of interest used to extract values from maps (coordinates from GloFAS5)
poi_5 = pd.concat((glofas5.geometry.x, glofas5.geometry.y), axis=1)
poi_5.columns = ['x', 'y']
poi_5 = poi_5.to_xarray()

# %% [markdown]
# ### GloFAS4
#
# #### Reservoirs

# %%
# load shapefile
glofas4 = gpd.read_file(PATH_GLOFAS4 / 'tables' / 'GloFAS_reservoirs.shp')

# assign ID
map_res_gdw = {ResID: ID for ID, ResID in zip(glofas5.index, glofas5.RES_ID) if not pd.isna(ResID)}
glofas4[idx_name] = glofas4.ResID.map(map_res_gdw).astype('Int64')

# keep reservoirs in GloFAS4 also in GloFAS5
glofas4.dropna(subset=[idx_name], inplace=True)
glofas4.sort_index(axis=0, inplace=True)
glofas4.set_index(idx_name, drop=False, inplace=True)

print(glofas4.shape)
# Out:
# (661, 34)

# %%
# points of interest used to extract values from maps (coordinates from GloFAS5 or GloFAS4)
poi_4 = pd.DataFrame(index=glofas5.index, columns=['x', 'y'], dtype=float)
for ID in tqdm(glofas5.index):
    if pd.notna(glofas5.loc[ID, 'RES_ID']):
        lat, lon = glofas4.loc[ID].geometry.y, glofas4.loc[ID].geometry.x
    else:
        lat, lon = glofas5.loc[ID].geometry.y, glofas5.loc[ID].geometry.x
    poi_4.loc[ID, :] = lon, lat
poi_4.index.name = idx_name
poi_4 = poi_4.to_xarray()
# Out:
#   0%|          | 0/1710 [00:00<?, ?it/s]

# %% [markdown]
# #### Static maps

# %%
# load the upstream area map
uparea = rxr.open_rasterio(PATH_GLOFAS4 / 'static_maps' / 'upArea_repaired.nc').squeeze(dim='band')
# uparea = uparea.where(uparea != -999999, np.nan)
uparea = uparea.where(uparea >= 0, np.nan)
uparea /= 1e6 # km2

# local drainage direction map
ldd = rxr.open_rasterio(PATH_GLOFAS4 / 'static_maps' / 'ldd_repaired.nc').squeeze(dim='band')

# %% [markdown]
# #### Long-term run
#
# First, I create the CSV required by the tool `ncextract` to extract the discharge time series from the GloFAS4 long-term-run. I will use the function `upstream_pixel` to find the coordinates of the pixel upstream for those reservoirs already in GloFAS4, so the time series represents inflow, instead of outflow.

# %%
# # dataframe of coordinates of the upstream pixel (only moved in present in GloFAS4)
# coords = pd.DataFrame(index=glofas5.index, columns=['longitude', 'latitude'], dtype=float)
# for ID in tqdm(glofas5.index):
#     if pd.notna(glofas5.loc[ID, 'RES_ID']):
#         lat, lon = glofas4.loc[ID].geometry.y, glofas4.loc[ID].geometry.x
#     else:
#         lat, lon = glofas5.loc[ID].geometry.y, glofas5.loc[ID].geometry.x
#     coords.loc[ID, :] = lon, lat

# # export input CSV for `ncextract`
# path = PATH_GLOFAS5 / 'reservoirs' / 'ancillary' / 'ncextract'
# coords.to_csv(path / 'reservoirs_glofas5_{0}.csv'.format(datetime.now().strftime('%Y%m%d')), float_format='%.3f')
# # step = 100
# # for i, (ID_0, ID_1) in enumerate(zip(csv.index[::step], csv.index[step-1::step]), start=1):
# #     print(ID_0, ID_1)
# #     coords.loc[ID_0:ID_1].to_csv(PATH_GLOFAS5 / 'reservoirs' / 'ancillary' / 'ncextract' / f'reservoirs_{i}.csv', float_format='%.3f')

# coords[glofas5.RES_ID.notnull()].to_csv(path / 'reservoirs_glofas4_{0}.csv'.format(datetime.now().strftime('%Y%m%d')), float_format='%.3f')

# %% [markdown]
# Maps of average discharges and 100-year return period of discharge from the GloFAS4 long-term-run.

# %%
# map of average discharge
# dis_avg_ltr = rxr.open_rasterio(PATH_GLOFAS4 / 'long_run' / 'dis' / 'thresholds' / 'disavg_1979_2023.nc').squeeze(dim='time')
dis_avg_ltr = xr.open_dataset(PATH_GLOFAS4 / 'long_run' / 'dis' / 'thresholds' / 'disavg_1979_2023.nc').squeeze(dim='time')
dis_avg_ltr = dis_avg_ltr.rename({'lat': 'y', 'lon': 'x'})
dis_avg_ltr.close()

# map of 100-year discharge
dis_100_ltr = rxr.open_rasterio(PATH_GLOFAS4 / 'long_run' / 'dis' / 'thresholds' / 'flood_threshold_glofas_v4_rl_100.0.nc').squeeze(dim='band')

# %% [markdown]
# Time series of discharge flowing into the reservoirs in the GloFAS4 long-term-run. These time series were extracted using `ncextract` with the `upstream` points created above.

# %%
# inflow time series from GloFAS4 long-term run in the reservoirs
inflow_ltr = xr.open_mfdataset((PATH_GLOFAS5 / 'reservoirs' / 'ancillary' / 'ncextract' / 'dis24' / 'inflow' / 'GDW_ID').glob('*.nc'), chunks='auto')['dis24']
inflow_ltr = inflow_ltr.drop_vars('surface', errors='ignore')
inflow_ltr = inflow_ltr.rename({'valid_time': 'time', 'id': idx_name, 'longitude': 'lon', 'latitude': 'lat'})
inflow_ltr = inflow_ltr.sel({idx_name: glofas5.index.intersection(inflow_ltr[idx_name].data).tolist()})

inflow_ltr
# Out:
# <xarray.DataArray 'dis24' (GDW_ID: 1710, time: 16437)> Size: 112MB
# dask.array<getitem, shape=(1710, 16437), dtype=float32, chunksize=(1, 16437), chunktype=numpy.ndarray>
# Coordinates:
#   * GDW_ID   (GDW_ID) int64 14kB 1 2 3 4 5 6 ... 28079 28090 28125 38808 99999
#   * time     (time) datetime64[ns] 131kB 1980-01-02 1980-01-03 ... 2025-01-01
#     lat      (GDW_ID) float64 14kB 53.68 44.43 52.23 0.425 ... 46.93 29.48 48.03
#     lon      (GDW_ID) float64 14kB -97.82 -75.82 104.3 ... -120.0 103.6 -119.6
# Attributes: (12/32)
#     GRIB_paramId:                             240024
#     GRIB_dataType:                            sfo
#     GRIB_numberOfPoints:                      21600000
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            avg
#     ...                                       ...
#     GRIB_name:                                Mean discharge in the last 24 h...
#     GRIB_shortName:                           dis24
#     GRIB_units:                               m**3 s**-1
#     long_name:                                Mean discharge in the last 24 h...
#     units:                                    m**3 s**-1
#     standard_name:                            unknown

# %%
# # outflow time series from GloFAS4 long-term run in the reservoirs
# outflow_ltr = xr.open_mfdataset((PATH_GLOFAS5 / 'reservoirs' / 'ancillary' / 'ncextract' / 'dis24' / 'outflow').glob('*.nc'), chunks='auto')['dis24']
# outflow_ltr = outflow_ltr.drop_vars('surface', errors='ignore')
# outflow_ltr = outflow_ltr.rename({'valid_time': 'time', 'id': idx_name, 'longitude': 'lon', 'latitude': 'lat'})
# outflow_ltr = outflow_ltr.sel({idx_name: glofas5.index.intersection(inflow_ltr[idx_name].data).tolist()})

# %% [markdown]
# ### GDW

# %%
# load Global Dam Watch
gdw = gpd.read_file(PATH_GDW / 'GDW_barriers_v1_0.shp').set_index('GDW_ID')
gdw['GRAND_ID'] = gdw['GRAND_ID'].replace(0, np.nan).astype('Int64')
gdw.replace(-99, np.nan, inplace=True)
cols_years = ['YEAR_DAM', 'PRE_YEAR', 'ALT_YEAR', 'REM_YEAR']
gdw[cols_years] = gdw[cols_years].astype('Int64')

# filter those in GloFAS5
gdw = gdw.loc[gdw.index.intersection(glofas5.index)]
print(gdw.shape)

# # map IDs in GRanD and GDW
# map_grand_gdw = {}
# for grand_id in glofas5.GRAND_ID:
#     mask = gdw.GRAND_ID == grand_id
#     if mask.sum() > 0:
#         map_grand_gdw[grand_id] = gdw[mask].index.item()

# # add the GDW_ID to glofas5
# glofas5['GDW_ID'] = glofas5.GRAND_ID.map(map_grand_gdw)
# glofas5['GDW_ID'] = glofas5['GDW_ID'].astype('Int64')

# # map IDs in GloFAS4 and GDW
# map_res_gdw = {
#     40: 99999,
#     47: 28076,
#     60: 28009,
#     72: 28015,
#     86: 28125,
#     112: 27427,
#     130: 27996,
#     150: 28090,
#     263: 7777,
#     367: 39019,
#     424: 38808,
#     439: 28079,
#     488: 27992,
# }
# mask = glofas5.GDW_ID.isnull()
# glofas5.loc[mask, 'GDW_ID'] = glofas5.loc[mask, 'RES_ID'].map(map_res_gdw)

# # export
# glofas5.to_file(PATH_GLOFAS5 / 'reservoirs' / 'tables' / 'ReservoirGlofas+GDW.shp')
# Out:
# (1709, 71)

# %% [markdown]
# ### GRanD

# %%
# load raw dataset
grand = gpd.read_file(PATH_GRAND / 'GRanD_dams_v1_3.shp')
grand.replace({-99: np.nan}, inplace=True)
cols_years = ['YEAR', 'ALT_YEAR', 'REM_YEAR']
grand[cols_years] = grand[cols_years].astype('Int64')

# connection between GRanD and glofas5
map_grand_idx = {grand_id: idx for idx, grand_id in glofas5.GRAND_ID.items() if not pd.isna(grand_id)}
grand[idx_name] = grand.GRAND_ID.map(map_grand_idx).astype('Int64')
grand = grand[grand[idx_name].notnull()]
grand.set_index(idx_name, drop=True, inplace=True)

print(grand.shape)
# Out:
# (1697, 59)

# %% [markdown]
# ### GLWD

# %%
# level 1
glwd1 = gpd.read_file(PATH_GLWD / 'level1' / 'glwd_1.shp')#.set_index('GLWD_ID', drop=True)
glwd1 = glwd1[glwd1.GLWD_ID.isin(glofas5.GLWD_ID)]

# level 2
glwd2 = gpd.read_file(PATH_GLWD / 'level2' / 'glwd_2.shp')#.set_index('GLWD_ID', drop=True)
glwd2 = glwd2[glwd2.GLWD_ID.isin(glofas5.GLWD_ID)]

# concatenate
glwd = pd.concat((glwd1, glwd2), axis=0)

if not glwd.shape[0] == glofas5.GLWD_ID.nunique():
    print('The number of lakes in "glwd" does not match the number of lakes in "glofas5" with assigned GLWD_ID')

# connection between GLWD and glofas5
map_glwd_idx = {glwd_id: idx for idx, glwd_id in glofas5.GLWD_ID.items() if not pd.isna(glwd_id)}
glwd[idx_name] = glwd.GLWD_ID.map(map_glwd_idx).astype('Int64')
glwd = glwd[glwd[idx_name].notnull()]
glwd.set_index(idx_name, drop=True, inplace=True)

print(glwd.shape)
# Out:
# (670, 29)

# %% [markdown]
# ### ICOLD

# %%
# load ICOLD dataset
icold = gpd.read_file(PATH_ICOLD / 'ICOLD_global.shp')

# connection between ICOLD and ID
map_icold_idx = {icold_id: idx for idx, icold_id in glofas5.INT_CODE.items() if pd.notna(icold_id)}
icold[idx_name] = icold.Int_Code.map(map_icold_idx).astype('Int64')
icold = icold[icold[idx_name].notnull()]
icold.set_index(idx_name, drop=True, inplace=True)

print(icold.shape)
# Out:
# (702, 44)

# %% [markdown]
# ## Attributes

# %% [markdown]
# ### Capacity

# %%
capacity = pd.DataFrame(index=glofas5.index, columns=['GLOFAS4', 'GDW', 'GRAND', 'GLWD', 'ICOLD', 'GLOFAS5', 'SOURCE'], dtype=float)
capacity.SOURCE = capacity.SOURCE.astype(str)

# GLOFAS4
capacity.loc[glofas4.index, 'GLOFAS4'] = glofas4.stor

# GDW
capacity.loc[gdw.index, 'GDW'] = gdw.CAP_MCM

# GRanD
capacity.loc[grand.index, 'GRAND'] = grand.CAP_MCM

# GLWD
capacity.loc[glwd.index, 'GLWD'] = glwd.VOLUME_CKM * 1e3

# ICOLD
capacity.loc[icold.index, 'ICOLD'] = icold.Res_Vol.values * 1e-3

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    capacity[['GLOFAS4', 'ICOLD', 'GLWD', 'GRAND', 'GDW']],
    thr=MIN_VOLUME,
    vmin=1e-1,
    vmax=1e6,
    title='storage (hm3)',
    scale='log',
)
plt.savefig(PATH_OUT / 'plots' / 'storage_pairplot.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# The values in GLWD and GloFAS4 are identical. However, GRanD values are often different; in some cases, the difference is one order of magnitude. I've checked some of the largest differences and, in all but one case, GRanD was the correct source.

# %%
# error = 2
# mask_error = (capacity.GRAND < capacity.GLOFAS4 / error) | (capacity.GRAND > error * capacity.GLOFAS4)
# print(mask_error.sum())
# pd.concat((glofas5.loc[mask_error], capacity[mask_error]), axis=1)

# %% [markdown]
# #### Select values
#
# I have manually checked the large discrepancies between GLOFAS4 and GRanD. In case of discrepancy, I compare with ICOLD and HydroLakes. It seems like GRanD is a more reliable source, so I will use the value from GRanD whenever possible, if not the value from GLOFAS4.

# %%
# select value from GRAND, GLOFAS4, HYLAK or ICOLD in that order
for source in ['GRAND', 'GDW', 'ICOLD', 'GLWD']:
    missing = capacity.GLOFAS5.isnull()
    mask = capacity[source].notnull()
    capacity.loc[missing & mask, 'GLOFAS5'] = capacity.loc[missing & mask, source]
    capacity.loc[missing & mask, 'SOURCE'] = source

print('{0} reservoirs are missing the capacity value'.format(capacity.GLOFAS5.isnull().sum()))
print('{0} reservoirs have nevative capacity value'.format((capacity.GLOFAS5 < 0).sum()))
capacity.SOURCE.value_counts()
# Out:
# 0 reservoirs are missing the capacity value
# 0 reservoirs have nevative capacity value
# SOURCE
# GRAND    1697
# GDW        12
# ICOLD       1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=np.log10(capacity.GLOFAS5),
    cmap='viridis',
    s=5,
    vmin=np.log10(MIN_VOLUME),
    # vmax=2.5
)
cbar = plt.colorbar(sct, shrink=.5, label='storage (hm3)')
ticks = [2, 3, 4, 5]
cbar.set_ticks(ticks)
cbar.set_ticklabels([10**x for x in ticks])
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'storage_map.jpg', dpi=300, bbox_inches='tight')

# add values to GLOFAS5
glofas5.loc[capacity.index, ['CAP_MCM', 'CAP_SRC']] = capacity[['GLOFAS5', 'SOURCE']].values

print('{0} reservoirs do not comply with the minimum storage of {1} hm3'.format((glofas5.CAP_MCM < MIN_VOLUME).sum(),
                                                                                MIN_VOLUME))
# Out:
# 8 reservoirs do not comply with the minimum storage of 100 hm3

# %% [markdown]
# ### Catchment area

# %%
catchment = pd.DataFrame(index=glofas5.index, columns=['UPAREA', 'GDW', 'GRAND', 'GLWD', 'ICOLD', 'GLOFAS5', 'SOURCE'], dtype='float')
catchment.SOURCE = catchment.SOURCE.astype(str)

# upstream area map
catchment.loc[poi_5[idx_name], 'UPAREA'] = np.round(uparea.sel({'x': poi_5['x'], 'y': poi_5['y']}, method='nearest').to_pandas(), 0)

# GDW
catchment.loc[gdw.index, 'GDW'] = gdw.CATCH_SKM

# GRanD
catchment.loc[grand.index, 'GRAND'] = grand.CATCH_SKM

# GLWD
catchment.loc[glwd.index, 'GLWD'] = glwd.CATCH_TSKM * 1e3

# ICOLD
catchment.loc[icold.index, 'ICOLD'] = icold.Catch_Area.values

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    catchment[['UPAREA', 'ICOLD', 'GLWD', 'GRAND', 'GDW']],
    thr=MIN_CATCHMENT,
    vmin=1,
    vmax=1e7,
    title='catchment (km²)'
)
plt.savefig(PATH_OUT / 'plots' / 'catchment_pairplot.jpg', dpi=300, bbox_inches='tight')

# %%
# error = 1.5
# mask_error = (catchment.GRAND < catchment.UPAREA / error) | (catchment.GRAND > error * catchment.UPAREA)
# print(mask_error.sum())
# pd.concat((glofas5[mask_error], catchment[mask_error]), axis=1)

# %%
# foo = pd.concat(
#     (glofas5[mask_error][['RES_ID', 'LAK_ID', 'GRAND_ID', 'GLWD_ID', 'INT_CODE', 'geometry']],
#      np.round(catchment[mask_error][['UPAREA', 'GRAND', 'GLWD', 'ICOLD']], 0)),
#     axis=1
# ).sort_values('GRAND_ID')

# foo

# %%
# foo.to_file(PATH_OUT / 'errors_area.shp')

# %% [markdown]
# #### Select values
#
# Following the procedure applied for the storage capacity, I will use the GRanD value when available.

# %%
# select value from GRAND, GLOFAS4, HYLAK or ICOLD in that order
for source in ['GRAND', 'GDW', 'GLWD', 'ICOLD', 'UPAREA']:
    missing = catchment.GLOFAS5.isnull()
    mask = catchment[source].notnull()
    catchment.loc[missing & mask, 'GLOFAS5'] = catchment.loc[missing & mask, source]
    catchment.loc[missing & mask, 'SOURCE'] = source

print('{0} reservoirs are missing the catchment value'.format(catchment.GLOFAS5.isnull().sum()))
print('{0} reservoirs have nevative catchment value'.format((catchment.GLOFAS5 < 0).sum()))
catchment.SOURCE.value_counts()
# Out:
# 0 reservoirs are missing the catchment value
# 0 reservoirs have nevative catchment value
# SOURCE
# GRAND    1697
# GDW        12
# GLWD        1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=np.log10(catchment.GLOFAS5),
    cmap='viridis_r',
    s=5,
    vmin=np.log10(MIN_CATCHMENT),
    # vmax=2.5
)
cbar = plt.colorbar(sct, shrink=.5, label='catchment (km2)')
ticks = [3, 4, 5, 6]
cbar.set_ticks(ticks)
cbar.set_ticklabels([10**x for x in ticks])
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'catchment_map.jpg', dpi=300, bbox_inches='tight')

# add values to GLOFAS5
glofas5.loc[catchment.index, ['CATCH_SKM', 'CATCH_SRC']] = catchment[['GLOFAS5', 'SOURCE']].values
print('{0} reservoirs do not comply with the minimum catchment area of {1} km²'.format((glofas5.CATCH_SKM < MIN_CATCHMENT).sum(),
                                                                                       MIN_CATCHMENT))
# Out:
# 24 reservoirs do not comply with the minimum catchment area of 500 km²

# %% [markdown]
# ### Surface area

# %%
area = pd.DataFrame(index=glofas5.index, columns=['GDW', 'GRAND', 'GLWD', 'ICOLD', 'GLOFAS5', 'SOURCE'], dtype=float)
area.SOURCE = area.SOURCE.astype(str)

# GDW
area.loc[gdw.index, 'GDW'] = gdw.AREA_SKM

# GRanD
area.loc[grand.index, 'GRAND'] = grand.AREA_SKM

# GLWD
area.loc[glwd.index, 'GLWD'] = glwd.AREA_SKM

# ICOLD
area.loc[icold.index, 'ICOLD'] = icold.Res_Area.values * 1e-3

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    area[['GDW', 'ICOLD', 'GLWD', 'GRAND']],
    thr=MIN_AREA,
    vmin=1,
    vmax=1e5,
    title='area (km²)'
)
plt.savefig(PATH_OUT / 'plots' / 'area_pairplot.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# There is an error in the units in some ICOLD values.

# %% [markdown]
# #### Select values

# %%
# select value from GRAND, GLOFAS4, HYLAK or ICOLD in that order
for source in ['GRAND', 'GDW', 'GLWD', 'ICOLD']:
    missing = area.GLOFAS5.isnull()
    mask = area[source].notnull()
    area.loc[missing & mask, 'GLOFAS5'] = area.loc[missing & mask, source]
    area.loc[missing & mask, 'SOURCE'] = source

print('{0} reservoirs are missing the area value'.format(area.GLOFAS5.isnull().sum()))
print('{0} reservoirs have nevative area value'.format((area.GLOFAS5 < 0).sum()))
area.SOURCE.value_counts()
# Out:
# 1 reservoirs are missing the area value
# 0 reservoirs have nevative area value
# SOURCE
# GRAND    1695
# GDW        13
# nan         1
# GLWD        1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=np.log10(area.GLOFAS5),
    cmap='viridis_r',
    s=5,
    # vmin=0,
    # vmax=2.5
)
cbar = plt.colorbar(sct, shrink=.5, label='area (km2)')
ticks = [1, 2, 3, 4]
cbar.set_ticks(ticks)
cbar.set_ticklabels([10**x for x in ticks])
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'area_map.jpg', dpi=300, bbox_inches='tight')

# add values to GLOFAS5
glofas5.loc[area.index, ['AREA_SKM', 'AREA_SRC']] = area[['GLOFAS5', 'SOURCE']].values

# %% [markdown]
# ### Mean inflow

# %% [markdown]
# I do not include the values reported in HydroLakes (`Dis_avg`) because they are identical to those in GRanD.

# %%
dis_avg = pd.DataFrame(index=glofas5.index, columns=['GLOFAS4', 'LTR', 'GDW', 'GRAND', 'GLWD', 'GLOFAS5', 'SOURCE'], dtype=float)
dis_avg.SOURCE = dis_avg.SOURCE.astype(str)

# GLOFAS4 reservoir parameter
dis_avg.loc[glofas4.index, 'GLOFAS4'] = glofas4.normq

# GLOFAS4 long-run average
# dis_avg['LTR'] = dis_avg_ltr.sel({'x': poi_5['x'], 'y': poi_5['y']}, method='nearest').to_pandas()
dis_avg['LTR'] = extract_timeseries(
    dis_avg_ltr, 
    poi_4.sortby(idx_name).rename({idx_name: 'id'}), 
    inflow=True, 
    ldd=ldd
).to_pandas()['dis']
# dis_avg['LTR'] = inflow_ltr.mean('time')

# GDW
dis_avg.loc[mask.index, 'GDW'] = gdw.DIS_AVG_LS * 1e-3

# GRanD
dis_avg.loc[mask.index, 'GRAND'] = grand.DIS_AVG_LS * 1e-3

# GLWD
dis_avg.loc[glwd.index, 'GLWD'] = glwd.INFLOW_CMS
# Out:
# 2025-08-19 09:36:56 | Time series for point 1 extracted
# 2025-08-19 09:36:57 | Time series for point 2 extracted
# 2025-08-19 09:36:57 | Time series for point 3 extracted
# 2025-08-19 09:36:57 | Time series for point 4 extracted
# 2025-08-19 09:36:57 | Time series for point 5 extracted
# 2025-08-19 09:36:57 | Time series for point 6 extracted
# 2025-08-19 09:36:57 | Time series for point 7 extracted
# 2025-08-19 09:36:57 | Time series for point 8 extracted
# 2025-08-19 09:36:57 | Time series for point 9 extracted
# 2025-08-19 09:36:57 | Time series for point 10 extracted
# 2025-08-19 09:36:57 | Time series for point 11 extracted
# 2025-08-19 09:36:57 | Time series for point 12 extracted
# 2025-08-19 09:36:57 | Time series for point 13 extracted
# 2025-08-19 09:36:57 | Time series for point 14 extracted
# 2025-08-19 09:36:57 | Time series for point 15 extracted
# 2025-08-19 09:36:57 | Time series for point 16 extracted
# 2025-08-19 09:36:57 | Time series for point 17 extracted
# 2025-08-19 09:36:57 | Time series for point 18 extracted
# 2025-08-19 09:36:57 | Time series for point 19 extracted
# 2025-08-19 09:36:57 | Time series for point 20 extracted
# 2025-08-19 09:36:57 | Time series for point 21 extracted
# 2025-08-19 09:36:57 | Time series for point 22 extracted
# 2025-08-19 09:36:57 | Time series for point 23 extracted
# 2025-08-19 09:36:57 | Time series for point 24 extracted
# 2025-08-19 09:36:57 | Time series for point 25 extracted
# 2025-08-19 09:36:57 | Time series for point 26 extracted
# 2025-08-19 09:36:57 | Time series for point 27 extracted
# 2025-08-19 09:36:57 | Time series for point 28 extracted
# 2025-08-19 09:36:57 | Time series for point 29 extracted
# 2025-08-19 09:36:57 | Time series for point 30 extracted
# 2025-08-19 09:36:58 | Time series for point 31 extracted
# 2025-08-19 09:36:58 | Time series for point 32 extracted
# 2025-08-19 09:36:58 | Time series for point 33 extracted
# 2025-08-19 09:36:58 | Time series for point 34 extracted
# 2025-08-19 09:36:58 | Time series for point 35 extracted
# 2025-08-19 09:36:58 | Time series for point 36 extracted
# 2025-08-19 09:36:58 | Time series for point 37 extracted
# 2025-08-19 09:36:58 | Time series for point 38 extracted
# 2025-08-19 09:36:58 | Time series for point 39 extracted
# 2025-08-19 09:36:58 | Time series for point 40 extracted
# 2025-08-19 09:36:58 | Time series for point 41 extracted
# 2025-08-19 09:36:58 | Time series for point 42 extracted
# 2025-08-19 09:36:58 | Time series for point 43 extracted
# 2025-08-19 09:36:58 | Time series for point 44 extracted
# 2025-08-19 09:36:58 | Time series for point 45 extracted
# 2025-08-19 09:36:58 | Time series for point 46 extracted
# 2025-08-19 09:36:58 | Time series for point 47 extracted
# 2025-08-19 09:36:58 | Time series for point 48 extracted
# 2025-08-19 09:36:58 | Time series for point 49 extracted
# 2025-08-19 09:36:58 | Time series for point 50 extracted
# 2025-08-19 09:36:58 | Time series for point 51 extracted
# 2025-08-19 09:36:58 | Time series for point 52 extracted
# 2025-08-19 09:36:58 | Time series for point 53 extracted
# 2025-08-19 09:36:58 | Time series for point 54 extracted
# 2025-08-19 09:36:58 | Time series for point 55 extracted
# 2025-08-19 09:36:58 | Time series for point 56 extracted
# 2025-08-19 09:36:58 | Time series for point 57 extracted
# 2025-08-19 09:36:58 | Time series for point 58 extracted
# 2025-08-19 09:36:58 | Time series for point 59 extracted
# 2025-08-19 09:36:58 | Time series for point 60 extracted
# 2025-08-19 09:36:58 | Time series for point 61 extracted
# 2025-08-19 09:36:58 | Time series for point 62 extracted
# 2025-08-19 09:36:58 | Time series for point 63 extracted
# 2025-08-19 09:36:58 | Time series for point 64 extracted
# 2025-08-19 09:36:58 | Time series for point 65 extracted
# 2025-08-19 09:36:58 | Time series for point 66 extracted
# 2025-08-19 09:36:58 | Time series for point 67 extracted
# 2025-08-19 09:36:58 | Time series for point 68 extracted
# 2025-08-19 09:36:59 | Time series for point 69 extracted
# 2025-08-19 09:36:59 | Time series for point 70 extracted
# 2025-08-19 09:36:59 | Time series for point 71 extracted
# 2025-08-19 09:36:59 | Time series for point 72 extracted
# 2025-08-19 09:36:59 | Time series for point 73 extracted
# 2025-08-19 09:36:59 | Time series for point 74 extracted
# 2025-08-19 09:36:59 | Time series for point 75 extracted
# 2025-08-19 09:36:59 | Time series for point 76 extracted
# 2025-08-19 09:36:59 | Time series for point 77 extracted
# 2025-08-19 09:36:59 | Time series for point 78 extracted
# 2025-08-19 09:36:59 | Time series for point 79 extracted
# 2025-08-19 09:36:59 | Time series for point 80 extracted
# 2025-08-19 09:36:59 | Time series for point 81 extracted
# 2025-08-19 09:36:59 | Time series for point 82 extracted
# 2025-08-19 09:36:59 | Time series for point 84 extracted
# 2025-08-19 09:36:59 | Time series for point 85 extracted
# 2025-08-19 09:36:59 | Time series for point 86 extracted
# 2025-08-19 09:36:59 | Time series for point 87 extracted
# 2025-08-19 09:36:59 | Time series for point 88 extracted
# 2025-08-19 09:36:59 | Time series for point 89 extracted
# 2025-08-19 09:36:59 | Time series for point 90 extracted
# 2025-08-19 09:36:59 | Time series for point 91 extracted
# 2025-08-19 09:36:59 | Time series for point 92 extracted
# 2025-08-19 09:36:59 | Time series for point 93 extracted
# 2025-08-19 09:36:59 | Time series for point 94 extracted
# 2025-08-19 09:36:59 | Time series for point 95 extracted
# 2025-08-19 09:36:59 | Time series for point 96 extracted
# 2025-08-19 09:36:59 | Time series for point 97 extracted
# 2025-08-19 09:36:59 | Time series for point 98 extracted
# 2025-08-19 09:36:59 | Time series for point 99 extracted
# 2025-08-19 09:36:59 | Time series for point 100 extracted
# 2025-08-19 09:36:59 | Time series for point 101 extracted
# 2025-08-19 09:36:59 | Time series for point 102 extracted
# 2025-08-19 09:36:59 | Time series for point 103 extracted
# 2025-08-19 09:36:59 | Time series for point 104 extracted
# 2025-08-19 09:36:59 | Time series for point 105 extracted
# 2025-08-19 09:36:59 | Time series for point 106 extracted
# 2025-08-19 09:36:59 | Time series for point 107 extracted
# 2025-08-19 09:36:59 | Time series for point 108 extracted
# 2025-08-19 09:36:59 | Time series for point 109 extracted
# 2025-08-19 09:36:59 | Time series for point 110 extracted
# 2025-08-19 09:36:59 | Time series for point 111 extracted
# 2025-08-19 09:36:59 | Time series for point 112 extracted
# 2025-08-19 09:36:59 | Time series for point 113 extracted
# 2025-08-19 09:36:59 | Time series for point 114 extracted
# 2025-08-19 09:36:59 | Time series for point 115 extracted
# 2025-08-19 09:36:59 | Time series for point 116 extracted
# 2025-08-19 09:36:59 | Time series for point 117 extracted
# 2025-08-19 09:36:59 | Time series for point 118 extracted
# 2025-08-19 09:36:59 | Time series for point 119 extracted
# 2025-08-19 09:36:59 | Time series for point 120 extracted
# 2025-08-19 09:36:59 | Time series for point 121 extracted
# 2025-08-19 09:36:59 | Time series for point 123 extracted
# 2025-08-19 09:36:59 | Time series for point 124 extracted
# 2025-08-19 09:36:59 | Time series for point 125 extracted
# 2025-08-19 09:36:59 | Time series for point 126 extracted
# 2025-08-19 09:36:59 | Time series for point 127 extracted
# 2025-08-19 09:36:59 | Time series for point 128 extracted
# 2025-08-19 09:36:59 | Time series for point 129 extracted
# 2025-08-19 09:36:59 | Time series for point 131 extracted
# 2025-08-19 09:37:00 | Time series for point 132 extracted
# 2025-08-19 09:37:00 | Time series for point 133 extracted
# 2025-08-19 09:37:00 | Time series for point 134 extracted
# 2025-08-19 09:37:00 | Time series for point 135 extracted
# 2025-08-19 09:37:00 | Time series for point 136 extracted
# 2025-08-19 09:37:00 | Time series for point 137 extracted
# 2025-08-19 09:37:00 | Time series for point 138 extracted
# 2025-08-19 09:37:00 | Time series for point 139 extracted
# 2025-08-19 09:37:00 | Time series for point 140 extracted
# 2025-08-19 09:37:00 | Time series for point 141 extracted
# 2025-08-19 09:37:00 | Time series for point 142 extracted
# 2025-08-19 09:37:00 | Time series for point 143 extracted
# 2025-08-19 09:37:00 | Time series for point 144 extracted
# 2025-08-19 09:37:00 | Time series for point 145 extracted
# 2025-08-19 09:37:00 | Time series for point 146 extracted
# 2025-08-19 09:37:00 | Time series for point 147 extracted
# 2025-08-19 09:37:00 | Time series for point 148 extracted
# 2025-08-19 09:37:00 | Time series for point 149 extracted
# 2025-08-19 09:37:00 | Time series for point 150 extracted
# 2025-08-19 09:37:00 | Time series for point 151 extracted
# 2025-08-19 09:37:00 | Time series for point 152 extracted
# 2025-08-19 09:37:00 | Time series for point 153 extracted
# 2025-08-19 09:37:00 | Time series for point 154 extracted
# 2025-08-19 09:37:00 | Time series for point 155 extracted
# 2025-08-19 09:37:00 | Time series for point 156 extracted
# 2025-08-19 09:37:00 | Time series for point 157 extracted
# 2025-08-19 09:37:00 | Time series for point 158 extracted
# 2025-08-19 09:37:00 | Time series for point 159 extracted
# 2025-08-19 09:37:00 | Time series for point 160 extracted
# 2025-08-19 09:37:00 | Time series for point 161 extracted
# 2025-08-19 09:37:00 | Time series for point 162 extracted
# 2025-08-19 09:37:00 | Time series for point 163 extracted
# 2025-08-19 09:37:00 | Time series for point 164 extracted
# 2025-08-19 09:37:00 | Time series for point 165 extracted
# 2025-08-19 09:37:00 | Time series for point 166 extracted
# 2025-08-19 09:37:00 | Time series for point 167 extracted
# 2025-08-19 09:37:00 | Time series for point 168 extracted
# 2025-08-19 09:37:00 | Time series for point 169 extracted
# 2025-08-19 09:37:00 | Time series for point 170 extracted
# 2025-08-19 09:37:00 | Time series for point 171 extracted
# 2025-08-19 09:37:00 | Time series for point 172 extracted
# 2025-08-19 09:37:00 | Time series for point 173 extracted
# 2025-08-19 09:37:00 | Time series for point 174 extracted
# 2025-08-19 09:37:00 | Time series for point 175 extracted
# 2025-08-19 09:37:00 | Time series for point 176 extracted
# 2025-08-19 09:37:00 | Time series for point 177 extracted
# 2025-08-19 09:37:00 | Time series for point 178 extracted
# 2025-08-19 09:37:00 | Time series for point 179 extracted
# 2025-08-19 09:37:00 | Time series for point 180 extracted
# 2025-08-19 09:37:00 | Time series for point 181 extracted
# 2025-08-19 09:37:00 | Time series for point 182 extracted
# 2025-08-19 09:37:00 | Time series for point 183 extracted
# 2025-08-19 09:37:00 | Time series for point 184 extracted
# 2025-08-19 09:37:00 | Time series for point 185 extracted
# 2025-08-19 09:37:00 | Time series for point 186 extracted
# 2025-08-19 09:37:00 | Time series for point 187 extracted
# 2025-08-19 09:37:00 | Time series for point 188 extracted
# 2025-08-19 09:37:00 | Time series for point 189 extracted
# 2025-08-19 09:37:01 | Time series for point 190 extracted
# 2025-08-19 09:37:01 | Time series for point 191 extracted
# 2025-08-19 09:37:01 | Time series for point 192 extracted
# 2025-08-19 09:37:01 | Time series for point 193 extracted
# 2025-08-19 09:37:01 | Time series for point 194 extracted
# 2025-08-19 09:37:01 | Time series for point 195 extracted
# 2025-08-19 09:37:01 | Time series for point 196 extracted
# 2025-08-19 09:37:01 | Time series for point 197 extracted
# 2025-08-19 09:37:01 | Time series for point 198 extracted
# 2025-08-19 09:37:01 | Time series for point 199 extracted
# 2025-08-19 09:37:01 | Time series for point 200 extracted
# 2025-08-19 09:37:01 | Time series for point 201 extracted
# 2025-08-19 09:37:01 | Time series for point 202 extracted
# 2025-08-19 09:37:01 | Time series for point 203 extracted
# 2025-08-19 09:37:01 | Time series for point 204 extracted
# 2025-08-19 09:37:01 | Time series for point 205 extracted
# 2025-08-19 09:37:01 | Time series for point 206 extracted
# 2025-08-19 09:37:01 | Time series for point 207 extracted
# 2025-08-19 09:37:01 | Time series for point 208 extracted
# 2025-08-19 09:37:01 | Time series for point 209 extracted
# 2025-08-19 09:37:01 | Time series for point 210 extracted
# 2025-08-19 09:37:01 | Time series for point 211 extracted
# 2025-08-19 09:37:01 | Time series for point 212 extracted
# 2025-08-19 09:37:01 | Time series for point 213 extracted
# 2025-08-19 09:37:01 | Time series for point 214 extracted
# 2025-08-19 09:37:01 | Time series for point 215 extracted
# 2025-08-19 09:37:01 | Time series for point 216 extracted
# 2025-08-19 09:37:01 | Time series for point 217 extracted
# 2025-08-19 09:37:01 | Time series for point 218 extracted
# 2025-08-19 09:37:01 | Time series for point 219 extracted
# 2025-08-19 09:37:01 | Time series for point 220 extracted
# 2025-08-19 09:37:01 | Time series for point 221 extracted
# 2025-08-19 09:37:01 | Time series for point 222 extracted
# 2025-08-19 09:37:01 | Time series for point 223 extracted
# 2025-08-19 09:37:01 | Time series for point 224 extracted
# 2025-08-19 09:37:01 | Time series for point 225 extracted
# 2025-08-19 09:37:01 | Time series for point 226 extracted
# 2025-08-19 09:37:01 | Time series for point 227 extracted
# 2025-08-19 09:37:01 | Time series for point 228 extracted
# 2025-08-19 09:37:01 | Time series for point 229 extracted
# 2025-08-19 09:37:01 | Time series for point 230 extracted
# 2025-08-19 09:37:01 | Time series for point 231 extracted
# 2025-08-19 09:37:01 | Time series for point 232 extracted
# 2025-08-19 09:37:01 | Time series for point 233 extracted
# 2025-08-19 09:37:01 | Time series for point 234 extracted
# 2025-08-19 09:37:01 | Time series for point 235 extracted
# 2025-08-19 09:37:01 | Time series for point 236 extracted
# 2025-08-19 09:37:01 | Time series for point 237 extracted
# 2025-08-19 09:37:01 | Time series for point 238 extracted
# 2025-08-19 09:37:01 | Time series for point 239 extracted
# 2025-08-19 09:37:01 | Time series for point 240 extracted
# 2025-08-19 09:37:01 | Time series for point 241 extracted
# 2025-08-19 09:37:01 | Time series for point 242 extracted
# 2025-08-19 09:37:01 | Time series for point 243 extracted
# 2025-08-19 09:37:01 | Time series for point 244 extracted
# 2025-08-19 09:37:01 | Time series for point 245 extracted
# 2025-08-19 09:37:01 | Time series for point 246 extracted
# 2025-08-19 09:37:01 | Time series for point 247 extracted
# 2025-08-19 09:37:01 | Time series for point 248 extracted
# 2025-08-19 09:37:01 | Time series for point 249 extracted
# 2025-08-19 09:37:01 | Time series for point 250 extracted
# 2025-08-19 09:37:01 | Time series for point 251 extracted
# 2025-08-19 09:37:02 | Time series for point 252 extracted
# 2025-08-19 09:37:02 | Time series for point 253 extracted
# 2025-08-19 09:37:02 | Time series for point 254 extracted
# 2025-08-19 09:37:02 | Time series for point 255 extracted
# 2025-08-19 09:37:02 | Time series for point 256 extracted
# 2025-08-19 09:37:02 | Time series for point 257 extracted
# 2025-08-19 09:37:02 | Time series for point 258 extracted
# 2025-08-19 09:37:02 | Time series for point 259 extracted
# 2025-08-19 09:37:02 | Time series for point 260 extracted
# 2025-08-19 09:37:02 | Time series for point 261 extracted
# 2025-08-19 09:37:02 | Time series for point 262 extracted
# 2025-08-19 09:37:02 | Time series for point 263 extracted
# 2025-08-19 09:37:02 | Time series for point 264 extracted
# 2025-08-19 09:37:02 | Time series for point 265 extracted
# 2025-08-19 09:37:02 | Time series for point 266 extracted
# 2025-08-19 09:37:02 | Time series for point 267 extracted
# 2025-08-19 09:37:02 | Time series for point 268 extracted
# 2025-08-19 09:37:02 | Time series for point 269 extracted
# 2025-08-19 09:37:02 | Time series for point 270 extracted
# 2025-08-19 09:37:02 | Time series for point 271 extracted
# 2025-08-19 09:37:02 | Time series for point 272 extracted
# 2025-08-19 09:37:02 | Time series for point 274 extracted
# 2025-08-19 09:37:02 | Time series for point 276 extracted
# 2025-08-19 09:37:02 | Time series for point 277 extracted
# 2025-08-19 09:37:02 | Time series for point 278 extracted
# 2025-08-19 09:37:02 | Time series for point 279 extracted
# 2025-08-19 09:37:02 | Time series for point 280 extracted
# 2025-08-19 09:37:02 | Time series for point 282 extracted
# 2025-08-19 09:37:02 | Time series for point 283 extracted
# 2025-08-19 09:37:02 | Time series for point 284 extracted
# 2025-08-19 09:37:02 | Time series for point 285 extracted
# 2025-08-19 09:37:02 | Time series for point 286 extracted
# 2025-08-19 09:37:02 | Time series for point 287 extracted
# 2025-08-19 09:37:02 | Time series for point 288 extracted
# 2025-08-19 09:37:02 | Time series for point 289 extracted
# 2025-08-19 09:37:02 | Time series for point 290 extracted
# 2025-08-19 09:37:02 | Time series for point 291 extracted
# 2025-08-19 09:37:02 | Time series for point 292 extracted
# 2025-08-19 09:37:02 | Time series for point 293 extracted
# 2025-08-19 09:37:02 | Time series for point 294 extracted
# 2025-08-19 09:37:02 | Time series for point 295 extracted
# 2025-08-19 09:37:02 | Time series for point 296 extracted
# 2025-08-19 09:37:02 | Time series for point 297 extracted
# 2025-08-19 09:37:02 | Time series for point 298 extracted
# 2025-08-19 09:37:02 | Time series for point 299 extracted
# 2025-08-19 09:37:02 | Time series for point 300 extracted
# 2025-08-19 09:37:02 | Time series for point 301 extracted
# 2025-08-19 09:37:02 | Time series for point 302 extracted
# 2025-08-19 09:37:02 | Time series for point 303 extracted
# 2025-08-19 09:37:02 | Time series for point 304 extracted
# 2025-08-19 09:37:02 | Time series for point 305 extracted
# 2025-08-19 09:37:02 | Time series for point 306 extracted
# 2025-08-19 09:37:02 | Time series for point 307 extracted
# 2025-08-19 09:37:02 | Time series for point 308 extracted
# 2025-08-19 09:37:02 | Time series for point 309 extracted
# 2025-08-19 09:37:02 | Time series for point 310 extracted
# 2025-08-19 09:37:02 | Time series for point 311 extracted
# 2025-08-19 09:37:02 | Time series for point 312 extracted
# 2025-08-19 09:37:02 | Time series for point 313 extracted
# 2025-08-19 09:37:02 | Time series for point 314 extracted
# 2025-08-19 09:37:02 | Time series for point 315 extracted
# 2025-08-19 09:37:02 | Time series for point 316 extracted
# 2025-08-19 09:37:02 | Time series for point 317 extracted
# 2025-08-19 09:37:02 | Time series for point 318 extracted
# 2025-08-19 09:37:02 | Time series for point 319 extracted
# 2025-08-19 09:37:02 | Time series for point 320 extracted
# 2025-08-19 09:37:03 | Time series for point 322 extracted
# 2025-08-19 09:37:03 | Time series for point 323 extracted
# 2025-08-19 09:37:03 | Time series for point 324 extracted
# 2025-08-19 09:37:03 | Time series for point 325 extracted
# 2025-08-19 09:37:03 | Time series for point 326 extracted
# 2025-08-19 09:37:03 | Time series for point 327 extracted
# 2025-08-19 09:37:03 | Time series for point 328 extracted
# 2025-08-19 09:37:03 | Time series for point 329 extracted
# 2025-08-19 09:37:03 | Time series for point 330 extracted
# 2025-08-19 09:37:03 | Time series for point 331 extracted
# 2025-08-19 09:37:03 | Time series for point 332 extracted
# 2025-08-19 09:37:03 | Time series for point 333 extracted
# 2025-08-19 09:37:03 | Time series for point 334 extracted
# 2025-08-19 09:37:03 | Time series for point 335 extracted
# 2025-08-19 09:37:03 | Time series for point 336 extracted
# 2025-08-19 09:37:03 | Time series for point 337 extracted
# 2025-08-19 09:37:03 | Time series for point 338 extracted
# 2025-08-19 09:37:03 | Time series for point 339 extracted
# 2025-08-19 09:37:03 | Time series for point 340 extracted
# 2025-08-19 09:37:03 | Time series for point 341 extracted
# 2025-08-19 09:37:03 | Time series for point 342 extracted
# 2025-08-19 09:37:03 | Time series for point 343 extracted
# 2025-08-19 09:37:03 | Time series for point 344 extracted
# 2025-08-19 09:37:03 | Time series for point 345 extracted
# 2025-08-19 09:37:03 | Time series for point 346 extracted
# 2025-08-19 09:37:03 | Time series for point 347 extracted
# 2025-08-19 09:37:03 | Time series for point 348 extracted
# 2025-08-19 09:37:03 | Time series for point 349 extracted
# 2025-08-19 09:37:03 | Time series for point 350 extracted
# 2025-08-19 09:37:03 | Time series for point 351 extracted
# 2025-08-19 09:37:03 | Time series for point 352 extracted
# 2025-08-19 09:37:03 | Time series for point 353 extracted
# 2025-08-19 09:37:03 | Time series for point 354 extracted
# 2025-08-19 09:37:03 | Time series for point 355 extracted
# 2025-08-19 09:37:03 | Time series for point 356 extracted
# 2025-08-19 09:37:03 | Time series for point 357 extracted
# 2025-08-19 09:37:03 | Time series for point 358 extracted
# 2025-08-19 09:37:03 | Time series for point 359 extracted
# 2025-08-19 09:37:03 | Time series for point 360 extracted
# 2025-08-19 09:37:03 | Time series for point 361 extracted
# 2025-08-19 09:37:03 | Time series for point 362 extracted
# 2025-08-19 09:37:03 | Time series for point 363 extracted
# 2025-08-19 09:37:03 | Time series for point 365 extracted
# 2025-08-19 09:37:03 | Time series for point 366 extracted
# 2025-08-19 09:37:03 | Time series for point 367 extracted
# 2025-08-19 09:37:03 | Time series for point 368 extracted
# 2025-08-19 09:37:03 | Time series for point 369 extracted
# 2025-08-19 09:37:03 | Time series for point 370 extracted
# 2025-08-19 09:37:03 | Time series for point 371 extracted
# 2025-08-19 09:37:03 | Time series for point 373 extracted
# 2025-08-19 09:37:03 | Time series for point 374 extracted
# 2025-08-19 09:37:03 | Time series for point 376 extracted
# 2025-08-19 09:37:03 | Time series for point 377 extracted
# 2025-08-19 09:37:03 | Time series for point 378 extracted
# 2025-08-19 09:37:03 | Time series for point 379 extracted
# 2025-08-19 09:37:03 | Time series for point 380 extracted
# 2025-08-19 09:37:03 | Time series for point 381 extracted
# 2025-08-19 09:37:03 | Time series for point 382 extracted
# 2025-08-19 09:37:03 | Time series for point 383 extracted
# 2025-08-19 09:37:03 | Time series for point 384 extracted
# 2025-08-19 09:37:03 | Time series for point 385 extracted
# 2025-08-19 09:37:03 | Time series for point 386 extracted
# 2025-08-19 09:37:03 | Time series for point 387 extracted
# 2025-08-19 09:37:03 | Time series for point 388 extracted
# 2025-08-19 09:37:03 | Time series for point 389 extracted
# 2025-08-19 09:37:03 | Time series for point 390 extracted
# 2025-08-19 09:37:03 | Time series for point 391 extracted
# 2025-08-19 09:37:03 | Time series for point 392 extracted
# 2025-08-19 09:37:04 | Time series for point 393 extracted
# 2025-08-19 09:37:04 | Time series for point 394 extracted
# 2025-08-19 09:37:04 | Time series for point 395 extracted
# 2025-08-19 09:37:04 | Time series for point 396 extracted
# 2025-08-19 09:37:04 | Time series for point 397 extracted
# 2025-08-19 09:37:04 | Time series for point 398 extracted
# 2025-08-19 09:37:04 | Time series for point 399 extracted
# 2025-08-19 09:37:04 | Time series for point 400 extracted
# 2025-08-19 09:37:04 | Time series for point 401 extracted
# 2025-08-19 09:37:04 | Time series for point 402 extracted
# 2025-08-19 09:37:04 | Time series for point 403 extracted
# 2025-08-19 09:37:04 | Time series for point 404 extracted
# 2025-08-19 09:37:04 | Time series for point 405 extracted
# 2025-08-19 09:37:04 | Time series for point 406 extracted
# 2025-08-19 09:37:04 | Time series for point 407 extracted
# 2025-08-19 09:37:04 | Time series for point 408 extracted
# 2025-08-19 09:37:04 | Time series for point 409 extracted
# 2025-08-19 09:37:04 | Time series for point 410 extracted
# 2025-08-19 09:37:04 | Time series for point 411 extracted
# 2025-08-19 09:37:04 | Time series for point 412 extracted
# 2025-08-19 09:37:04 | Time series for point 413 extracted
# 2025-08-19 09:37:04 | Time series for point 415 extracted
# 2025-08-19 09:37:04 | Time series for point 416 extracted
# 2025-08-19 09:37:04 | Time series for point 417 extracted
# 2025-08-19 09:37:04 | Time series for point 418 extracted
# 2025-08-19 09:37:04 | Time series for point 419 extracted
# 2025-08-19 09:37:04 | Time series for point 420 extracted
# 2025-08-19 09:37:04 | Time series for point 422 extracted
# 2025-08-19 09:37:04 | Time series for point 423 extracted
# 2025-08-19 09:37:04 | Time series for point 426 extracted
# 2025-08-19 09:37:04 | Time series for point 427 extracted
# 2025-08-19 09:37:04 | Time series for point 428 extracted
# 2025-08-19 09:37:04 | Time series for point 432 extracted
# 2025-08-19 09:37:04 | Time series for point 435 extracted
# 2025-08-19 09:37:04 | Time series for point 437 extracted
# 2025-08-19 09:37:04 | Time series for point 440 extracted
# 2025-08-19 09:37:04 | Time series for point 441 extracted
# 2025-08-19 09:37:04 | Time series for point 446 extracted
# 2025-08-19 09:37:04 | Time series for point 447 extracted
# 2025-08-19 09:37:04 | Time series for point 448 extracted
# 2025-08-19 09:37:04 | Time series for point 449 extracted
# 2025-08-19 09:37:04 | Time series for point 451 extracted
# 2025-08-19 09:37:04 | Time series for point 452 extracted
# 2025-08-19 09:37:04 | Time series for point 453 extracted
# 2025-08-19 09:37:04 | Time series for point 459 extracted
# 2025-08-19 09:37:04 | Time series for point 461 extracted
# 2025-08-19 09:37:04 | Time series for point 463 extracted
# 2025-08-19 09:37:04 | Time series for point 467 extracted
# 2025-08-19 09:37:04 | Time series for point 470 extracted
# 2025-08-19 09:37:04 | Time series for point 472 extracted
# 2025-08-19 09:37:04 | Time series for point 475 extracted
# 2025-08-19 09:37:04 | Time series for point 477 extracted
# 2025-08-19 09:37:04 | Time series for point 479 extracted
# 2025-08-19 09:37:04 | Time series for point 480 extracted
# 2025-08-19 09:37:04 | Time series for point 481 extracted
# 2025-08-19 09:37:04 | Time series for point 482 extracted
# 2025-08-19 09:37:04 | Time series for point 485 extracted
# 2025-08-19 09:37:04 | Time series for point 487 extracted
# 2025-08-19 09:37:04 | Time series for point 489 extracted
# 2025-08-19 09:37:04 | Time series for point 490 extracted
# 2025-08-19 09:37:04 | Time series for point 491 extracted
# 2025-08-19 09:37:04 | Time series for point 492 extracted
# 2025-08-19 09:37:04 | Time series for point 493 extracted
# 2025-08-19 09:37:04 | Time series for point 495 extracted
# 2025-08-19 09:37:04 | Time series for point 505 extracted
# 2025-08-19 09:37:04 | Time series for point 507 extracted
# 2025-08-19 09:37:04 | Time series for point 512 extracted
# 2025-08-19 09:37:04 | Time series for point 513 extracted
# 2025-08-19 09:37:04 | Time series for point 514 extracted
# 2025-08-19 09:37:04 | Time series for point 519 extracted
# 2025-08-19 09:37:04 | Time series for point 522 extracted
# 2025-08-19 09:37:04 | Time series for point 523 extracted
# 2025-08-19 09:37:04 | Time series for point 529 extracted
# 2025-08-19 09:37:05 | Time series for point 530 extracted
# 2025-08-19 09:37:05 | Time series for point 534 extracted
# 2025-08-19 09:37:05 | Time series for point 535 extracted
# 2025-08-19 09:37:05 | Time series for point 540 extracted
# 2025-08-19 09:37:05 | Time series for point 548 extracted
# 2025-08-19 09:37:05 | Time series for point 549 extracted
# 2025-08-19 09:37:05 | Time series for point 556 extracted
# 2025-08-19 09:37:05 | Time series for point 557 extracted
# 2025-08-19 09:37:05 | Time series for point 562 extracted
# 2025-08-19 09:37:05 | Time series for point 568 extracted
# 2025-08-19 09:37:05 | Time series for point 570 extracted
# 2025-08-19 09:37:05 | Time series for point 571 extracted
# 2025-08-19 09:37:05 | Time series for point 578 extracted
# 2025-08-19 09:37:05 | Time series for point 579 extracted
# 2025-08-19 09:37:05 | Time series for point 580 extracted
# 2025-08-19 09:37:05 | Time series for point 582 extracted
# 2025-08-19 09:37:05 | Time series for point 584 extracted
# 2025-08-19 09:37:05 | Time series for point 591 extracted
# 2025-08-19 09:37:05 | Time series for point 592 extracted
# 2025-08-19 09:37:05 | Time series for point 595 extracted
# 2025-08-19 09:37:05 | Time series for point 602 extracted
# 2025-08-19 09:37:05 | Time series for point 606 extracted
# 2025-08-19 09:37:05 | Time series for point 607 extracted
# 2025-08-19 09:37:05 | Time series for point 613 extracted
# 2025-08-19 09:37:05 | Time series for point 614 extracted
# 2025-08-19 09:37:05 | Time series for point 627 extracted
# 2025-08-19 09:37:05 | Time series for point 633 extracted
# 2025-08-19 09:37:05 | Time series for point 636 extracted
# 2025-08-19 09:37:05 | Time series for point 645 extracted
# 2025-08-19 09:37:05 | Time series for point 649 extracted
# 2025-08-19 09:37:05 | Time series for point 651 extracted
# 2025-08-19 09:37:05 | Time series for point 652 extracted
# 2025-08-19 09:37:05 | Time series for point 669 extracted
# 2025-08-19 09:37:05 | Time series for point 672 extracted
# 2025-08-19 09:37:05 | Time series for point 681 extracted
# 2025-08-19 09:37:05 | Time series for point 683 extracted
# 2025-08-19 09:37:05 | Time series for point 694 extracted
# 2025-08-19 09:37:05 | Time series for point 696 extracted
# 2025-08-19 09:37:05 | Time series for point 699 extracted
# 2025-08-19 09:37:05 | Time series for point 700 extracted
# 2025-08-19 09:37:05 | Time series for point 707 extracted
# 2025-08-19 09:37:05 | Time series for point 709 extracted
# 2025-08-19 09:37:05 | Time series for point 713 extracted
# 2025-08-19 09:37:05 | Time series for point 716 extracted
# 2025-08-19 09:37:05 | Time series for point 717 extracted
# 2025-08-19 09:37:05 | Time series for point 720 extracted
# 2025-08-19 09:37:05 | Time series for point 721 extracted
# 2025-08-19 09:37:05 | Time series for point 724 extracted
# 2025-08-19 09:37:05 | Time series for point 727 extracted
# 2025-08-19 09:37:05 | Time series for point 730 extracted
# 2025-08-19 09:37:05 | Time series for point 731 extracted
# 2025-08-19 09:37:05 | Time series for point 733 extracted
# 2025-08-19 09:37:05 | Time series for point 734 extracted
# 2025-08-19 09:37:05 | Time series for point 737 extracted
# 2025-08-19 09:37:05 | Time series for point 740 extracted
# 2025-08-19 09:37:05 | Time series for point 743 extracted
# 2025-08-19 09:37:05 | Time series for point 744 extracted
# 2025-08-19 09:37:05 | Time series for point 747 extracted
# 2025-08-19 09:37:05 | Time series for point 749 extracted
# 2025-08-19 09:37:05 | Time series for point 756 extracted
# 2025-08-19 09:37:05 | Time series for point 757 extracted
# 2025-08-19 09:37:05 | Time series for point 758 extracted
# 2025-08-19 09:37:05 | Time series for point 759 extracted
# 2025-08-19 09:37:06 | Time series for point 760 extracted
# 2025-08-19 09:37:06 | Time series for point 763 extracted
# 2025-08-19 09:37:06 | Time series for point 764 extracted
# 2025-08-19 09:37:06 | Time series for point 769 extracted
# 2025-08-19 09:37:06 | Time series for point 770 extracted
# 2025-08-19 09:37:06 | Time series for point 771 extracted
# 2025-08-19 09:37:06 | Time series for point 772 extracted
# 2025-08-19 09:37:06 | Time series for point 775 extracted
# 2025-08-19 09:37:06 | Time series for point 783 extracted
# 2025-08-19 09:37:06 | Time series for point 785 extracted
# 2025-08-19 09:37:06 | Time series for point 786 extracted
# 2025-08-19 09:37:06 | Time series for point 788 extracted
# 2025-08-19 09:37:06 | Time series for point 790 extracted
# 2025-08-19 09:37:06 | Time series for point 791 extracted
# 2025-08-19 09:37:06 | Time series for point 793 extracted
# 2025-08-19 09:37:06 | Time series for point 794 extracted
# 2025-08-19 09:37:06 | Time series for point 795 extracted
# 2025-08-19 09:37:06 | Time series for point 796 extracted
# 2025-08-19 09:37:06 | Time series for point 797 extracted
# 2025-08-19 09:37:06 | Time series for point 798 extracted
# 2025-08-19 09:37:06 | Time series for point 800 extracted
# 2025-08-19 09:37:06 | Time series for point 801 extracted
# 2025-08-19 09:37:06 | Time series for point 803 extracted
# 2025-08-19 09:37:06 | Time series for point 804 extracted
# 2025-08-19 09:37:06 | Time series for point 805 extracted
# 2025-08-19 09:37:06 | Time series for point 806 extracted
# 2025-08-19 09:37:06 | Time series for point 809 extracted
# 2025-08-19 09:37:06 | Time series for point 811 extracted
# 2025-08-19 09:37:06 | Time series for point 812 extracted
# 2025-08-19 09:37:06 | Time series for point 813 extracted
# 2025-08-19 09:37:06 | Time series for point 814 extracted
# 2025-08-19 09:37:06 | Time series for point 815 extracted
# 2025-08-19 09:37:06 | Time series for point 816 extracted
# 2025-08-19 09:37:06 | Time series for point 821 extracted
# 2025-08-19 09:37:06 | Time series for point 822 extracted
# 2025-08-19 09:37:06 | Time series for point 824 extracted
# 2025-08-19 09:37:06 | Time series for point 826 extracted
# 2025-08-19 09:37:06 | Time series for point 827 extracted
# 2025-08-19 09:37:06 | Time series for point 828 extracted
# 2025-08-19 09:37:06 | Time series for point 829 extracted
# 2025-08-19 09:37:06 | Time series for point 830 extracted
# 2025-08-19 09:37:06 | Time series for point 831 extracted
# 2025-08-19 09:37:06 | Time series for point 832 extracted
# 2025-08-19 09:37:06 | Time series for point 833 extracted
# 2025-08-19 09:37:06 | Time series for point 834 extracted
# 2025-08-19 09:37:06 | Time series for point 835 extracted
# 2025-08-19 09:37:06 | Time series for point 837 extracted
# 2025-08-19 09:37:06 | Time series for point 838 extracted
# 2025-08-19 09:37:06 | Time series for point 839 extracted
# 2025-08-19 09:37:06 | Time series for point 841 extracted
# 2025-08-19 09:37:06 | Time series for point 842 extracted
# 2025-08-19 09:37:06 | Time series for point 843 extracted
# 2025-08-19 09:37:06 | Time series for point 844 extracted
# 2025-08-19 09:37:06 | Time series for point 845 extracted
# 2025-08-19 09:37:06 | Time series for point 846 extracted
# 2025-08-19 09:37:06 | Time series for point 847 extracted
# 2025-08-19 09:37:06 | Time series for point 848 extracted
# 2025-08-19 09:37:06 | Time series for point 849 extracted
# 2025-08-19 09:37:06 | Time series for point 850 extracted
# 2025-08-19 09:37:06 | Time series for point 851 extracted
# 2025-08-19 09:37:06 | Time series for point 852 extracted
# 2025-08-19 09:37:06 | Time series for point 853 extracted
# 2025-08-19 09:37:06 | Time series for point 854 extracted
# 2025-08-19 09:37:06 | Time series for point 855 extracted
# 2025-08-19 09:37:06 | Time series for point 856 extracted
# 2025-08-19 09:37:06 | Time series for point 857 extracted
# 2025-08-19 09:37:06 | Time series for point 858 extracted
# 2025-08-19 09:37:06 | Time series for point 859 extracted
# 2025-08-19 09:37:06 | Time series for point 861 extracted
# 2025-08-19 09:37:06 | Time series for point 862 extracted
# 2025-08-19 09:37:06 | Time series for point 863 extracted
# 2025-08-19 09:37:06 | Time series for point 864 extracted
# 2025-08-19 09:37:06 | Time series for point 867 extracted
# 2025-08-19 09:37:06 | Time series for point 870 extracted
# 2025-08-19 09:37:06 | Time series for point 871 extracted
# 2025-08-19 09:37:06 | Time series for point 872 extracted
# 2025-08-19 09:37:06 | Time series for point 873 extracted
# 2025-08-19 09:37:06 | Time series for point 874 extracted
# 2025-08-19 09:37:06 | Time series for point 875 extracted
# 2025-08-19 09:37:06 | Time series for point 876 extracted
# 2025-08-19 09:37:06 | Time series for point 877 extracted
# 2025-08-19 09:37:06 | Time series for point 878 extracted
# 2025-08-19 09:37:06 | Time series for point 879 extracted
# 2025-08-19 09:37:06 | Time series for point 880 extracted
# 2025-08-19 09:37:06 | Time series for point 882 extracted
# 2025-08-19 09:37:06 | Time series for point 883 extracted
# 2025-08-19 09:37:06 | Time series for point 885 extracted
# 2025-08-19 09:37:06 | Time series for point 887 extracted
# 2025-08-19 09:37:06 | Time series for point 889 extracted
# 2025-08-19 09:37:06 | Time series for point 890 extracted
# 2025-08-19 09:37:06 | Time series for point 891 extracted
# 2025-08-19 09:37:07 | Time series for point 892 extracted
# 2025-08-19 09:37:07 | Time series for point 893 extracted
# 2025-08-19 09:37:07 | Time series for point 894 extracted
# 2025-08-19 09:37:07 | Time series for point 895 extracted
# 2025-08-19 09:37:07 | Time series for point 896 extracted
# 2025-08-19 09:37:07 | Time series for point 897 extracted
# 2025-08-19 09:37:07 | Time series for point 900 extracted
# 2025-08-19 09:37:07 | Time series for point 902 extracted
# 2025-08-19 09:37:07 | Time series for point 903 extracted
# 2025-08-19 09:37:07 | Time series for point 905 extracted
# 2025-08-19 09:37:07 | Time series for point 906 extracted
# 2025-08-19 09:37:07 | Time series for point 908 extracted
# 2025-08-19 09:37:07 | Time series for point 909 extracted
# 2025-08-19 09:37:07 | Time series for point 911 extracted
# 2025-08-19 09:37:07 | Time series for point 912 extracted
# 2025-08-19 09:37:07 | Time series for point 913 extracted
# 2025-08-19 09:37:07 | Time series for point 914 extracted
# 2025-08-19 09:37:07 | Time series for point 916 extracted
# 2025-08-19 09:37:07 | Time series for point 919 extracted
# 2025-08-19 09:37:07 | Time series for point 922 extracted
# 2025-08-19 09:37:07 | Time series for point 923 extracted
# 2025-08-19 09:37:07 | Time series for point 924 extracted
# 2025-08-19 09:37:07 | Time series for point 925 extracted
# 2025-08-19 09:37:07 | Time series for point 927 extracted
# 2025-08-19 09:37:07 | Time series for point 932 extracted
# 2025-08-19 09:37:07 | Time series for point 935 extracted
# 2025-08-19 09:37:07 | Time series for point 938 extracted
# 2025-08-19 09:37:07 | Time series for point 939 extracted
# 2025-08-19 09:37:07 | Time series for point 940 extracted
# 2025-08-19 09:37:07 | Time series for point 941 extracted
# 2025-08-19 09:37:07 | Time series for point 942 extracted
# 2025-08-19 09:37:07 | Time series for point 943 extracted
# 2025-08-19 09:37:07 | Time series for point 944 extracted
# 2025-08-19 09:37:07 | Time series for point 945 extracted
# 2025-08-19 09:37:07 | Time series for point 947 extracted
# 2025-08-19 09:37:07 | Time series for point 948 extracted
# 2025-08-19 09:37:07 | Time series for point 949 extracted
# 2025-08-19 09:37:07 | Time series for point 951 extracted
# 2025-08-19 09:37:07 | Time series for point 954 extracted
# 2025-08-19 09:37:07 | Time series for point 955 extracted
# 2025-08-19 09:37:07 | Time series for point 956 extracted
# 2025-08-19 09:37:07 | Time series for point 957 extracted
# 2025-08-19 09:37:07 | Time series for point 958 extracted
# 2025-08-19 09:37:07 | Time series for point 959 extracted
# 2025-08-19 09:37:07 | Time series for point 960 extracted
# 2025-08-19 09:37:07 | Time series for point 961 extracted
# 2025-08-19 09:37:07 | Time series for point 962 extracted
# 2025-08-19 09:37:07 | Time series for point 966 extracted
# 2025-08-19 09:37:07 | Time series for point 967 extracted
# 2025-08-19 09:37:07 | Time series for point 968 extracted
# 2025-08-19 09:37:07 | Time series for point 969 extracted
# 2025-08-19 09:37:07 | Time series for point 971 extracted
# 2025-08-19 09:37:07 | Time series for point 974 extracted
# 2025-08-19 09:37:07 | Time series for point 975 extracted
# 2025-08-19 09:37:07 | Time series for point 976 extracted
# 2025-08-19 09:37:07 | Time series for point 977 extracted
# 2025-08-19 09:37:07 | Time series for point 978 extracted
# 2025-08-19 09:37:07 | Time series for point 979 extracted
# 2025-08-19 09:37:07 | Time series for point 980 extracted
# 2025-08-19 09:37:07 | Time series for point 981 extracted
# 2025-08-19 09:37:07 | Time series for point 982 extracted
# 2025-08-19 09:37:07 | Time series for point 983 extracted
# 2025-08-19 09:37:07 | Time series for point 984 extracted
# 2025-08-19 09:37:07 | Time series for point 986 extracted
# 2025-08-19 09:37:07 | Time series for point 988 extracted
# 2025-08-19 09:37:07 | Time series for point 989 extracted
# 2025-08-19 09:37:07 | Time series for point 991 extracted
# 2025-08-19 09:37:07 | Time series for point 992 extracted
# 2025-08-19 09:37:07 | Time series for point 993 extracted
# 2025-08-19 09:37:07 | Time series for point 994 extracted
# 2025-08-19 09:37:07 | Time series for point 995 extracted
# 2025-08-19 09:37:07 | Time series for point 997 extracted
# 2025-08-19 09:37:07 | Time series for point 998 extracted
# 2025-08-19 09:37:07 | Time series for point 999 extracted
# 2025-08-19 09:37:07 | Time series for point 1004 extracted
# 2025-08-19 09:37:07 | Time series for point 1006 extracted
# 2025-08-19 09:37:07 | Time series for point 1007 extracted
# 2025-08-19 09:37:07 | Time series for point 1008 extracted
# 2025-08-19 09:37:07 | Time series for point 1010 extracted
# 2025-08-19 09:37:07 | Time series for point 1012 extracted
# 2025-08-19 09:37:07 | Time series for point 1013 extracted
# 2025-08-19 09:37:07 | Time series for point 1014 extracted
# 2025-08-19 09:37:07 | Time series for point 1015 extracted
# 2025-08-19 09:37:07 | Time series for point 1016 extracted
# 2025-08-19 09:37:07 | Time series for point 1017 extracted
# 2025-08-19 09:37:07 | Time series for point 1019 extracted
# 2025-08-19 09:37:07 | Time series for point 1020 extracted
# 2025-08-19 09:37:07 | Time series for point 1021 extracted
# 2025-08-19 09:37:07 | Time series for point 1022 extracted
# 2025-08-19 09:37:07 | Time series for point 1024 extracted
# 2025-08-19 09:37:07 | Time series for point 1025 extracted
# 2025-08-19 09:37:07 | Time series for point 1027 extracted
# 2025-08-19 09:37:07 | Time series for point 1028 extracted
# 2025-08-19 09:37:07 | Time series for point 1029 extracted
# 2025-08-19 09:37:07 | Time series for point 1031 extracted
# 2025-08-19 09:37:07 | Time series for point 1032 extracted
# 2025-08-19 09:37:07 | Time series for point 1034 extracted
# 2025-08-19 09:37:07 | Time series for point 1035 extracted
# 2025-08-19 09:37:07 | Time series for point 1038 extracted
# 2025-08-19 09:37:07 | Time series for point 1041 extracted
# 2025-08-19 09:37:07 | Time series for point 1042 extracted
# 2025-08-19 09:37:08 | Time series for point 1043 extracted
# 2025-08-19 09:37:08 | Time series for point 1044 extracted
# 2025-08-19 09:37:08 | Time series for point 1045 extracted
# 2025-08-19 09:37:08 | Time series for point 1048 extracted
# 2025-08-19 09:37:08 | Time series for point 1051 extracted
# 2025-08-19 09:37:08 | Time series for point 1052 extracted
# 2025-08-19 09:37:08 | Time series for point 1053 extracted
# 2025-08-19 09:37:08 | Time series for point 1055 extracted
# 2025-08-19 09:37:08 | Time series for point 1057 extracted
# 2025-08-19 09:37:08 | Time series for point 1058 extracted
# 2025-08-19 09:37:08 | Time series for point 1060 extracted
# 2025-08-19 09:37:08 | Time series for point 1062 extracted
# 2025-08-19 09:37:08 | Time series for point 1063 extracted
# 2025-08-19 09:37:08 | Time series for point 1064 extracted
# 2025-08-19 09:37:08 | Time series for point 1065 extracted
# 2025-08-19 09:37:08 | Time series for point 1066 extracted
# 2025-08-19 09:37:08 | Time series for point 1067 extracted
# 2025-08-19 09:37:08 | Time series for point 1068 extracted
# 2025-08-19 09:37:08 | Time series for point 1069 extracted
# 2025-08-19 09:37:08 | Time series for point 1070 extracted
# 2025-08-19 09:37:08 | Time series for point 1071 extracted
# 2025-08-19 09:37:08 | Time series for point 1072 extracted
# 2025-08-19 09:37:08 | Time series for point 1073 extracted
# 2025-08-19 09:37:08 | Time series for point 1074 extracted
# 2025-08-19 09:37:08 | Time series for point 1077 extracted
# 2025-08-19 09:37:08 | Time series for point 1078 extracted
# 2025-08-19 09:37:08 | Time series for point 1079 extracted
# 2025-08-19 09:37:08 | Time series for point 1081 extracted
# 2025-08-19 09:37:08 | Time series for point 1084 extracted
# 2025-08-19 09:37:08 | Time series for point 1085 extracted
# 2025-08-19 09:37:08 | Time series for point 1086 extracted
# 2025-08-19 09:37:08 | Time series for point 1088 extracted
# 2025-08-19 09:37:08 | Time series for point 1089 extracted
# 2025-08-19 09:37:08 | Time series for point 1090 extracted
# 2025-08-19 09:37:08 | Time series for point 1091 extracted
# 2025-08-19 09:37:08 | Time series for point 1092 extracted
# 2025-08-19 09:37:08 | Time series for point 1093 extracted
# 2025-08-19 09:37:08 | Time series for point 1094 extracted
# 2025-08-19 09:37:08 | Time series for point 1095 extracted
# 2025-08-19 09:37:08 | Time series for point 1096 extracted
# 2025-08-19 09:37:08 | Time series for point 1097 extracted
# 2025-08-19 09:37:08 | Time series for point 1098 extracted
# 2025-08-19 09:37:08 | Time series for point 1099 extracted
# 2025-08-19 09:37:08 | Time series for point 1100 extracted
# 2025-08-19 09:37:08 | Time series for point 1101 extracted
# 2025-08-19 09:37:08 | Time series for point 1106 extracted
# 2025-08-19 09:37:08 | Time series for point 1107 extracted
# 2025-08-19 09:37:08 | Time series for point 1108 extracted
# 2025-08-19 09:37:08 | Time series for point 1111 extracted
# 2025-08-19 09:37:08 | Time series for point 1113 extracted
# 2025-08-19 09:37:08 | Time series for point 1115 extracted
# 2025-08-19 09:37:08 | Time series for point 1116 extracted
# 2025-08-19 09:37:08 | Time series for point 1118 extracted
# 2025-08-19 09:37:08 | Time series for point 1119 extracted
# 2025-08-19 09:37:08 | Time series for point 1120 extracted
# 2025-08-19 09:37:08 | Time series for point 1121 extracted
# 2025-08-19 09:37:08 | Time series for point 1122 extracted
# 2025-08-19 09:37:08 | Time series for point 1123 extracted
# 2025-08-19 09:37:08 | Time series for point 1124 extracted
# 2025-08-19 09:37:08 | Time series for point 1125 extracted
# 2025-08-19 09:37:08 | Time series for point 1126 extracted
# 2025-08-19 09:37:08 | Time series for point 1127 extracted
# 2025-08-19 09:37:08 | Time series for point 1128 extracted
# 2025-08-19 09:37:08 | Time series for point 1130 extracted
# 2025-08-19 09:37:08 | Time series for point 1131 extracted
# 2025-08-19 09:37:08 | Time series for point 1133 extracted
# 2025-08-19 09:37:08 | Time series for point 1134 extracted
# 2025-08-19 09:37:08 | Time series for point 1135 extracted
# 2025-08-19 09:37:08 | Time series for point 1136 extracted
# 2025-08-19 09:37:08 | Time series for point 1137 extracted
# 2025-08-19 09:37:08 | Time series for point 1138 extracted
# 2025-08-19 09:37:08 | Time series for point 1139 extracted
# 2025-08-19 09:37:08 | Time series for point 1140 extracted
# 2025-08-19 09:37:08 | Time series for point 1141 extracted
# 2025-08-19 09:37:08 | Time series for point 1142 extracted
# 2025-08-19 09:37:08 | Time series for point 1143 extracted
# 2025-08-19 09:37:08 | Time series for point 1145 extracted
# 2025-08-19 09:37:08 | Time series for point 1147 extracted
# 2025-08-19 09:37:09 | Time series for point 1148 extracted
# 2025-08-19 09:37:09 | Time series for point 1152 extracted
# 2025-08-19 09:37:09 | Time series for point 1154 extracted
# 2025-08-19 09:37:09 | Time series for point 1157 extracted
# 2025-08-19 09:37:09 | Time series for point 1159 extracted
# 2025-08-19 09:37:09 | Time series for point 1161 extracted
# 2025-08-19 09:37:09 | Time series for point 1162 extracted
# 2025-08-19 09:37:09 | Time series for point 1165 extracted
# 2025-08-19 09:37:09 | Time series for point 1166 extracted
# 2025-08-19 09:37:09 | Time series for point 1167 extracted
# 2025-08-19 09:37:09 | Time series for point 1169 extracted
# 2025-08-19 09:37:09 | Time series for point 1170 extracted
# 2025-08-19 09:37:09 | Time series for point 1173 extracted
# 2025-08-19 09:37:09 | Time series for point 1174 extracted
# 2025-08-19 09:37:09 | Time series for point 1175 extracted
# 2025-08-19 09:37:09 | Time series for point 1176 extracted
# 2025-08-19 09:37:09 | Time series for point 1177 extracted
# 2025-08-19 09:37:09 | Time series for point 1178 extracted
# 2025-08-19 09:37:09 | Time series for point 1179 extracted
# 2025-08-19 09:37:09 | Time series for point 1181 extracted
# 2025-08-19 09:37:09 | Time series for point 1184 extracted
# 2025-08-19 09:37:09 | Time series for point 1186 extracted
# 2025-08-19 09:37:09 | Time series for point 1187 extracted
# 2025-08-19 09:37:09 | Time series for point 1189 extracted
# 2025-08-19 09:37:09 | Time series for point 1192 extracted
# 2025-08-19 09:37:09 | Time series for point 1193 extracted
# 2025-08-19 09:37:09 | Time series for point 1194 extracted
# 2025-08-19 09:37:09 | Time series for point 1195 extracted
# 2025-08-19 09:37:09 | Time series for point 1196 extracted
# 2025-08-19 09:37:09 | Time series for point 1197 extracted
# 2025-08-19 09:37:09 | Time series for point 1198 extracted
# 2025-08-19 09:37:09 | Time series for point 1199 extracted
# 2025-08-19 09:37:09 | Time series for point 1200 extracted
# 2025-08-19 09:37:09 | Time series for point 1201 extracted
# 2025-08-19 09:37:09 | Time series for point 1202 extracted
# 2025-08-19 09:37:09 | Time series for point 1203 extracted
# 2025-08-19 09:37:09 | Time series for point 1206 extracted
# 2025-08-19 09:37:09 | Time series for point 1207 extracted
# ...
# 2025-08-19 09:37:16 | Time series for point 4532 extracted
# 2025-08-19 09:37:16 | Time series for point 4536 extracted
# 2025-08-19 09:37:16 | Time series for point 4544 extracted
# 2025-08-19 09:37:16 | Time series for point 4566 extracted
# 2025-08-19 09:37:16 | Time series for point 4605 extracted
# 2025-08-19 09:37:16 | Time series for point 4611 extracted
# 2025-08-19 09:37:16 | Time series for point 4612 extracted
# 2025-08-19 09:37:16 | Time series for point 4616 extracted
# 2025-08-19 09:37:16 | Time series for point 4638 extracted
# 2025-08-19 09:37:16 | Time series for point 4651 extracted
# 2025-08-19 09:37:16 | Time series for point 4676 extracted
# 2025-08-19 09:37:16 | Time series for point 4677 extracted
# 2025-08-19 09:37:16 | Time series for point 4706 extracted
# 2025-08-19 09:37:16 | Time series for point 4741 extracted
# 2025-08-19 09:37:16 | Time series for point 4797 extracted
# 2025-08-19 09:37:16 | Time series for point 4856 extracted
# 2025-08-19 09:37:16 | Time series for point 4892 extracted
# 2025-08-19 09:37:16 | Time series for point 4893 extracted
# 2025-08-19 09:37:16 | Time series for point 4941 extracted
# 2025-08-19 09:37:16 | Time series for point 4952 extracted
# 2025-08-19 09:37:16 | Time series for point 4984 extracted
# 2025-08-19 09:37:16 | Time series for point 5057 extracted
# 2025-08-19 09:37:16 | Time series for point 5079 extracted
# 2025-08-19 09:37:16 | Time series for point 5109 extracted
# 2025-08-19 09:37:16 | Time series for point 5117 extracted
# 2025-08-19 09:37:16 | Time series for point 5235 extracted
# 2025-08-19 09:37:16 | Time series for point 5364 extracted
# 2025-08-19 09:37:16 | Time series for point 5418 extracted
# 2025-08-19 09:37:16 | Time series for point 5496 extracted
# 2025-08-19 09:37:16 | Time series for point 6855 extracted
# 2025-08-19 09:37:16 | Time series for point 6856 extracted
# 2025-08-19 09:37:16 | Time series for point 6859 extracted
# 2025-08-19 09:37:16 | Time series for point 6865 extracted
# 2025-08-19 09:37:16 | Time series for point 6866 extracted
# 2025-08-19 09:37:16 | Time series for point 6867 extracted
# 2025-08-19 09:37:16 | Time series for point 6869 extracted
# 2025-08-19 09:37:16 | Time series for point 6872 extracted
# 2025-08-19 09:37:16 | Time series for point 6874 extracted
# 2025-08-19 09:37:16 | Time series for point 6876 extracted
# 2025-08-19 09:37:16 | Time series for point 6877 extracted
# 2025-08-19 09:37:16 | Time series for point 6878 extracted
# 2025-08-19 09:37:16 | Time series for point 6879 extracted
# 2025-08-19 09:37:16 | Time series for point 6880 extracted
# 2025-08-19 09:37:16 | Time series for point 6881 extracted
# 2025-08-19 09:37:16 | Time series for point 6882 extracted
# 2025-08-19 09:37:16 | Time series for point 6883 extracted
# 2025-08-19 09:37:16 | Time series for point 6886 extracted
# 2025-08-19 09:37:16 | Time series for point 6888 extracted
# 2025-08-19 09:37:16 | Time series for point 6889 extracted
# 2025-08-19 09:37:16 | Time series for point 6891 extracted
# 2025-08-19 09:37:16 | Time series for point 6893 extracted
# 2025-08-19 09:37:16 | Time series for point 6895 extracted
# 2025-08-19 09:37:16 | Time series for point 6898 extracted
# 2025-08-19 09:37:17 | Time series for point 6899 extracted
# 2025-08-19 09:37:17 | Time series for point 6900 extracted
# 2025-08-19 09:37:17 | Time series for point 6901 extracted
# 2025-08-19 09:37:17 | Time series for point 6903 extracted
# 2025-08-19 09:37:17 | Time series for point 6904 extracted
# 2025-08-19 09:37:17 | Time series for point 6905 extracted
# 2025-08-19 09:37:17 | Time series for point 6906 extracted
# 2025-08-19 09:37:17 | Time series for point 6907 extracted
# 2025-08-19 09:37:17 | Time series for point 6908 extracted
# 2025-08-19 09:37:17 | Time series for point 6909 extracted
# 2025-08-19 09:37:17 | Time series for point 6910 extracted
# 2025-08-19 09:37:17 | Time series for point 6911 extracted
# 2025-08-19 09:37:17 | Time series for point 6913 extracted
# 2025-08-19 09:37:17 | Time series for point 6914 extracted
# 2025-08-19 09:37:17 | Time series for point 6916 extracted
# 2025-08-19 09:37:17 | Time series for point 6921 extracted
# 2025-08-19 09:37:17 | Time series for point 6923 extracted
# 2025-08-19 09:37:17 | Time series for point 6925 extracted
# 2025-08-19 09:37:17 | Time series for point 6926 extracted
# 2025-08-19 09:37:17 | Time series for point 6928 extracted
# 2025-08-19 09:37:17 | Time series for point 6931 extracted
# 2025-08-19 09:37:17 | Time series for point 6932 extracted
# 2025-08-19 09:37:17 | Time series for point 6936 extracted
# 2025-08-19 09:37:17 | Time series for point 6937 extracted
# 2025-08-19 09:37:17 | Time series for point 6940 extracted
# 2025-08-19 09:37:17 | Time series for point 6943 extracted
# 2025-08-19 09:37:17 | Time series for point 6944 extracted
# 2025-08-19 09:37:17 | Time series for point 6947 extracted
# 2025-08-19 09:37:17 | Time series for point 6951 extracted
# 2025-08-19 09:37:17 | Time series for point 6954 extracted
# 2025-08-19 09:37:17 | Time series for point 6957 extracted
# 2025-08-19 09:37:17 | Time series for point 6959 extracted
# 2025-08-19 09:37:17 | Time series for point 6961 extracted
# 2025-08-19 09:37:17 | Time series for point 6963 extracted
# 2025-08-19 09:37:17 | Time series for point 6966 extracted
# 2025-08-19 09:37:17 | Time series for point 6967 extracted
# 2025-08-19 09:37:17 | Time series for point 6968 extracted
# 2025-08-19 09:37:17 | Time series for point 6970 extracted
# 2025-08-19 09:37:17 | Time series for point 6971 extracted
# 2025-08-19 09:37:17 | Time series for point 6973 extracted
# 2025-08-19 09:37:17 | Time series for point 6974 extracted
# 2025-08-19 09:37:17 | Time series for point 6976 extracted
# 2025-08-19 09:37:17 | Time series for point 6979 extracted
# 2025-08-19 09:37:17 | Time series for point 6980 extracted
# 2025-08-19 09:37:17 | Time series for point 6981 extracted
# 2025-08-19 09:37:17 | Time series for point 6983 extracted
# 2025-08-19 09:37:17 | Time series for point 6984 extracted
# 2025-08-19 09:37:17 | Time series for point 6988 extracted
# 2025-08-19 09:37:17 | Time series for point 6989 extracted
# 2025-08-19 09:37:17 | Time series for point 6990 extracted
# 2025-08-19 09:37:17 | Time series for point 6991 extracted
# 2025-08-19 09:37:17 | Time series for point 6992 extracted
# 2025-08-19 09:37:17 | Time series for point 6993 extracted
# 2025-08-19 09:37:17 | Time series for point 6994 extracted
# 2025-08-19 09:37:17 | Time series for point 6997 extracted
# 2025-08-19 09:37:17 | Time series for point 6998 extracted
# 2025-08-19 09:37:17 | Time series for point 6999 extracted
# 2025-08-19 09:37:17 | Time series for point 7001 extracted
# 2025-08-19 09:37:17 | Time series for point 7003 extracted
# 2025-08-19 09:37:17 | Time series for point 7008 extracted
# 2025-08-19 09:37:17 | Time series for point 7009 extracted
# 2025-08-19 09:37:17 | Time series for point 7010 extracted
# 2025-08-19 09:37:17 | Time series for point 7013 extracted
# 2025-08-19 09:37:17 | Time series for point 7016 extracted
# 2025-08-19 09:37:17 | Time series for point 7017 extracted
# 2025-08-19 09:37:17 | Time series for point 7019 extracted
# 2025-08-19 09:37:17 | Time series for point 7020 extracted
# 2025-08-19 09:37:17 | Time series for point 7022 extracted
# 2025-08-19 09:37:17 | Time series for point 7023 extracted
# 2025-08-19 09:37:17 | Time series for point 7025 extracted
# 2025-08-19 09:37:17 | Time series for point 7026 extracted
# 2025-08-19 09:37:17 | Time series for point 7027 extracted
# 2025-08-19 09:37:17 | Time series for point 7028 extracted
# 2025-08-19 09:37:17 | Time series for point 7029 extracted
# 2025-08-19 09:37:17 | Time series for point 7030 extracted
# 2025-08-19 09:37:17 | Time series for point 7031 extracted
# 2025-08-19 09:37:17 | Time series for point 7032 extracted
# 2025-08-19 09:37:17 | Time series for point 7034 extracted
# 2025-08-19 09:37:17 | Time series for point 7035 extracted
# 2025-08-19 09:37:17 | Time series for point 7036 extracted
# 2025-08-19 09:37:17 | Time series for point 7038 extracted
# 2025-08-19 09:37:17 | Time series for point 7039 extracted
# 2025-08-19 09:37:17 | Time series for point 7044 extracted
# 2025-08-19 09:37:17 | Time series for point 7045 extracted
# 2025-08-19 09:37:17 | Time series for point 7047 extracted
# 2025-08-19 09:37:17 | Time series for point 7049 extracted
# 2025-08-19 09:37:17 | Time series for point 7051 extracted
# 2025-08-19 09:37:17 | Time series for point 7052 extracted
# 2025-08-19 09:37:17 | Time series for point 7055 extracted
# 2025-08-19 09:37:17 | Time series for point 7056 extracted
# 2025-08-19 09:37:17 | Time series for point 7059 extracted
# 2025-08-19 09:37:18 | Time series for point 7060 extracted
# 2025-08-19 09:37:18 | Time series for point 7062 extracted
# 2025-08-19 09:37:18 | Time series for point 7063 extracted
# 2025-08-19 09:37:18 | Time series for point 7064 extracted
# 2025-08-19 09:37:18 | Time series for point 7066 extracted
# 2025-08-19 09:37:18 | Time series for point 7067 extracted
# 2025-08-19 09:37:18 | Time series for point 7069 extracted
# 2025-08-19 09:37:18 | Time series for point 7070 extracted
# 2025-08-19 09:37:18 | Time series for point 7071 extracted
# 2025-08-19 09:37:18 | Time series for point 7073 extracted
# 2025-08-19 09:37:18 | Time series for point 7074 extracted
# 2025-08-19 09:37:18 | Time series for point 7075 extracted
# 2025-08-19 09:37:18 | Time series for point 7076 extracted
# 2025-08-19 09:37:18 | Time series for point 7077 extracted
# 2025-08-19 09:37:18 | Time series for point 7078 extracted
# 2025-08-19 09:37:18 | Time series for point 7081 extracted
# 2025-08-19 09:37:18 | Time series for point 7082 extracted
# 2025-08-19 09:37:18 | Time series for point 7083 extracted
# 2025-08-19 09:37:18 | Time series for point 7084 extracted
# 2025-08-19 09:37:18 | Time series for point 7085 extracted
# 2025-08-19 09:37:18 | Time series for point 7086 extracted
# 2025-08-19 09:37:18 | Time series for point 7088 extracted
# 2025-08-19 09:37:18 | Time series for point 7089 extracted
# 2025-08-19 09:37:18 | Time series for point 7091 extracted
# 2025-08-19 09:37:18 | Time series for point 7097 extracted
# 2025-08-19 09:37:18 | Time series for point 7098 extracted
# 2025-08-19 09:37:18 | Time series for point 7099 extracted
# 2025-08-19 09:37:18 | Time series for point 7100 extracted
# 2025-08-19 09:37:18 | Time series for point 7101 extracted
# 2025-08-19 09:37:18 | Time series for point 7102 extracted
# 2025-08-19 09:37:18 | Time series for point 7103 extracted
# 2025-08-19 09:37:18 | Time series for point 7104 extracted
# 2025-08-19 09:37:18 | Time series for point 7106 extracted
# 2025-08-19 09:37:18 | Time series for point 7107 extracted
# 2025-08-19 09:37:18 | Time series for point 7109 extracted
# 2025-08-19 09:37:18 | Time series for point 7110 extracted
# 2025-08-19 09:37:18 | Time series for point 7111 extracted
# 2025-08-19 09:37:18 | Time series for point 7112 extracted
# 2025-08-19 09:37:18 | Time series for point 7113 extracted
# 2025-08-19 09:37:18 | Time series for point 7114 extracted
# 2025-08-19 09:37:18 | Time series for point 7118 extracted
# 2025-08-19 09:37:18 | Time series for point 7119 extracted
# 2025-08-19 09:37:18 | Time series for point 7120 extracted
# 2025-08-19 09:37:18 | Time series for point 7121 extracted
# 2025-08-19 09:37:18 | Time series for point 7122 extracted
# 2025-08-19 09:37:18 | Time series for point 7124 extracted
# 2025-08-19 09:37:18 | Time series for point 7125 extracted
# 2025-08-19 09:37:18 | Time series for point 7129 extracted
# 2025-08-19 09:37:18 | Time series for point 7131 extracted
# 2025-08-19 09:37:18 | Time series for point 7132 extracted
# 2025-08-19 09:37:18 | Time series for point 7133 extracted
# 2025-08-19 09:37:18 | Time series for point 7134 extracted
# 2025-08-19 09:37:18 | Time series for point 7135 extracted
# 2025-08-19 09:37:18 | Time series for point 7136 extracted
# 2025-08-19 09:37:18 | Time series for point 7137 extracted
# 2025-08-19 09:37:18 | Time series for point 7138 extracted
# 2025-08-19 09:37:18 | Time series for point 7141 extracted
# 2025-08-19 09:37:18 | Time series for point 7144 extracted
# 2025-08-19 09:37:18 | Time series for point 7145 extracted
# 2025-08-19 09:37:18 | Time series for point 7148 extracted
# 2025-08-19 09:37:18 | Time series for point 7149 extracted
# 2025-08-19 09:37:18 | Time series for point 7152 extracted
# 2025-08-19 09:37:18 | Time series for point 7153 extracted
# 2025-08-19 09:37:18 | Time series for point 7157 extracted
# 2025-08-19 09:37:18 | Time series for point 7158 extracted
# 2025-08-19 09:37:18 | Time series for point 7160 extracted
# 2025-08-19 09:37:18 | Time series for point 7161 extracted
# 2025-08-19 09:37:18 | Time series for point 7162 extracted
# 2025-08-19 09:37:18 | Time series for point 7163 extracted
# 2025-08-19 09:37:18 | Time series for point 7164 extracted
# 2025-08-19 09:37:18 | Time series for point 7165 extracted
# 2025-08-19 09:37:18 | Time series for point 7166 extracted
# 2025-08-19 09:37:18 | Time series for point 7168 extracted
# 2025-08-19 09:37:18 | Time series for point 7169 extracted
# 2025-08-19 09:37:18 | Time series for point 7170 extracted
# 2025-08-19 09:37:18 | Time series for point 7172 extracted
# 2025-08-19 09:37:18 | Time series for point 7173 extracted
# 2025-08-19 09:37:18 | Time series for point 7174 extracted
# 2025-08-19 09:37:18 | Time series for point 7175 extracted
# 2025-08-19 09:37:18 | Time series for point 7177 extracted
# 2025-08-19 09:37:18 | Time series for point 7179 extracted
# 2025-08-19 09:37:18 | Time series for point 7181 extracted
# 2025-08-19 09:37:18 | Time series for point 7182 extracted
# 2025-08-19 09:37:18 | Time series for point 7183 extracted
# 2025-08-19 09:37:18 | Time series for point 7184 extracted
# 2025-08-19 09:37:18 | Time series for point 7185 extracted
# 2025-08-19 09:37:18 | Time series for point 7187 extracted
# 2025-08-19 09:37:18 | Time series for point 7191 extracted
# 2025-08-19 09:37:18 | Time series for point 7192 extracted
# 2025-08-19 09:37:18 | Time series for point 7195 extracted
# 2025-08-19 09:37:18 | Time series for point 7196 extracted
# 2025-08-19 09:37:18 | Time series for point 7197 extracted
# 2025-08-19 09:37:18 | Time series for point 7198 extracted
# 2025-08-19 09:37:18 | Time series for point 7200 extracted
# 2025-08-19 09:37:18 | Time series for point 7201 extracted
# 2025-08-19 09:37:18 | Time series for point 7203 extracted
# 2025-08-19 09:37:18 | Time series for point 7204 extracted
# 2025-08-19 09:37:18 | Time series for point 7206 extracted
# 2025-08-19 09:37:18 | Time series for point 7207 extracted
# 2025-08-19 09:37:18 | Time series for point 7209 extracted
# 2025-08-19 09:37:18 | Time series for point 7211 extracted
# 2025-08-19 09:37:18 | Time series for point 7214 extracted
# 2025-08-19 09:37:18 | Time series for point 7215 extracted
# 2025-08-19 09:37:18 | Time series for point 7220 extracted
# 2025-08-19 09:37:18 | Time series for point 7222 extracted
# 2025-08-19 09:37:18 | Time series for point 7227 extracted
# 2025-08-19 09:37:18 | Time series for point 7228 extracted
# 2025-08-19 09:37:18 | Time series for point 7229 extracted
# 2025-08-19 09:37:18 | Time series for point 7242 extracted
# 2025-08-19 09:37:18 | Time series for point 7249 extracted
# 2025-08-19 09:37:18 | Time series for point 7274 extracted
# 2025-08-19 09:37:18 | Time series for point 7311 extracted
# 2025-08-19 09:37:18 | Time series for point 7336 extracted
# 2025-08-19 09:37:18 | Time series for point 7777 extracted
# 2025-08-19 09:37:18 | Time series for point 10557 extracted
# 2025-08-19 09:37:18 | Time series for point 27427 extracted
# 2025-08-19 09:37:18 | Time series for point 27992 extracted
# 2025-08-19 09:37:18 | Time series for point 27996 extracted
# 2025-08-19 09:37:18 | Time series for point 28009 extracted
# 2025-08-19 09:37:18 | Time series for point 28015 extracted
# 2025-08-19 09:37:18 | Time series for point 28076 extracted
# 2025-08-19 09:37:18 | Time series for point 28079 extracted
# 2025-08-19 09:37:18 | Time series for point 28090 extracted
# 2025-08-19 09:37:18 | Time series for point 28125 extracted
# 2025-08-19 09:37:18 | Time series for point 38808 extracted
# 2025-08-19 09:37:18 | Time series for point 99999 extracted

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    dis_avg[['GLOFAS4', 'GDW', 'GRAND', 'GLWD', 'LTR']],
    thr=0,
    vmin=0.01,
    vmax=3e4,
    title='average discharge (m3/s)'
)
plt.savefig(PATH_OUT / 'plots' / 'dis_avg_pairplot.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Select values
# I will use in all cases the average flow in the long-term run.

# %%
# select values from the GLOFAS4 long-term run
dis_avg.GLOFAS5 = dis_avg.LTR
dis_avg.SOURCE = 'GLOFAS4_ltr'

fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=dis_avg.GLOFAS5 / catchment.UPAREA * 3.6 * 24,
    cmap='viridis_r',
    s=5,
)
cbar = plt.colorbar(sct, shrink=.5, label='average discharge\n(mm/day)')
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'dis_avg_map.jpg', dpi=300, bbox_inches='tight')

# add values to GLOFAS5
glofas5.loc[dis_avg.index, 'DISAVG_CMS'] = dis_avg['GLOFAS5'].round(1).values

print('{0} reservoirs have an average inflow below 1 m3/s'.format((glofas5.DISAVG_CMS < 1).sum()))
# Out:
# 37 reservoirs have an average inflow below 1 m3/s

# %% [markdown]
# ### Degree of regulation
#
# The degree of regulation is the amount of annual inflow that the reservoir can store. I'll cap this value to 100 years (same as GRanD does), since it's not feasible that a reservoir was designed to store that amount of water.

# %%
dor = pd.DataFrame(index=glofas5.index, columns=['GLOFAS5', 'GDW', 'GRAND', 'GLWD'], dtype=float)

# GLOFAS5
dor['GLOFAS5'] = np.minimum(glofas5.CAP_MCM * 1e6 / (glofas5.DISAVG_CMS  * 24 * 3600 * 365), 100)

# GWD
dor.loc[gdw.index, 'GDW'] = gdw.DOR_PC.values / 100

# GRanD
dor.loc[grand.index, 'GRAND'] = grand.DOR_PC.values / 100

# GLWD
dor.loc[glwd.index, 'GLWD'] = np.minimum(glwd.VOLUME_CKM * 1e9 / (glwd.INFLOW_CMS * 24 * 3600 * 365), 100)

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    dor[['GLOFAS5', 'GLWD', 'GDW', 'GRAND']],
    thr=0,
    vmin=0.001,
    vmax=150,
    title='degree of regulation (-)'
)
plt.savefig(PATH_OUT / 'plots' / 'dor_pairplot.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Select values
#
# I will use the values obtained from the attributes in GLOFAS5.

# %%
fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=dor.GLOFAS5,
    cmap='viridis_r',
    s=5,
    vmin=0,
    vmax=10
)
cbar = plt.colorbar(sct, shrink=.5, label='degree of regulation\n(-)')
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'dor_map.jpg', dpi=300, bbox_inches='tight')

glofas5['DOR'] = dor.GLOFAS5.round(3)

print('{0} reservoirs do not comply with the minimum degree of regulation {1}'.format((glofas5.DOR < MIN_DOR).sum(),
                                                                                       MIN_DOR))
print('{0} reservoirs have a degree of regulation larger than 10 years'.format((glofas5.DOR > 10).sum()))
# Out:
# 220 reservoirs do not comply with the minimum degree of regulation 0.08
# 77 reservoirs have a degree of regulation larger than 10 years

# %% [markdown]
# There are problems in the computation of the degree of regulation, inherited either from the reservoir storage or the average inflow. It's not realistic that 84 reservoirs were designed to store 10 years of inflow.

# %% [markdown]
# ### 100-year return period

# %%
dis_100 = pd.DataFrame(index=glofas5.index, columns=['GLOFAS4', 'LTR', 'GLOFAS5', 'SOURCE'], dtype=float)
dis_100.SOURCE = dis_100.SOURCE.astype(str)

# GLOFAS4
dis_100.loc[glofas4.index, 'GLOFAS4'] = glofas4.ndq

# GLOFAS4 long-run average
# dis_100['LTR'] = dis_100_ltr.sel({'x': poi_5['x'], 'y': poi_5['y']}, method='nearest').to_pandas()
dis_100['LTR'] = extract_timeseries(dis_100_ltr, poi_4.rename({idx_name: 'id'}), inflow=True, ldd=ldd).to_pandas()
# dis_100['LTR'] = pd.Series({ID: return_period(inflow_ltr.sel(ID=ID).to_pandas(), T=100) for ID in inflow_ltr.ID.data})
# Out:
# 2025-08-19 09:37:28 | Time series for point 1 extracted
# 2025-08-19 09:37:28 | Time series for point 2 extracted
# 2025-08-19 09:37:28 | Time series for point 3 extracted
# 2025-08-19 09:37:28 | Time series for point 4 extracted
# 2025-08-19 09:37:29 | Time series for point 5 extracted
# 2025-08-19 09:37:29 | Time series for point 6 extracted
# 2025-08-19 09:37:29 | Time series for point 7 extracted
# 2025-08-19 09:37:29 | Time series for point 8 extracted
# 2025-08-19 09:37:29 | Time series for point 9 extracted
# 2025-08-19 09:37:29 | Time series for point 10 extracted
# 2025-08-19 09:37:29 | Time series for point 11 extracted
# 2025-08-19 09:37:29 | Time series for point 12 extracted
# 2025-08-19 09:37:29 | Time series for point 13 extracted
# 2025-08-19 09:37:29 | Time series for point 14 extracted
# 2025-08-19 09:37:29 | Time series for point 15 extracted
# 2025-08-19 09:37:29 | Time series for point 16 extracted
# 2025-08-19 09:37:29 | Time series for point 17 extracted
# 2025-08-19 09:37:29 | Time series for point 18 extracted
# 2025-08-19 09:37:29 | Time series for point 19 extracted
# 2025-08-19 09:37:29 | Time series for point 20 extracted
# 2025-08-19 09:37:29 | Time series for point 21 extracted
# 2025-08-19 09:37:29 | Time series for point 22 extracted
# 2025-08-19 09:37:29 | Time series for point 23 extracted
# 2025-08-19 09:37:29 | Time series for point 24 extracted
# 2025-08-19 09:37:29 | Time series for point 25 extracted
# 2025-08-19 09:37:29 | Time series for point 26 extracted
# 2025-08-19 09:37:29 | Time series for point 27 extracted
# 2025-08-19 09:37:29 | Time series for point 28 extracted
# 2025-08-19 09:37:29 | Time series for point 29 extracted
# 2025-08-19 09:37:29 | Time series for point 30 extracted
# 2025-08-19 09:37:29 | Time series for point 31 extracted
# 2025-08-19 09:37:29 | Time series for point 32 extracted
# 2025-08-19 09:37:30 | Time series for point 33 extracted
# 2025-08-19 09:37:30 | Time series for point 34 extracted
# 2025-08-19 09:37:30 | Time series for point 35 extracted
# 2025-08-19 09:37:30 | Time series for point 36 extracted
# 2025-08-19 09:37:30 | Time series for point 37 extracted
# 2025-08-19 09:37:30 | Time series for point 38 extracted
# 2025-08-19 09:37:30 | Time series for point 39 extracted
# 2025-08-19 09:37:30 | Time series for point 40 extracted
# 2025-08-19 09:37:30 | Time series for point 41 extracted
# 2025-08-19 09:37:30 | Time series for point 42 extracted
# 2025-08-19 09:37:30 | Time series for point 43 extracted
# 2025-08-19 09:37:30 | Time series for point 44 extracted
# 2025-08-19 09:37:30 | Time series for point 45 extracted
# 2025-08-19 09:37:30 | Time series for point 46 extracted
# 2025-08-19 09:37:30 | Time series for point 47 extracted
# 2025-08-19 09:37:30 | Time series for point 48 extracted
# 2025-08-19 09:37:30 | Time series for point 49 extracted
# 2025-08-19 09:37:30 | Time series for point 50 extracted
# 2025-08-19 09:37:30 | Time series for point 51 extracted
# 2025-08-19 09:37:30 | Time series for point 52 extracted
# 2025-08-19 09:37:30 | Time series for point 53 extracted
# 2025-08-19 09:37:30 | Time series for point 54 extracted
# 2025-08-19 09:37:30 | Time series for point 55 extracted
# 2025-08-19 09:37:30 | Time series for point 56 extracted
# 2025-08-19 09:37:30 | Time series for point 57 extracted
# 2025-08-19 09:37:30 | Time series for point 58 extracted
# 2025-08-19 09:37:30 | Time series for point 59 extracted
# 2025-08-19 09:37:30 | Time series for point 60 extracted
# 2025-08-19 09:37:30 | Time series for point 61 extracted
# 2025-08-19 09:37:30 | Time series for point 62 extracted
# 2025-08-19 09:37:30 | Time series for point 63 extracted
# 2025-08-19 09:37:30 | Time series for point 64 extracted
# 2025-08-19 09:37:30 | Time series for point 65 extracted
# 2025-08-19 09:37:30 | Time series for point 66 extracted
# 2025-08-19 09:37:30 | Time series for point 67 extracted
# 2025-08-19 09:37:31 | Time series for point 68 extracted
# 2025-08-19 09:37:31 | Time series for point 69 extracted
# 2025-08-19 09:37:31 | Time series for point 70 extracted
# 2025-08-19 09:37:31 | Time series for point 71 extracted
# 2025-08-19 09:37:31 | Time series for point 72 extracted
# 2025-08-19 09:37:31 | Time series for point 73 extracted
# 2025-08-19 09:37:31 | Time series for point 74 extracted
# 2025-08-19 09:37:31 | Time series for point 75 extracted
# 2025-08-19 09:37:31 | Time series for point 76 extracted
# 2025-08-19 09:37:31 | Time series for point 77 extracted
# 2025-08-19 09:37:31 | Time series for point 78 extracted
# 2025-08-19 09:37:31 | Time series for point 79 extracted
# 2025-08-19 09:37:31 | Time series for point 80 extracted
# 2025-08-19 09:37:31 | Time series for point 81 extracted
# 2025-08-19 09:37:31 | Time series for point 82 extracted
# 2025-08-19 09:37:31 | Time series for point 84 extracted
# 2025-08-19 09:37:31 | Time series for point 85 extracted
# 2025-08-19 09:37:31 | Time series for point 86 extracted
# 2025-08-19 09:37:31 | Time series for point 87 extracted
# 2025-08-19 09:37:31 | Time series for point 88 extracted
# 2025-08-19 09:37:31 | Time series for point 89 extracted
# 2025-08-19 09:37:31 | Time series for point 90 extracted
# 2025-08-19 09:37:31 | Time series for point 91 extracted
# 2025-08-19 09:37:31 | Time series for point 92 extracted
# 2025-08-19 09:37:31 | Time series for point 93 extracted
# 2025-08-19 09:37:31 | Time series for point 94 extracted
# 2025-08-19 09:37:31 | Time series for point 95 extracted
# 2025-08-19 09:37:31 | Time series for point 96 extracted
# 2025-08-19 09:37:31 | Time series for point 97 extracted
# 2025-08-19 09:37:31 | Time series for point 98 extracted
# 2025-08-19 09:37:31 | Time series for point 99 extracted
# 2025-08-19 09:37:31 | Time series for point 100 extracted
# 2025-08-19 09:37:31 | Time series for point 101 extracted
# 2025-08-19 09:37:31 | Time series for point 102 extracted
# 2025-08-19 09:37:31 | Time series for point 103 extracted
# 2025-08-19 09:37:31 | Time series for point 104 extracted
# 2025-08-19 09:37:31 | Time series for point 105 extracted
# 2025-08-19 09:37:31 | Time series for point 106 extracted
# 2025-08-19 09:37:31 | Time series for point 107 extracted
# 2025-08-19 09:37:31 | Time series for point 108 extracted
# 2025-08-19 09:37:31 | Time series for point 109 extracted
# 2025-08-19 09:37:31 | Time series for point 110 extracted
# 2025-08-19 09:37:31 | Time series for point 111 extracted
# 2025-08-19 09:37:31 | Time series for point 112 extracted
# 2025-08-19 09:37:31 | Time series for point 113 extracted
# 2025-08-19 09:37:31 | Time series for point 114 extracted
# 2025-08-19 09:37:31 | Time series for point 115 extracted
# 2025-08-19 09:37:31 | Time series for point 116 extracted
# 2025-08-19 09:37:31 | Time series for point 117 extracted
# 2025-08-19 09:37:31 | Time series for point 118 extracted
# 2025-08-19 09:37:31 | Time series for point 119 extracted
# 2025-08-19 09:37:31 | Time series for point 120 extracted
# 2025-08-19 09:37:31 | Time series for point 121 extracted
# 2025-08-19 09:37:31 | Time series for point 123 extracted
# 2025-08-19 09:37:31 | Time series for point 124 extracted
# 2025-08-19 09:37:31 | Time series for point 125 extracted
# 2025-08-19 09:37:31 | Time series for point 126 extracted
# 2025-08-19 09:37:31 | Time series for point 127 extracted
# 2025-08-19 09:37:31 | Time series for point 128 extracted
# 2025-08-19 09:37:31 | Time series for point 129 extracted
# 2025-08-19 09:37:31 | Time series for point 131 extracted
# 2025-08-19 09:37:31 | Time series for point 132 extracted
# 2025-08-19 09:37:31 | Time series for point 133 extracted
# 2025-08-19 09:37:31 | Time series for point 134 extracted
# 2025-08-19 09:37:31 | Time series for point 135 extracted
# 2025-08-19 09:37:31 | Time series for point 136 extracted
# 2025-08-19 09:37:31 | Time series for point 137 extracted
# 2025-08-19 09:37:31 | Time series for point 138 extracted
# 2025-08-19 09:37:31 | Time series for point 139 extracted
# 2025-08-19 09:37:32 | Time series for point 140 extracted
# 2025-08-19 09:37:32 | Time series for point 141 extracted
# 2025-08-19 09:37:32 | Time series for point 142 extracted
# 2025-08-19 09:37:32 | Time series for point 143 extracted
# 2025-08-19 09:37:32 | Time series for point 144 extracted
# 2025-08-19 09:37:32 | Time series for point 145 extracted
# 2025-08-19 09:37:32 | Time series for point 146 extracted
# 2025-08-19 09:37:32 | Time series for point 147 extracted
# 2025-08-19 09:37:32 | Time series for point 148 extracted
# 2025-08-19 09:37:32 | Time series for point 149 extracted
# 2025-08-19 09:37:32 | Time series for point 150 extracted
# 2025-08-19 09:37:32 | Time series for point 151 extracted
# 2025-08-19 09:37:32 | Time series for point 152 extracted
# 2025-08-19 09:37:32 | Time series for point 153 extracted
# 2025-08-19 09:37:32 | Time series for point 154 extracted
# 2025-08-19 09:37:32 | Time series for point 155 extracted
# 2025-08-19 09:37:32 | Time series for point 156 extracted
# 2025-08-19 09:37:32 | Time series for point 157 extracted
# 2025-08-19 09:37:32 | Time series for point 158 extracted
# 2025-08-19 09:37:32 | Time series for point 159 extracted
# 2025-08-19 09:37:32 | Time series for point 160 extracted
# 2025-08-19 09:37:32 | Time series for point 161 extracted
# 2025-08-19 09:37:32 | Time series for point 162 extracted
# 2025-08-19 09:37:32 | Time series for point 163 extracted
# 2025-08-19 09:37:32 | Time series for point 164 extracted
# 2025-08-19 09:37:32 | Time series for point 165 extracted
# 2025-08-19 09:37:32 | Time series for point 166 extracted
# 2025-08-19 09:37:32 | Time series for point 167 extracted
# 2025-08-19 09:37:32 | Time series for point 168 extracted
# 2025-08-19 09:37:32 | Time series for point 169 extracted
# 2025-08-19 09:37:32 | Time series for point 170 extracted
# 2025-08-19 09:37:32 | Time series for point 171 extracted
# 2025-08-19 09:37:32 | Time series for point 172 extracted
# 2025-08-19 09:37:32 | Time series for point 173 extracted
# 2025-08-19 09:37:32 | Time series for point 174 extracted
# 2025-08-19 09:37:32 | Time series for point 175 extracted
# 2025-08-19 09:37:32 | Time series for point 176 extracted
# 2025-08-19 09:37:32 | Time series for point 177 extracted
# 2025-08-19 09:37:32 | Time series for point 178 extracted
# 2025-08-19 09:37:32 | Time series for point 179 extracted
# 2025-08-19 09:37:32 | Time series for point 180 extracted
# 2025-08-19 09:37:32 | Time series for point 181 extracted
# 2025-08-19 09:37:32 | Time series for point 182 extracted
# 2025-08-19 09:37:33 | Time series for point 183 extracted
# 2025-08-19 09:37:33 | Time series for point 184 extracted
# 2025-08-19 09:37:33 | Time series for point 185 extracted
# 2025-08-19 09:37:33 | Time series for point 186 extracted
# 2025-08-19 09:37:33 | Time series for point 187 extracted
# 2025-08-19 09:37:33 | Time series for point 188 extracted
# 2025-08-19 09:37:33 | Time series for point 189 extracted
# 2025-08-19 09:37:33 | Time series for point 190 extracted
# 2025-08-19 09:37:33 | Time series for point 191 extracted
# 2025-08-19 09:37:33 | Time series for point 192 extracted
# 2025-08-19 09:37:33 | Time series for point 193 extracted
# 2025-08-19 09:37:33 | Time series for point 194 extracted
# 2025-08-19 09:37:33 | Time series for point 195 extracted
# 2025-08-19 09:37:33 | Time series for point 196 extracted
# 2025-08-19 09:37:33 | Time series for point 197 extracted
# 2025-08-19 09:37:33 | Time series for point 198 extracted
# 2025-08-19 09:37:33 | Time series for point 199 extracted
# 2025-08-19 09:37:33 | Time series for point 200 extracted
# 2025-08-19 09:37:33 | Time series for point 201 extracted
# 2025-08-19 09:37:33 | Time series for point 202 extracted
# 2025-08-19 09:37:33 | Time series for point 203 extracted
# 2025-08-19 09:37:33 | Time series for point 204 extracted
# 2025-08-19 09:37:33 | Time series for point 205 extracted
# 2025-08-19 09:37:33 | Time series for point 206 extracted
# 2025-08-19 09:37:33 | Time series for point 207 extracted
# 2025-08-19 09:37:33 | Time series for point 208 extracted
# 2025-08-19 09:37:33 | Time series for point 209 extracted
# 2025-08-19 09:37:33 | Time series for point 210 extracted
# 2025-08-19 09:37:33 | Time series for point 211 extracted
# 2025-08-19 09:37:33 | Time series for point 212 extracted
# 2025-08-19 09:37:33 | Time series for point 213 extracted
# 2025-08-19 09:37:33 | Time series for point 214 extracted
# 2025-08-19 09:37:33 | Time series for point 215 extracted
# 2025-08-19 09:37:33 | Time series for point 216 extracted
# 2025-08-19 09:37:33 | Time series for point 217 extracted
# 2025-08-19 09:37:33 | Time series for point 218 extracted
# 2025-08-19 09:37:33 | Time series for point 219 extracted
# 2025-08-19 09:37:33 | Time series for point 220 extracted
# 2025-08-19 09:37:33 | Time series for point 221 extracted
# 2025-08-19 09:37:33 | Time series for point 222 extracted
# 2025-08-19 09:37:33 | Time series for point 223 extracted
# 2025-08-19 09:37:33 | Time series for point 224 extracted
# 2025-08-19 09:37:33 | Time series for point 225 extracted
# 2025-08-19 09:37:33 | Time series for point 226 extracted
# 2025-08-19 09:37:33 | Time series for point 227 extracted
# 2025-08-19 09:37:34 | Time series for point 228 extracted
# 2025-08-19 09:37:34 | Time series for point 229 extracted
# 2025-08-19 09:37:34 | Time series for point 230 extracted
# 2025-08-19 09:37:34 | Time series for point 231 extracted
# 2025-08-19 09:37:34 | Time series for point 232 extracted
# 2025-08-19 09:37:34 | Time series for point 233 extracted
# 2025-08-19 09:37:34 | Time series for point 234 extracted
# 2025-08-19 09:37:34 | Time series for point 235 extracted
# 2025-08-19 09:37:34 | Time series for point 236 extracted
# 2025-08-19 09:37:34 | Time series for point 237 extracted
# 2025-08-19 09:37:34 | Time series for point 238 extracted
# 2025-08-19 09:37:34 | Time series for point 239 extracted
# 2025-08-19 09:37:34 | Time series for point 240 extracted
# 2025-08-19 09:37:34 | Time series for point 241 extracted
# 2025-08-19 09:37:34 | Time series for point 242 extracted
# 2025-08-19 09:37:34 | Time series for point 243 extracted
# 2025-08-19 09:37:34 | Time series for point 244 extracted
# 2025-08-19 09:37:34 | Time series for point 245 extracted
# 2025-08-19 09:37:34 | Time series for point 246 extracted
# 2025-08-19 09:37:34 | Time series for point 247 extracted
# 2025-08-19 09:37:34 | Time series for point 248 extracted
# 2025-08-19 09:37:34 | Time series for point 249 extracted
# 2025-08-19 09:37:34 | Time series for point 250 extracted
# 2025-08-19 09:37:34 | Time series for point 251 extracted
# 2025-08-19 09:37:34 | Time series for point 252 extracted
# 2025-08-19 09:37:34 | Time series for point 253 extracted
# 2025-08-19 09:37:34 | Time series for point 254 extracted
# 2025-08-19 09:37:34 | Time series for point 255 extracted
# 2025-08-19 09:37:34 | Time series for point 256 extracted
# 2025-08-19 09:37:34 | Time series for point 257 extracted
# 2025-08-19 09:37:34 | Time series for point 258 extracted
# 2025-08-19 09:37:34 | Time series for point 259 extracted
# 2025-08-19 09:37:34 | Time series for point 260 extracted
# 2025-08-19 09:37:34 | Time series for point 261 extracted
# 2025-08-19 09:37:34 | Time series for point 262 extracted
# 2025-08-19 09:37:34 | Time series for point 263 extracted
# 2025-08-19 09:37:34 | Time series for point 264 extracted
# 2025-08-19 09:37:34 | Time series for point 265 extracted
# 2025-08-19 09:37:34 | Time series for point 266 extracted
# 2025-08-19 09:37:34 | Time series for point 267 extracted
# 2025-08-19 09:37:34 | Time series for point 268 extracted
# 2025-08-19 09:37:34 | Time series for point 269 extracted
# 2025-08-19 09:37:34 | Time series for point 270 extracted
# 2025-08-19 09:37:34 | Time series for point 271 extracted
# 2025-08-19 09:37:34 | Time series for point 272 extracted
# 2025-08-19 09:37:34 | Time series for point 274 extracted
# 2025-08-19 09:37:34 | Time series for point 276 extracted
# 2025-08-19 09:37:34 | Time series for point 277 extracted
# 2025-08-19 09:37:34 | Time series for point 278 extracted
# 2025-08-19 09:37:34 | Time series for point 279 extracted
# 2025-08-19 09:37:34 | Time series for point 280 extracted
# 2025-08-19 09:37:34 | Time series for point 282 extracted
# 2025-08-19 09:37:34 | Time series for point 283 extracted
# 2025-08-19 09:37:34 | Time series for point 284 extracted
# 2025-08-19 09:37:35 | Time series for point 285 extracted
# 2025-08-19 09:37:35 | Time series for point 286 extracted
# 2025-08-19 09:37:35 | Time series for point 287 extracted
# 2025-08-19 09:37:35 | Time series for point 288 extracted
# 2025-08-19 09:37:35 | Time series for point 289 extracted
# 2025-08-19 09:37:35 | Time series for point 290 extracted
# 2025-08-19 09:37:35 | Time series for point 291 extracted
# 2025-08-19 09:37:35 | Time series for point 292 extracted
# 2025-08-19 09:37:35 | Time series for point 293 extracted
# 2025-08-19 09:37:35 | Time series for point 294 extracted
# 2025-08-19 09:37:35 | Time series for point 295 extracted
# 2025-08-19 09:37:35 | Time series for point 296 extracted
# 2025-08-19 09:37:35 | Time series for point 297 extracted
# 2025-08-19 09:37:35 | Time series for point 298 extracted
# 2025-08-19 09:37:35 | Time series for point 299 extracted
# 2025-08-19 09:37:35 | Time series for point 300 extracted
# 2025-08-19 09:37:35 | Time series for point 301 extracted
# 2025-08-19 09:37:35 | Time series for point 302 extracted
# 2025-08-19 09:37:35 | Time series for point 303 extracted
# 2025-08-19 09:37:35 | Time series for point 304 extracted
# 2025-08-19 09:37:35 | Time series for point 305 extracted
# 2025-08-19 09:37:35 | Time series for point 306 extracted
# 2025-08-19 09:37:35 | Time series for point 307 extracted
# 2025-08-19 09:37:35 | Time series for point 308 extracted
# 2025-08-19 09:37:35 | Time series for point 309 extracted
# 2025-08-19 09:37:35 | Time series for point 310 extracted
# 2025-08-19 09:37:35 | Time series for point 311 extracted
# 2025-08-19 09:37:35 | Time series for point 312 extracted
# 2025-08-19 09:37:35 | Time series for point 313 extracted
# 2025-08-19 09:37:35 | Time series for point 314 extracted
# 2025-08-19 09:37:35 | Time series for point 315 extracted
# 2025-08-19 09:37:35 | Time series for point 316 extracted
# 2025-08-19 09:37:35 | Time series for point 317 extracted
# 2025-08-19 09:37:35 | Time series for point 318 extracted
# 2025-08-19 09:37:35 | Time series for point 319 extracted
# 2025-08-19 09:37:35 | Time series for point 320 extracted
# 2025-08-19 09:37:35 | Time series for point 322 extracted
# 2025-08-19 09:37:35 | Time series for point 323 extracted
# 2025-08-19 09:37:35 | Time series for point 324 extracted
# 2025-08-19 09:37:35 | Time series for point 325 extracted
# 2025-08-19 09:37:35 | Time series for point 326 extracted
# 2025-08-19 09:37:35 | Time series for point 327 extracted
# 2025-08-19 09:37:35 | Time series for point 328 extracted
# 2025-08-19 09:37:35 | Time series for point 329 extracted
# 2025-08-19 09:37:35 | Time series for point 330 extracted
# 2025-08-19 09:37:35 | Time series for point 331 extracted
# 2025-08-19 09:37:35 | Time series for point 332 extracted
# 2025-08-19 09:37:35 | Time series for point 333 extracted
# 2025-08-19 09:37:35 | Time series for point 334 extracted
# 2025-08-19 09:37:35 | Time series for point 335 extracted
# 2025-08-19 09:37:35 | Time series for point 336 extracted
# 2025-08-19 09:37:35 | Time series for point 337 extracted
# 2025-08-19 09:37:35 | Time series for point 338 extracted
# 2025-08-19 09:37:35 | Time series for point 339 extracted
# 2025-08-19 09:37:35 | Time series for point 340 extracted
# 2025-08-19 09:37:35 | Time series for point 341 extracted
# 2025-08-19 09:37:35 | Time series for point 342 extracted
# 2025-08-19 09:37:35 | Time series for point 343 extracted
# 2025-08-19 09:37:35 | Time series for point 344 extracted
# 2025-08-19 09:37:35 | Time series for point 345 extracted
# 2025-08-19 09:37:35 | Time series for point 346 extracted
# 2025-08-19 09:37:35 | Time series for point 347 extracted
# 2025-08-19 09:37:35 | Time series for point 348 extracted
# 2025-08-19 09:37:35 | Time series for point 349 extracted
# 2025-08-19 09:37:35 | Time series for point 350 extracted
# 2025-08-19 09:37:35 | Time series for point 351 extracted
# 2025-08-19 09:37:35 | Time series for point 352 extracted
# 2025-08-19 09:37:35 | Time series for point 353 extracted
# 2025-08-19 09:37:35 | Time series for point 354 extracted
# 2025-08-19 09:37:35 | Time series for point 355 extracted
# 2025-08-19 09:37:35 | Time series for point 356 extracted
# 2025-08-19 09:37:35 | Time series for point 357 extracted
# 2025-08-19 09:37:36 | Time series for point 358 extracted
# 2025-08-19 09:37:36 | Time series for point 359 extracted
# 2025-08-19 09:37:36 | Time series for point 360 extracted
# 2025-08-19 09:37:36 | Time series for point 361 extracted
# 2025-08-19 09:37:36 | Time series for point 362 extracted
# 2025-08-19 09:37:36 | Time series for point 363 extracted
# 2025-08-19 09:37:36 | Time series for point 365 extracted
# 2025-08-19 09:37:36 | Time series for point 366 extracted
# 2025-08-19 09:37:36 | Time series for point 367 extracted
# 2025-08-19 09:37:36 | Time series for point 368 extracted
# 2025-08-19 09:37:36 | Time series for point 369 extracted
# 2025-08-19 09:37:36 | Time series for point 370 extracted
# 2025-08-19 09:37:36 | Time series for point 371 extracted
# 2025-08-19 09:37:36 | Time series for point 373 extracted
# 2025-08-19 09:37:36 | Time series for point 374 extracted
# 2025-08-19 09:37:36 | Time series for point 376 extracted
# 2025-08-19 09:37:36 | Time series for point 377 extracted
# 2025-08-19 09:37:36 | Time series for point 378 extracted
# 2025-08-19 09:37:36 | Time series for point 379 extracted
# 2025-08-19 09:37:36 | Time series for point 380 extracted
# 2025-08-19 09:37:36 | Time series for point 381 extracted
# 2025-08-19 09:37:36 | Time series for point 382 extracted
# 2025-08-19 09:37:36 | Time series for point 383 extracted
# 2025-08-19 09:37:36 | Time series for point 384 extracted
# 2025-08-19 09:37:36 | Time series for point 385 extracted
# 2025-08-19 09:37:36 | Time series for point 386 extracted
# 2025-08-19 09:37:36 | Time series for point 387 extracted
# 2025-08-19 09:37:36 | Time series for point 388 extracted
# 2025-08-19 09:37:36 | Time series for point 389 extracted
# 2025-08-19 09:37:36 | Time series for point 390 extracted
# 2025-08-19 09:37:36 | Time series for point 391 extracted
# 2025-08-19 09:37:36 | Time series for point 392 extracted
# 2025-08-19 09:37:36 | Time series for point 393 extracted
# 2025-08-19 09:37:36 | Time series for point 394 extracted
# 2025-08-19 09:37:36 | Time series for point 395 extracted
# 2025-08-19 09:37:36 | Time series for point 396 extracted
# 2025-08-19 09:37:36 | Time series for point 397 extracted
# 2025-08-19 09:37:36 | Time series for point 398 extracted
# 2025-08-19 09:37:36 | Time series for point 399 extracted
# 2025-08-19 09:37:36 | Time series for point 400 extracted
# 2025-08-19 09:37:36 | Time series for point 401 extracted
# 2025-08-19 09:37:36 | Time series for point 402 extracted
# 2025-08-19 09:37:36 | Time series for point 403 extracted
# 2025-08-19 09:37:36 | Time series for point 404 extracted
# 2025-08-19 09:37:36 | Time series for point 405 extracted
# 2025-08-19 09:37:36 | Time series for point 406 extracted
# 2025-08-19 09:37:36 | Time series for point 407 extracted
# 2025-08-19 09:37:36 | Time series for point 408 extracted
# 2025-08-19 09:37:36 | Time series for point 409 extracted
# 2025-08-19 09:37:36 | Time series for point 410 extracted
# 2025-08-19 09:37:36 | Time series for point 411 extracted
# 2025-08-19 09:37:36 | Time series for point 412 extracted
# 2025-08-19 09:37:36 | Time series for point 413 extracted
# 2025-08-19 09:37:36 | Time series for point 415 extracted
# 2025-08-19 09:37:36 | Time series for point 416 extracted
# 2025-08-19 09:37:36 | Time series for point 417 extracted
# 2025-08-19 09:37:36 | Time series for point 418 extracted
# 2025-08-19 09:37:36 | Time series for point 419 extracted
# 2025-08-19 09:37:37 | Time series for point 420 extracted
# 2025-08-19 09:37:37 | Time series for point 422 extracted
# 2025-08-19 09:37:37 | Time series for point 423 extracted
# 2025-08-19 09:37:37 | Time series for point 426 extracted
# 2025-08-19 09:37:37 | Time series for point 427 extracted
# 2025-08-19 09:37:37 | Time series for point 428 extracted
# 2025-08-19 09:37:37 | Time series for point 432 extracted
# 2025-08-19 09:37:37 | Time series for point 435 extracted
# 2025-08-19 09:37:37 | Time series for point 437 extracted
# 2025-08-19 09:37:37 | Time series for point 440 extracted
# 2025-08-19 09:37:37 | Time series for point 441 extracted
# 2025-08-19 09:37:37 | Time series for point 446 extracted
# 2025-08-19 09:37:37 | Time series for point 447 extracted
# 2025-08-19 09:37:37 | Time series for point 448 extracted
# 2025-08-19 09:37:37 | Time series for point 449 extracted
# 2025-08-19 09:37:37 | Time series for point 451 extracted
# 2025-08-19 09:37:37 | Time series for point 452 extracted
# 2025-08-19 09:37:37 | Time series for point 453 extracted
# 2025-08-19 09:37:37 | Time series for point 459 extracted
# 2025-08-19 09:37:37 | Time series for point 461 extracted
# 2025-08-19 09:37:37 | Time series for point 463 extracted
# 2025-08-19 09:37:37 | Time series for point 467 extracted
# 2025-08-19 09:37:37 | Time series for point 470 extracted
# 2025-08-19 09:37:37 | Time series for point 472 extracted
# 2025-08-19 09:37:37 | Time series for point 475 extracted
# 2025-08-19 09:37:37 | Time series for point 477 extracted
# 2025-08-19 09:37:37 | Time series for point 479 extracted
# 2025-08-19 09:37:37 | Time series for point 480 extracted
# 2025-08-19 09:37:37 | Time series for point 481 extracted
# 2025-08-19 09:37:37 | Time series for point 482 extracted
# 2025-08-19 09:37:37 | Time series for point 485 extracted
# 2025-08-19 09:37:37 | Time series for point 487 extracted
# 2025-08-19 09:37:37 | Time series for point 489 extracted
# 2025-08-19 09:37:37 | Time series for point 490 extracted
# 2025-08-19 09:37:37 | Time series for point 491 extracted
# 2025-08-19 09:37:37 | Time series for point 492 extracted
# 2025-08-19 09:37:37 | Time series for point 493 extracted
# 2025-08-19 09:37:37 | Time series for point 495 extracted
# 2025-08-19 09:37:37 | Time series for point 505 extracted
# 2025-08-19 09:37:37 | Time series for point 507 extracted
# 2025-08-19 09:37:37 | Time series for point 512 extracted
# 2025-08-19 09:37:37 | Time series for point 513 extracted
# 2025-08-19 09:37:37 | Time series for point 514 extracted
# 2025-08-19 09:37:37 | Time series for point 519 extracted
# 2025-08-19 09:37:37 | Time series for point 522 extracted
# 2025-08-19 09:37:37 | Time series for point 523 extracted
# 2025-08-19 09:37:37 | Time series for point 529 extracted
# 2025-08-19 09:37:37 | Time series for point 530 extracted
# 2025-08-19 09:37:37 | Time series for point 534 extracted
# 2025-08-19 09:37:37 | Time series for point 535 extracted
# 2025-08-19 09:37:37 | Time series for point 540 extracted
# 2025-08-19 09:37:37 | Time series for point 548 extracted
# 2025-08-19 09:37:37 | Time series for point 549 extracted
# 2025-08-19 09:37:37 | Time series for point 556 extracted
# 2025-08-19 09:37:37 | Time series for point 557 extracted
# 2025-08-19 09:37:37 | Time series for point 562 extracted
# 2025-08-19 09:37:37 | Time series for point 568 extracted
# 2025-08-19 09:37:37 | Time series for point 570 extracted
# 2025-08-19 09:37:37 | Time series for point 571 extracted
# 2025-08-19 09:37:37 | Time series for point 578 extracted
# 2025-08-19 09:37:37 | Time series for point 579 extracted
# 2025-08-19 09:37:37 | Time series for point 580 extracted
# 2025-08-19 09:37:37 | Time series for point 582 extracted
# 2025-08-19 09:37:37 | Time series for point 584 extracted
# 2025-08-19 09:37:37 | Time series for point 591 extracted
# 2025-08-19 09:37:37 | Time series for point 592 extracted
# 2025-08-19 09:37:37 | Time series for point 595 extracted
# 2025-08-19 09:37:37 | Time series for point 602 extracted
# 2025-08-19 09:37:37 | Time series for point 606 extracted
# 2025-08-19 09:37:37 | Time series for point 607 extracted
# 2025-08-19 09:37:37 | Time series for point 613 extracted
# 2025-08-19 09:37:37 | Time series for point 614 extracted
# 2025-08-19 09:37:37 | Time series for point 627 extracted
# 2025-08-19 09:37:37 | Time series for point 633 extracted
# 2025-08-19 09:37:37 | Time series for point 636 extracted
# 2025-08-19 09:37:37 | Time series for point 645 extracted
# 2025-08-19 09:37:37 | Time series for point 649 extracted
# 2025-08-19 09:37:37 | Time series for point 651 extracted
# 2025-08-19 09:37:37 | Time series for point 652 extracted
# 2025-08-19 09:37:37 | Time series for point 669 extracted
# 2025-08-19 09:37:37 | Time series for point 672 extracted
# 2025-08-19 09:37:37 | Time series for point 681 extracted
# 2025-08-19 09:37:37 | Time series for point 683 extracted
# 2025-08-19 09:37:37 | Time series for point 694 extracted
# 2025-08-19 09:37:37 | Time series for point 696 extracted
# 2025-08-19 09:37:37 | Time series for point 699 extracted
# 2025-08-19 09:37:37 | Time series for point 700 extracted
# 2025-08-19 09:37:37 | Time series for point 707 extracted
# 2025-08-19 09:37:37 | Time series for point 709 extracted
# 2025-08-19 09:37:37 | Time series for point 713 extracted
# 2025-08-19 09:37:37 | Time series for point 716 extracted
# 2025-08-19 09:37:37 | Time series for point 717 extracted
# 2025-08-19 09:37:37 | Time series for point 720 extracted
# 2025-08-19 09:37:37 | Time series for point 721 extracted
# 2025-08-19 09:37:37 | Time series for point 724 extracted
# 2025-08-19 09:37:37 | Time series for point 727 extracted
# 2025-08-19 09:37:37 | Time series for point 730 extracted
# 2025-08-19 09:37:37 | Time series for point 731 extracted
# 2025-08-19 09:37:37 | Time series for point 733 extracted
# 2025-08-19 09:37:37 | Time series for point 734 extracted
# 2025-08-19 09:37:37 | Time series for point 737 extracted
# 2025-08-19 09:37:37 | Time series for point 740 extracted
# 2025-08-19 09:37:37 | Time series for point 743 extracted
# 2025-08-19 09:37:37 | Time series for point 744 extracted
# 2025-08-19 09:37:37 | Time series for point 747 extracted
# 2025-08-19 09:37:37 | Time series for point 749 extracted
# 2025-08-19 09:37:37 | Time series for point 756 extracted
# 2025-08-19 09:37:38 | Time series for point 757 extracted
# 2025-08-19 09:37:38 | Time series for point 758 extracted
# 2025-08-19 09:37:38 | Time series for point 759 extracted
# 2025-08-19 09:37:38 | Time series for point 760 extracted
# 2025-08-19 09:37:38 | Time series for point 763 extracted
# 2025-08-19 09:37:38 | Time series for point 764 extracted
# 2025-08-19 09:37:38 | Time series for point 769 extracted
# 2025-08-19 09:37:38 | Time series for point 770 extracted
# 2025-08-19 09:37:38 | Time series for point 771 extracted
# 2025-08-19 09:37:38 | Time series for point 772 extracted
# 2025-08-19 09:37:38 | Time series for point 775 extracted
# 2025-08-19 09:37:38 | Time series for point 783 extracted
# 2025-08-19 09:37:38 | Time series for point 785 extracted
# 2025-08-19 09:37:38 | Time series for point 786 extracted
# 2025-08-19 09:37:38 | Time series for point 788 extracted
# 2025-08-19 09:37:38 | Time series for point 790 extracted
# 2025-08-19 09:37:38 | Time series for point 791 extracted
# 2025-08-19 09:37:38 | Time series for point 793 extracted
# 2025-08-19 09:37:38 | Time series for point 794 extracted
# 2025-08-19 09:37:38 | Time series for point 795 extracted
# 2025-08-19 09:37:38 | Time series for point 796 extracted
# 2025-08-19 09:37:38 | Time series for point 797 extracted
# 2025-08-19 09:37:38 | Time series for point 798 extracted
# 2025-08-19 09:37:38 | Time series for point 800 extracted
# 2025-08-19 09:37:38 | Time series for point 801 extracted
# 2025-08-19 09:37:38 | Time series for point 803 extracted
# 2025-08-19 09:37:38 | Time series for point 804 extracted
# 2025-08-19 09:37:38 | Time series for point 805 extracted
# 2025-08-19 09:37:38 | Time series for point 806 extracted
# 2025-08-19 09:37:38 | Time series for point 809 extracted
# 2025-08-19 09:37:38 | Time series for point 811 extracted
# 2025-08-19 09:37:38 | Time series for point 812 extracted
# 2025-08-19 09:37:38 | Time series for point 813 extracted
# 2025-08-19 09:37:38 | Time series for point 814 extracted
# 2025-08-19 09:37:38 | Time series for point 815 extracted
# 2025-08-19 09:37:38 | Time series for point 816 extracted
# 2025-08-19 09:37:38 | Time series for point 821 extracted
# 2025-08-19 09:37:38 | Time series for point 822 extracted
# 2025-08-19 09:37:38 | Time series for point 824 extracted
# 2025-08-19 09:37:38 | Time series for point 826 extracted
# 2025-08-19 09:37:38 | Time series for point 827 extracted
# 2025-08-19 09:37:38 | Time series for point 828 extracted
# 2025-08-19 09:37:38 | Time series for point 829 extracted
# 2025-08-19 09:37:38 | Time series for point 830 extracted
# 2025-08-19 09:37:38 | Time series for point 831 extracted
# 2025-08-19 09:37:38 | Time series for point 832 extracted
# 2025-08-19 09:37:38 | Time series for point 833 extracted
# 2025-08-19 09:37:38 | Time series for point 834 extracted
# 2025-08-19 09:37:38 | Time series for point 835 extracted
# 2025-08-19 09:37:38 | Time series for point 837 extracted
# 2025-08-19 09:37:38 | Time series for point 838 extracted
# 2025-08-19 09:37:38 | Time series for point 839 extracted
# 2025-08-19 09:37:38 | Time series for point 841 extracted
# 2025-08-19 09:37:38 | Time series for point 842 extracted
# 2025-08-19 09:37:38 | Time series for point 843 extracted
# 2025-08-19 09:37:38 | Time series for point 844 extracted
# 2025-08-19 09:37:38 | Time series for point 845 extracted
# 2025-08-19 09:37:38 | Time series for point 846 extracted
# 2025-08-19 09:37:38 | Time series for point 847 extracted
# 2025-08-19 09:37:38 | Time series for point 848 extracted
# 2025-08-19 09:37:38 | Time series for point 849 extracted
# 2025-08-19 09:37:38 | Time series for point 850 extracted
# 2025-08-19 09:37:38 | Time series for point 851 extracted
# 2025-08-19 09:37:38 | Time series for point 852 extracted
# 2025-08-19 09:37:38 | Time series for point 853 extracted
# 2025-08-19 09:37:38 | Time series for point 854 extracted
# 2025-08-19 09:37:38 | Time series for point 855 extracted
# 2025-08-19 09:37:38 | Time series for point 856 extracted
# 2025-08-19 09:37:38 | Time series for point 857 extracted
# 2025-08-19 09:37:38 | Time series for point 858 extracted
# 2025-08-19 09:37:38 | Time series for point 859 extracted
# 2025-08-19 09:37:38 | Time series for point 861 extracted
# 2025-08-19 09:37:38 | Time series for point 862 extracted
# 2025-08-19 09:37:38 | Time series for point 863 extracted
# 2025-08-19 09:37:38 | Time series for point 864 extracted
# 2025-08-19 09:37:38 | Time series for point 867 extracted
# 2025-08-19 09:37:38 | Time series for point 870 extracted
# 2025-08-19 09:37:38 | Time series for point 871 extracted
# 2025-08-19 09:37:38 | Time series for point 872 extracted
# 2025-08-19 09:37:38 | Time series for point 873 extracted
# 2025-08-19 09:37:38 | Time series for point 874 extracted
# 2025-08-19 09:37:38 | Time series for point 875 extracted
# 2025-08-19 09:37:38 | Time series for point 876 extracted
# 2025-08-19 09:37:38 | Time series for point 877 extracted
# 2025-08-19 09:37:38 | Time series for point 878 extracted
# 2025-08-19 09:37:38 | Time series for point 879 extracted
# 2025-08-19 09:37:38 | Time series for point 880 extracted
# 2025-08-19 09:37:38 | Time series for point 882 extracted
# 2025-08-19 09:37:38 | Time series for point 883 extracted
# 2025-08-19 09:37:38 | Time series for point 885 extracted
# 2025-08-19 09:37:38 | Time series for point 887 extracted
# 2025-08-19 09:37:38 | Time series for point 889 extracted
# 2025-08-19 09:37:38 | Time series for point 890 extracted
# 2025-08-19 09:37:38 | Time series for point 891 extracted
# 2025-08-19 09:37:38 | Time series for point 892 extracted
# 2025-08-19 09:37:38 | Time series for point 893 extracted
# 2025-08-19 09:37:38 | Time series for point 894 extracted
# 2025-08-19 09:37:38 | Time series for point 895 extracted
# 2025-08-19 09:37:38 | Time series for point 896 extracted
# 2025-08-19 09:37:38 | Time series for point 897 extracted
# 2025-08-19 09:37:38 | Time series for point 900 extracted
# 2025-08-19 09:37:38 | Time series for point 902 extracted
# 2025-08-19 09:37:38 | Time series for point 903 extracted
# 2025-08-19 09:37:38 | Time series for point 905 extracted
# 2025-08-19 09:37:38 | Time series for point 906 extracted
# 2025-08-19 09:37:38 | Time series for point 908 extracted
# 2025-08-19 09:37:38 | Time series for point 909 extracted
# 2025-08-19 09:37:38 | Time series for point 911 extracted
# 2025-08-19 09:37:38 | Time series for point 912 extracted
# 2025-08-19 09:37:38 | Time series for point 913 extracted
# 2025-08-19 09:37:38 | Time series for point 914 extracted
# 2025-08-19 09:37:38 | Time series for point 916 extracted
# 2025-08-19 09:37:38 | Time series for point 919 extracted
# 2025-08-19 09:37:38 | Time series for point 922 extracted
# 2025-08-19 09:37:38 | Time series for point 923 extracted
# 2025-08-19 09:37:38 | Time series for point 924 extracted
# 2025-08-19 09:37:38 | Time series for point 925 extracted
# 2025-08-19 09:37:38 | Time series for point 927 extracted
# 2025-08-19 09:37:38 | Time series for point 932 extracted
# 2025-08-19 09:37:38 | Time series for point 935 extracted
# 2025-08-19 09:37:38 | Time series for point 938 extracted
# 2025-08-19 09:37:38 | Time series for point 939 extracted
# 2025-08-19 09:37:38 | Time series for point 940 extracted
# 2025-08-19 09:37:38 | Time series for point 941 extracted
# 2025-08-19 09:37:38 | Time series for point 942 extracted
# 2025-08-19 09:37:38 | Time series for point 943 extracted
# 2025-08-19 09:37:38 | Time series for point 944 extracted
# 2025-08-19 09:37:38 | Time series for point 945 extracted
# 2025-08-19 09:37:38 | Time series for point 947 extracted
# 2025-08-19 09:37:38 | Time series for point 948 extracted
# 2025-08-19 09:37:38 | Time series for point 949 extracted
# 2025-08-19 09:37:38 | Time series for point 951 extracted
# 2025-08-19 09:37:38 | Time series for point 954 extracted
# 2025-08-19 09:37:38 | Time series for point 955 extracted
# 2025-08-19 09:37:38 | Time series for point 956 extracted
# 2025-08-19 09:37:38 | Time series for point 957 extracted
# 2025-08-19 09:37:38 | Time series for point 958 extracted
# 2025-08-19 09:37:38 | Time series for point 959 extracted
# 2025-08-19 09:37:38 | Time series for point 960 extracted
# 2025-08-19 09:37:38 | Time series for point 961 extracted
# 2025-08-19 09:37:38 | Time series for point 962 extracted
# 2025-08-19 09:37:38 | Time series for point 966 extracted
# 2025-08-19 09:37:38 | Time series for point 967 extracted
# 2025-08-19 09:37:38 | Time series for point 968 extracted
# 2025-08-19 09:37:38 | Time series for point 969 extracted
# 2025-08-19 09:37:38 | Time series for point 971 extracted
# 2025-08-19 09:37:38 | Time series for point 974 extracted
# 2025-08-19 09:37:38 | Time series for point 975 extracted
# 2025-08-19 09:37:38 | Time series for point 976 extracted
# 2025-08-19 09:37:38 | Time series for point 977 extracted
# 2025-08-19 09:37:38 | Time series for point 978 extracted
# 2025-08-19 09:37:38 | Time series for point 979 extracted
# 2025-08-19 09:37:38 | Time series for point 980 extracted
# 2025-08-19 09:37:39 | Time series for point 981 extracted
# 2025-08-19 09:37:39 | Time series for point 982 extracted
# 2025-08-19 09:37:39 | Time series for point 983 extracted
# 2025-08-19 09:37:39 | Time series for point 984 extracted
# 2025-08-19 09:37:39 | Time series for point 986 extracted
# 2025-08-19 09:37:39 | Time series for point 988 extracted
# 2025-08-19 09:37:39 | Time series for point 989 extracted
# 2025-08-19 09:37:39 | Time series for point 991 extracted
# 2025-08-19 09:37:39 | Time series for point 992 extracted
# 2025-08-19 09:37:39 | Time series for point 993 extracted
# 2025-08-19 09:37:39 | Time series for point 994 extracted
# 2025-08-19 09:37:39 | Time series for point 995 extracted
# 2025-08-19 09:37:39 | Time series for point 997 extracted
# 2025-08-19 09:37:39 | Time series for point 998 extracted
# 2025-08-19 09:37:39 | Time series for point 999 extracted
# 2025-08-19 09:37:39 | Time series for point 1004 extracted
# 2025-08-19 09:37:39 | Time series for point 1006 extracted
# 2025-08-19 09:37:39 | Time series for point 1007 extracted
# 2025-08-19 09:37:39 | Time series for point 1008 extracted
# 2025-08-19 09:37:39 | Time series for point 1010 extracted
# 2025-08-19 09:37:39 | Time series for point 1012 extracted
# 2025-08-19 09:37:39 | Time series for point 1013 extracted
# 2025-08-19 09:37:39 | Time series for point 1014 extracted
# 2025-08-19 09:37:39 | Time series for point 1015 extracted
# 2025-08-19 09:37:39 | Time series for point 1016 extracted
# 2025-08-19 09:37:39 | Time series for point 1017 extracted
# 2025-08-19 09:37:39 | Time series for point 1019 extracted
# 2025-08-19 09:37:39 | Time series for point 1020 extracted
# 2025-08-19 09:37:39 | Time series for point 1021 extracted
# 2025-08-19 09:37:39 | Time series for point 1022 extracted
# 2025-08-19 09:37:39 | Time series for point 1024 extracted
# 2025-08-19 09:37:39 | Time series for point 1025 extracted
# 2025-08-19 09:37:39 | Time series for point 1027 extracted
# 2025-08-19 09:37:39 | Time series for point 1028 extracted
# 2025-08-19 09:37:39 | Time series for point 1029 extracted
# 2025-08-19 09:37:39 | Time series for point 1031 extracted
# 2025-08-19 09:37:39 | Time series for point 1032 extracted
# 2025-08-19 09:37:39 | Time series for point 1034 extracted
# 2025-08-19 09:37:39 | Time series for point 1035 extracted
# 2025-08-19 09:37:39 | Time series for point 1038 extracted
# 2025-08-19 09:37:39 | Time series for point 1041 extracted
# 2025-08-19 09:37:39 | Time series for point 1042 extracted
# 2025-08-19 09:37:39 | Time series for point 1043 extracted
# 2025-08-19 09:37:39 | Time series for point 1044 extracted
# 2025-08-19 09:37:39 | Time series for point 1045 extracted
# 2025-08-19 09:37:39 | Time series for point 1048 extracted
# 2025-08-19 09:37:39 | Time series for point 1051 extracted
# 2025-08-19 09:37:39 | Time series for point 1052 extracted
# 2025-08-19 09:37:39 | Time series for point 1053 extracted
# 2025-08-19 09:37:39 | Time series for point 1055 extracted
# 2025-08-19 09:37:39 | Time series for point 1057 extracted
# 2025-08-19 09:37:39 | Time series for point 1058 extracted
# 2025-08-19 09:37:39 | Time series for point 1060 extracted
# 2025-08-19 09:37:39 | Time series for point 1062 extracted
# 2025-08-19 09:37:39 | Time series for point 1063 extracted
# 2025-08-19 09:37:39 | Time series for point 1064 extracted
# 2025-08-19 09:37:39 | Time series for point 1065 extracted
# 2025-08-19 09:37:39 | Time series for point 1066 extracted
# 2025-08-19 09:37:39 | Time series for point 1067 extracted
# 2025-08-19 09:37:39 | Time series for point 1068 extracted
# 2025-08-19 09:37:39 | Time series for point 1069 extracted
# 2025-08-19 09:37:39 | Time series for point 1070 extracted
# 2025-08-19 09:37:39 | Time series for point 1071 extracted
# 2025-08-19 09:37:39 | Time series for point 1072 extracted
# 2025-08-19 09:37:39 | Time series for point 1073 extracted
# 2025-08-19 09:37:39 | Time series for point 1074 extracted
# 2025-08-19 09:37:39 | Time series for point 1077 extracted
# 2025-08-19 09:37:39 | Time series for point 1078 extracted
# 2025-08-19 09:37:39 | Time series for point 1079 extracted
# 2025-08-19 09:37:39 | Time series for point 1081 extracted
# 2025-08-19 09:37:39 | Time series for point 1084 extracted
# 2025-08-19 09:37:39 | Time series for point 1085 extracted
# 2025-08-19 09:37:39 | Time series for point 1086 extracted
# 2025-08-19 09:37:39 | Time series for point 1088 extracted
# 2025-08-19 09:37:39 | Time series for point 1089 extracted
# 2025-08-19 09:37:39 | Time series for point 1090 extracted
# 2025-08-19 09:37:39 | Time series for point 1091 extracted
# 2025-08-19 09:37:39 | Time series for point 1092 extracted
# 2025-08-19 09:37:39 | Time series for point 1093 extracted
# 2025-08-19 09:37:39 | Time series for point 1094 extracted
# 2025-08-19 09:37:39 | Time series for point 1095 extracted
# 2025-08-19 09:37:39 | Time series for point 1096 extracted
# 2025-08-19 09:37:39 | Time series for point 1097 extracted
# 2025-08-19 09:37:39 | Time series for point 1098 extracted
# 2025-08-19 09:37:40 | Time series for point 1099 extracted
# 2025-08-19 09:37:40 | Time series for point 1100 extracted
# 2025-08-19 09:37:40 | Time series for point 1101 extracted
# 2025-08-19 09:37:40 | Time series for point 1106 extracted
# 2025-08-19 09:37:40 | Time series for point 1107 extracted
# 2025-08-19 09:37:40 | Time series for point 1108 extracted
# 2025-08-19 09:37:40 | Time series for point 1111 extracted
# 2025-08-19 09:37:40 | Time series for point 1113 extracted
# 2025-08-19 09:37:40 | Time series for point 1115 extracted
# 2025-08-19 09:37:40 | Time series for point 1116 extracted
# 2025-08-19 09:37:40 | Time series for point 1118 extracted
# 2025-08-19 09:37:40 | Time series for point 1119 extracted
# 2025-08-19 09:37:40 | Time series for point 1120 extracted
# 2025-08-19 09:37:40 | Time series for point 1121 extracted
# 2025-08-19 09:37:40 | Time series for point 1122 extracted
# 2025-08-19 09:37:40 | Time series for point 1123 extracted
# 2025-08-19 09:37:40 | Time series for point 1124 extracted
# 2025-08-19 09:37:40 | Time series for point 1125 extracted
# 2025-08-19 09:37:40 | Time series for point 1126 extracted
# 2025-08-19 09:37:40 | Time series for point 1127 extracted
# 2025-08-19 09:37:40 | Time series for point 1128 extracted
# 2025-08-19 09:37:40 | Time series for point 1130 extracted
# 2025-08-19 09:37:40 | Time series for point 1131 extracted
# 2025-08-19 09:37:40 | Time series for point 1133 extracted
# 2025-08-19 09:37:40 | Time series for point 1134 extracted
# 2025-08-19 09:37:40 | Time series for point 1135 extracted
# 2025-08-19 09:37:40 | Time series for point 1136 extracted
# 2025-08-19 09:37:40 | Time series for point 1137 extracted
# 2025-08-19 09:37:40 | Time series for point 1138 extracted
# 2025-08-19 09:37:40 | Time series for point 1139 extracted
# 2025-08-19 09:37:40 | Time series for point 1140 extracted
# 2025-08-19 09:37:40 | Time series for point 1141 extracted
# 2025-08-19 09:37:40 | Time series for point 1142 extracted
# 2025-08-19 09:37:40 | Time series for point 1143 extracted
# 2025-08-19 09:37:40 | Time series for point 1145 extracted
# 2025-08-19 09:37:40 | Time series for point 1147 extracted
# 2025-08-19 09:37:40 | Time series for point 1148 extracted
# 2025-08-19 09:37:40 | Time series for point 1152 extracted
# 2025-08-19 09:37:40 | Time series for point 1154 extracted
# 2025-08-19 09:37:40 | Time series for point 1157 extracted
# 2025-08-19 09:37:40 | Time series for point 1159 extracted
# 2025-08-19 09:37:40 | Time series for point 1161 extracted
# 2025-08-19 09:37:40 | Time series for point 1162 extracted
# 2025-08-19 09:37:40 | Time series for point 1165 extracted
# 2025-08-19 09:37:40 | Time series for point 1166 extracted
# 2025-08-19 09:37:40 | Time series for point 1167 extracted
# 2025-08-19 09:37:40 | Time series for point 1169 extracted
# 2025-08-19 09:37:40 | Time series for point 1170 extracted
# 2025-08-19 09:37:40 | Time series for point 1173 extracted
# 2025-08-19 09:37:40 | Time series for point 1174 extracted
# 2025-08-19 09:37:40 | Time series for point 1175 extracted
# 2025-08-19 09:37:40 | Time series for point 1176 extracted
# 2025-08-19 09:37:40 | Time series for point 1177 extracted
# 2025-08-19 09:37:40 | Time series for point 1178 extracted
# 2025-08-19 09:37:40 | Time series for point 1179 extracted
# 2025-08-19 09:37:40 | Time series for point 1181 extracted
# 2025-08-19 09:37:40 | Time series for point 1184 extracted
# 2025-08-19 09:37:40 | Time series for point 1186 extracted
# 2025-08-19 09:37:40 | Time series for point 1187 extracted
# 2025-08-19 09:37:40 | Time series for point 1189 extracted
# 2025-08-19 09:37:40 | Time series for point 1192 extracted
# 2025-08-19 09:37:40 | Time series for point 1193 extracted
# 2025-08-19 09:37:40 | Time series for point 1194 extracted
# 2025-08-19 09:37:40 | Time series for point 1195 extracted
# 2025-08-19 09:37:40 | Time series for point 1196 extracted
# 2025-08-19 09:37:40 | Time series for point 1197 extracted
# 2025-08-19 09:37:40 | Time series for point 1198 extracted
# 2025-08-19 09:37:40 | Time series for point 1199 extracted
# 2025-08-19 09:37:40 | Time series for point 1200 extracted
# 2025-08-19 09:37:40 | Time series for point 1201 extracted
# 2025-08-19 09:37:41 | Time series for point 1202 extracted
# 2025-08-19 09:37:41 | Time series for point 1203 extracted
# 2025-08-19 09:37:41 | Time series for point 1206 extracted
# 2025-08-19 09:37:41 | Time series for point 1207 extracted
# ...
# 2025-08-19 09:37:46 | Time series for point 4532 extracted
# 2025-08-19 09:37:46 | Time series for point 4536 extracted
# 2025-08-19 09:37:46 | Time series for point 4544 extracted
# 2025-08-19 09:37:46 | Time series for point 4566 extracted
# 2025-08-19 09:37:46 | Time series for point 4605 extracted
# 2025-08-19 09:37:46 | Time series for point 4611 extracted
# 2025-08-19 09:37:46 | Time series for point 4612 extracted
# 2025-08-19 09:37:46 | Time series for point 4616 extracted
# 2025-08-19 09:37:46 | Time series for point 4638 extracted
# 2025-08-19 09:37:46 | Time series for point 4651 extracted
# 2025-08-19 09:37:46 | Time series for point 4676 extracted
# 2025-08-19 09:37:46 | Time series for point 4677 extracted
# 2025-08-19 09:37:46 | Time series for point 4706 extracted
# 2025-08-19 09:37:46 | Time series for point 4741 extracted
# 2025-08-19 09:37:46 | Time series for point 4797 extracted
# 2025-08-19 09:37:46 | Time series for point 4856 extracted
# 2025-08-19 09:37:46 | Time series for point 4892 extracted
# 2025-08-19 09:37:46 | Time series for point 4893 extracted
# 2025-08-19 09:37:46 | Time series for point 4941 extracted
# 2025-08-19 09:37:46 | Time series for point 4952 extracted
# 2025-08-19 09:37:46 | Time series for point 4984 extracted
# 2025-08-19 09:37:46 | Time series for point 5057 extracted
# 2025-08-19 09:37:46 | Time series for point 5079 extracted
# 2025-08-19 09:37:46 | Time series for point 5109 extracted
# 2025-08-19 09:37:46 | Time series for point 5117 extracted
# 2025-08-19 09:37:46 | Time series for point 5235 extracted
# 2025-08-19 09:37:46 | Time series for point 5364 extracted
# 2025-08-19 09:37:46 | Time series for point 5418 extracted
# 2025-08-19 09:37:46 | Time series for point 5496 extracted
# 2025-08-19 09:37:46 | Time series for point 6855 extracted
# 2025-08-19 09:37:46 | Time series for point 6856 extracted
# 2025-08-19 09:37:46 | Time series for point 6859 extracted
# 2025-08-19 09:37:46 | Time series for point 6865 extracted
# 2025-08-19 09:37:46 | Time series for point 6866 extracted
# 2025-08-19 09:37:46 | Time series for point 6867 extracted
# 2025-08-19 09:37:46 | Time series for point 6869 extracted
# 2025-08-19 09:37:46 | Time series for point 6872 extracted
# 2025-08-19 09:37:46 | Time series for point 6874 extracted
# 2025-08-19 09:37:46 | Time series for point 6876 extracted
# 2025-08-19 09:37:46 | Time series for point 6877 extracted
# 2025-08-19 09:37:46 | Time series for point 6878 extracted
# 2025-08-19 09:37:46 | Time series for point 6879 extracted
# 2025-08-19 09:37:46 | Time series for point 6880 extracted
# 2025-08-19 09:37:46 | Time series for point 6881 extracted
# 2025-08-19 09:37:46 | Time series for point 6882 extracted
# 2025-08-19 09:37:46 | Time series for point 6883 extracted
# 2025-08-19 09:37:46 | Time series for point 6886 extracted
# 2025-08-19 09:37:46 | Time series for point 6888 extracted
# 2025-08-19 09:37:46 | Time series for point 6889 extracted
# 2025-08-19 09:37:46 | Time series for point 6891 extracted
# 2025-08-19 09:37:46 | Time series for point 6893 extracted
# 2025-08-19 09:37:46 | Time series for point 6895 extracted
# 2025-08-19 09:37:46 | Time series for point 6898 extracted
# 2025-08-19 09:37:46 | Time series for point 6899 extracted
# 2025-08-19 09:37:46 | Time series for point 6900 extracted
# 2025-08-19 09:37:46 | Time series for point 6901 extracted
# 2025-08-19 09:37:46 | Time series for point 6903 extracted
# 2025-08-19 09:37:46 | Time series for point 6904 extracted
# 2025-08-19 09:37:46 | Time series for point 6905 extracted
# 2025-08-19 09:37:46 | Time series for point 6906 extracted
# 2025-08-19 09:37:46 | Time series for point 6907 extracted
# 2025-08-19 09:37:46 | Time series for point 6908 extracted
# 2025-08-19 09:37:46 | Time series for point 6909 extracted
# 2025-08-19 09:37:46 | Time series for point 6910 extracted
# 2025-08-19 09:37:46 | Time series for point 6911 extracted
# 2025-08-19 09:37:46 | Time series for point 6913 extracted
# 2025-08-19 09:37:46 | Time series for point 6914 extracted
# 2025-08-19 09:37:46 | Time series for point 6916 extracted
# 2025-08-19 09:37:46 | Time series for point 6921 extracted
# 2025-08-19 09:37:46 | Time series for point 6923 extracted
# 2025-08-19 09:37:46 | Time series for point 6925 extracted
# 2025-08-19 09:37:46 | Time series for point 6926 extracted
# 2025-08-19 09:37:46 | Time series for point 6928 extracted
# 2025-08-19 09:37:46 | Time series for point 6931 extracted
# 2025-08-19 09:37:46 | Time series for point 6932 extracted
# 2025-08-19 09:37:46 | Time series for point 6936 extracted
# 2025-08-19 09:37:46 | Time series for point 6937 extracted
# 2025-08-19 09:37:46 | Time series for point 6940 extracted
# 2025-08-19 09:37:46 | Time series for point 6943 extracted
# 2025-08-19 09:37:46 | Time series for point 6944 extracted
# 2025-08-19 09:37:46 | Time series for point 6947 extracted
# 2025-08-19 09:37:46 | Time series for point 6951 extracted
# 2025-08-19 09:37:46 | Time series for point 6954 extracted
# 2025-08-19 09:37:46 | Time series for point 6957 extracted
# 2025-08-19 09:37:46 | Time series for point 6959 extracted
# 2025-08-19 09:37:46 | Time series for point 6961 extracted
# 2025-08-19 09:37:46 | Time series for point 6963 extracted
# 2025-08-19 09:37:46 | Time series for point 6966 extracted
# 2025-08-19 09:37:46 | Time series for point 6967 extracted
# 2025-08-19 09:37:46 | Time series for point 6968 extracted
# 2025-08-19 09:37:46 | Time series for point 6970 extracted
# 2025-08-19 09:37:46 | Time series for point 6971 extracted
# 2025-08-19 09:37:46 | Time series for point 6973 extracted
# 2025-08-19 09:37:46 | Time series for point 6974 extracted
# 2025-08-19 09:37:46 | Time series for point 6976 extracted
# 2025-08-19 09:37:46 | Time series for point 6979 extracted
# 2025-08-19 09:37:46 | Time series for point 6980 extracted
# 2025-08-19 09:37:46 | Time series for point 6981 extracted
# 2025-08-19 09:37:47 | Time series for point 6983 extracted
# 2025-08-19 09:37:47 | Time series for point 6984 extracted
# 2025-08-19 09:37:47 | Time series for point 6988 extracted
# 2025-08-19 09:37:47 | Time series for point 6989 extracted
# 2025-08-19 09:37:47 | Time series for point 6990 extracted
# 2025-08-19 09:37:47 | Time series for point 6991 extracted
# 2025-08-19 09:37:47 | Time series for point 6992 extracted
# 2025-08-19 09:37:47 | Time series for point 6993 extracted
# 2025-08-19 09:37:47 | Time series for point 6994 extracted
# 2025-08-19 09:37:47 | Time series for point 6997 extracted
# 2025-08-19 09:37:47 | Time series for point 6998 extracted
# 2025-08-19 09:37:47 | Time series for point 6999 extracted
# 2025-08-19 09:37:47 | Time series for point 7001 extracted
# 2025-08-19 09:37:47 | Time series for point 7003 extracted
# 2025-08-19 09:37:47 | Time series for point 7008 extracted
# 2025-08-19 09:37:47 | Time series for point 7009 extracted
# 2025-08-19 09:37:47 | Time series for point 7010 extracted
# 2025-08-19 09:37:47 | Time series for point 7013 extracted
# 2025-08-19 09:37:47 | Time series for point 7016 extracted
# 2025-08-19 09:37:47 | Time series for point 7017 extracted
# 2025-08-19 09:37:47 | Time series for point 7019 extracted
# 2025-08-19 09:37:47 | Time series for point 7020 extracted
# 2025-08-19 09:37:47 | Time series for point 7022 extracted
# 2025-08-19 09:37:47 | Time series for point 7023 extracted
# 2025-08-19 09:37:47 | Time series for point 7025 extracted
# 2025-08-19 09:37:47 | Time series for point 7026 extracted
# 2025-08-19 09:37:47 | Time series for point 7027 extracted
# 2025-08-19 09:37:47 | Time series for point 7028 extracted
# 2025-08-19 09:37:47 | Time series for point 7029 extracted
# 2025-08-19 09:37:47 | Time series for point 7030 extracted
# 2025-08-19 09:37:47 | Time series for point 7031 extracted
# 2025-08-19 09:37:47 | Time series for point 7032 extracted
# 2025-08-19 09:37:47 | Time series for point 7034 extracted
# 2025-08-19 09:37:47 | Time series for point 7035 extracted
# 2025-08-19 09:37:47 | Time series for point 7036 extracted
# 2025-08-19 09:37:47 | Time series for point 7038 extracted
# 2025-08-19 09:37:47 | Time series for point 7039 extracted
# 2025-08-19 09:37:47 | Time series for point 7044 extracted
# 2025-08-19 09:37:47 | Time series for point 7045 extracted
# 2025-08-19 09:37:47 | Time series for point 7047 extracted
# 2025-08-19 09:37:47 | Time series for point 7049 extracted
# 2025-08-19 09:37:47 | Time series for point 7051 extracted
# 2025-08-19 09:37:47 | Time series for point 7052 extracted
# 2025-08-19 09:37:47 | Time series for point 7055 extracted
# 2025-08-19 09:37:47 | Time series for point 7056 extracted
# 2025-08-19 09:37:47 | Time series for point 7059 extracted
# 2025-08-19 09:37:47 | Time series for point 7060 extracted
# 2025-08-19 09:37:47 | Time series for point 7062 extracted
# 2025-08-19 09:37:47 | Time series for point 7063 extracted
# 2025-08-19 09:37:47 | Time series for point 7064 extracted
# 2025-08-19 09:37:47 | Time series for point 7066 extracted
# 2025-08-19 09:37:47 | Time series for point 7067 extracted
# 2025-08-19 09:37:47 | Time series for point 7069 extracted
# 2025-08-19 09:37:47 | Time series for point 7070 extracted
# 2025-08-19 09:37:47 | Time series for point 7071 extracted
# 2025-08-19 09:37:47 | Time series for point 7073 extracted
# 2025-08-19 09:37:47 | Time series for point 7074 extracted
# 2025-08-19 09:37:47 | Time series for point 7075 extracted
# 2025-08-19 09:37:47 | Time series for point 7076 extracted
# 2025-08-19 09:37:47 | Time series for point 7077 extracted
# 2025-08-19 09:37:47 | Time series for point 7078 extracted
# 2025-08-19 09:37:47 | Time series for point 7081 extracted
# 2025-08-19 09:37:47 | Time series for point 7082 extracted
# 2025-08-19 09:37:47 | Time series for point 7083 extracted
# 2025-08-19 09:37:47 | Time series for point 7084 extracted
# 2025-08-19 09:37:47 | Time series for point 7085 extracted
# 2025-08-19 09:37:47 | Time series for point 7086 extracted
# 2025-08-19 09:37:47 | Time series for point 7088 extracted
# 2025-08-19 09:37:47 | Time series for point 7089 extracted
# 2025-08-19 09:37:47 | Time series for point 7091 extracted
# 2025-08-19 09:37:47 | Time series for point 7097 extracted
# 2025-08-19 09:37:47 | Time series for point 7098 extracted
# 2025-08-19 09:37:47 | Time series for point 7099 extracted
# 2025-08-19 09:37:47 | Time series for point 7100 extracted
# 2025-08-19 09:37:47 | Time series for point 7101 extracted
# 2025-08-19 09:37:47 | Time series for point 7102 extracted
# 2025-08-19 09:37:47 | Time series for point 7103 extracted
# 2025-08-19 09:37:47 | Time series for point 7104 extracted
# 2025-08-19 09:37:47 | Time series for point 7106 extracted
# 2025-08-19 09:37:47 | Time series for point 7107 extracted
# 2025-08-19 09:37:47 | Time series for point 7109 extracted
# 2025-08-19 09:37:47 | Time series for point 7110 extracted
# 2025-08-19 09:37:47 | Time series for point 7111 extracted
# 2025-08-19 09:37:47 | Time series for point 7112 extracted
# 2025-08-19 09:37:47 | Time series for point 7113 extracted
# 2025-08-19 09:37:47 | Time series for point 7114 extracted
# 2025-08-19 09:37:47 | Time series for point 7118 extracted
# 2025-08-19 09:37:47 | Time series for point 7119 extracted
# 2025-08-19 09:37:47 | Time series for point 7120 extracted
# 2025-08-19 09:37:47 | Time series for point 7121 extracted
# 2025-08-19 09:37:47 | Time series for point 7122 extracted
# 2025-08-19 09:37:47 | Time series for point 7124 extracted
# 2025-08-19 09:37:47 | Time series for point 7125 extracted
# 2025-08-19 09:37:47 | Time series for point 7129 extracted
# 2025-08-19 09:37:47 | Time series for point 7131 extracted
# 2025-08-19 09:37:47 | Time series for point 7132 extracted
# 2025-08-19 09:37:47 | Time series for point 7133 extracted
# 2025-08-19 09:37:47 | Time series for point 7134 extracted
# 2025-08-19 09:37:47 | Time series for point 7135 extracted
# 2025-08-19 09:37:47 | Time series for point 7136 extracted
# 2025-08-19 09:37:47 | Time series for point 7137 extracted
# 2025-08-19 09:37:47 | Time series for point 7138 extracted
# 2025-08-19 09:37:47 | Time series for point 7141 extracted
# 2025-08-19 09:37:47 | Time series for point 7144 extracted
# 2025-08-19 09:37:47 | Time series for point 7145 extracted
# 2025-08-19 09:37:47 | Time series for point 7148 extracted
# 2025-08-19 09:37:47 | Time series for point 7149 extracted
# 2025-08-19 09:37:47 | Time series for point 7152 extracted
# 2025-08-19 09:37:47 | Time series for point 7153 extracted
# 2025-08-19 09:37:47 | Time series for point 7157 extracted
# 2025-08-19 09:37:47 | Time series for point 7158 extracted
# 2025-08-19 09:37:47 | Time series for point 7160 extracted
# 2025-08-19 09:37:47 | Time series for point 7161 extracted
# 2025-08-19 09:37:47 | Time series for point 7162 extracted
# 2025-08-19 09:37:47 | Time series for point 7163 extracted
# 2025-08-19 09:37:47 | Time series for point 7164 extracted
# 2025-08-19 09:37:47 | Time series for point 7165 extracted
# 2025-08-19 09:37:47 | Time series for point 7166 extracted
# 2025-08-19 09:37:47 | Time series for point 7168 extracted
# 2025-08-19 09:37:47 | Time series for point 7169 extracted
# 2025-08-19 09:37:47 | Time series for point 7170 extracted
# 2025-08-19 09:37:47 | Time series for point 7172 extracted
# 2025-08-19 09:37:47 | Time series for point 7173 extracted
# 2025-08-19 09:37:47 | Time series for point 7174 extracted
# 2025-08-19 09:37:47 | Time series for point 7175 extracted
# 2025-08-19 09:37:47 | Time series for point 7177 extracted
# 2025-08-19 09:37:47 | Time series for point 7179 extracted
# 2025-08-19 09:37:47 | Time series for point 7181 extracted
# 2025-08-19 09:37:47 | Time series for point 7182 extracted
# 2025-08-19 09:37:47 | Time series for point 7183 extracted
# 2025-08-19 09:37:47 | Time series for point 7184 extracted
# 2025-08-19 09:37:47 | Time series for point 7185 extracted
# 2025-08-19 09:37:47 | Time series for point 7187 extracted
# 2025-08-19 09:37:47 | Time series for point 7191 extracted
# 2025-08-19 09:37:47 | Time series for point 7192 extracted
# 2025-08-19 09:37:47 | Time series for point 7195 extracted
# 2025-08-19 09:37:47 | Time series for point 7196 extracted
# 2025-08-19 09:37:47 | Time series for point 7197 extracted
# 2025-08-19 09:37:47 | Time series for point 7198 extracted
# 2025-08-19 09:37:47 | Time series for point 7200 extracted
# 2025-08-19 09:37:47 | Time series for point 7201 extracted
# 2025-08-19 09:37:47 | Time series for point 7203 extracted
# 2025-08-19 09:37:47 | Time series for point 7204 extracted
# 2025-08-19 09:37:47 | Time series for point 7206 extracted
# 2025-08-19 09:37:47 | Time series for point 7207 extracted
# 2025-08-19 09:37:47 | Time series for point 7209 extracted
# 2025-08-19 09:37:47 | Time series for point 7211 extracted
# 2025-08-19 09:37:47 | Time series for point 7214 extracted
# 2025-08-19 09:37:47 | Time series for point 7215 extracted
# 2025-08-19 09:37:47 | Time series for point 7220 extracted
# 2025-08-19 09:37:47 | Time series for point 7222 extracted
# 2025-08-19 09:37:47 | Time series for point 7227 extracted
# 2025-08-19 09:37:47 | Time series for point 7228 extracted
# 2025-08-19 09:37:47 | Time series for point 7229 extracted
# 2025-08-19 09:37:47 | Time series for point 7242 extracted
# 2025-08-19 09:37:47 | Time series for point 7249 extracted
# 2025-08-19 09:37:47 | Time series for point 7274 extracted
# 2025-08-19 09:37:47 | Time series for point 7311 extracted
# 2025-08-19 09:37:47 | Time series for point 7336 extracted
# 2025-08-19 09:37:47 | Time series for point 7777 extracted
# 2025-08-19 09:37:47 | Time series for point 10557 extracted
# 2025-08-19 09:37:47 | Time series for point 27427 extracted
# 2025-08-19 09:37:47 | Time series for point 27992 extracted
# 2025-08-19 09:37:47 | Time series for point 27996 extracted
# 2025-08-19 09:37:47 | Time series for point 28009 extracted
# 2025-08-19 09:37:47 | Time series for point 28015 extracted
# 2025-08-19 09:37:47 | Time series for point 28076 extracted
# 2025-08-19 09:37:47 | Time series for point 28079 extracted
# 2025-08-19 09:37:47 | Time series for point 28090 extracted
# 2025-08-19 09:37:47 | Time series for point 28125 extracted
# 2025-08-19 09:37:47 | Time series for point 38808 extracted
# 2025-08-19 09:37:48 | Time series for point 99999 extracted

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    dis_100[['GLOFAS4', 'LTR']],
    thr=0,
    vmin=0.1,
    vmax=1e5,
    title='100-year discharge (m3/s)',
    # scale='linear'
)
plt.savefig(PATH_OUT / 'plots' / 'dis_100_pairplot.jpg', dpi=300, bbox_inches='tight');

# %% [markdown]
# #### Select values

# %%
# select values from the GLOFAS4 long-term run
dis_100.GLOFAS5 = dis_100.LTR
dis_100.SOURCE = 'GLOFAS4_ltr'

fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=dis_100.GLOFAS5 / catchment.UPAREA * 3.6 * 24,
    cmap='viridis_r',
    s=5,
)
cbar = plt.colorbar(sct, shrink=.5, label='100-year discharge\n(mm/day)')
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'dis_100_map.jpg', dpi=300, bbox_inches='tight')

# add values to GLOFAS5
glofas5.loc[dis_100.index, 'DIS100_CMS'] = dis_100['GLOFAS5'].round(1).values

print('{0} reservoirs have an 100-year inflow below 10 m3/s'.format((glofas5.DIS100_CMS < 10).sum()))
# Out:
# 7 reservoirs have an 100-year inflow below 10 m3/s

# %% [markdown]
# ### Environment flow

# %%
dis_env = pd.DataFrame(index=glofas5.index, columns=['GLOFAS4', 'LTR', 'GLOFAS5', 'SOURCE'], dtype=float)
dis_env.SOURCE = dis_env.SOURCE.astype(str)

# GLOFAS4
dis_env.loc[glofas4.index, 'GLOFAS4'] = glofas4.minq

# GLOFAS4 long-term run
# dis_env['LTR'] = inflow_ltr.quantile(.05, dim='time', skipna=True).to_pandas()
dis_env['LTR'] = .05 * dis_avg.GLOFAS5 # simplification of the French regulation

# %% [markdown]
# #### Comparison

# %%
compare_attributes(
    dis_env[['GLOFAS4', 'LTR']],
    thr=0,
    vmin=1e-4,
    vmax=1e4,
    title='environmental discharge (m3/s)',
    scale='log'
)
plt.savefig(PATH_OUT / 'plots' / 'dis_env_pairplot.jpg', dpi=300, bbox_inches='tight');

# %% [markdown]
# #### Select values
#
# I will select the values extracted from the D2 map, as it limits extremely low values.

# %%
# select values from the GLOFAS4 naturalised run
dis_env.GLOFAS5 = dis_env.LTR
dis_env.SOURCE = 'GLOFAS4_ltr'

fig, ax = plt.subplots(figsize=(20, 5), subplot_kw=dict(projection=ccrs.PlateCarree()))
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='lightgray'), alpha=.5, zorder=0)
sct = ax.scatter(
    glofas5.geometry.x,
    glofas5.geometry.y,
    c=dis_env.GLOFAS5 / catchment.UPAREA * 3.6 * 24,
    cmap='viridis_r',
    s=5,
    # vmin=0,
    # vmax=2.5
)
cbar = plt.colorbar(sct, shrink=.5, label='environmental discharge\n(mm/day)')
plt.axis('off');
plt.savefig(PATH_OUT / 'plots' / 'dis_env_map.jpg', dpi=300, bbox_inches='tight')

# add values to GLOFAS5
glofas5.loc[dis_env.index, 'DISENV_CMS'] = dis_env['GLOFAS5'].round(4).values

print('{0} reservoirs have an environmental flow below 0.1 m3/s'.format((glofas5.DISENV_CMS < 0.1).sum()))
# Out:
# 65 reservoirs have an environmental flow below 0.1 m3/s

# %% [markdown]
# There are very low values of environmental flow.

# %% [markdown]
# ## Export
# ### Excel file

# %%
# copy glofas5 as main source
reservoirs = glofas5.copy()
reservoirs.sort_index(inplace=True)

# LISFLOOD coordinates
reservoirs['LisfloodX'] = reservoirs.geometry.x
reservoirs['LisfloodY'] = reservoirs.geometry.y

# source of discharge data
reservoirs['DIS_SRC'] = 'GLOFAS4_ltr'

# # add data from GRanD
# grand_ids = reservoirs.GRAND_ID.dropna()
# grand_cols = ['RES_NAME', 'DAM_NAME', 'RIVER', 'MAIN_BASIN', 'COUNTRY', 'YEAR', 'REM_YEAR', 'LONG_DD', 'LAT_DD']
# reservoirs.loc[grand_ids.index, grand_cols] = grand.loc[grand_ids.index, grand_cols].values

# add data from GDW
gdw_cols = ['RES_NAME', 'DAM_NAME', 'RIVER', 'MAIN_BASIN', 'COUNTRY', 'YEAR_DAM', 'REM_YEAR', 'LONG_RIV', 'LAT_RIV']
gdw_ids = gdw.index.intersection(reservoirs.index)
reservoirs.loc[gdw_ids, gdw_cols] = gdw.loc[gdw_ids, gdw_cols]

# add info from GLOFAS4
ids = reservoirs[reservoirs.GRAND_ID.isnull() & reservoirs.RES_ID.notnull()].index
cols_glofas4 = ['COUNTRY', 'DAM_NAME', 'RIVER']
reservoirs.loc[ids, cols_glofas4] = glofas4.loc[ids, cols_glofas4]

# reorder and rename columns
cols = ['RES_ID', 'GDW_ID', 'GRAND_ID', 'GLWD_ID', 'INT_CODE'] + \
    gdw_cols +  \
    ['LisfloodX', 'LisfloodY',
     'CAP_MCM', 'CAP_SRC', 'CATCH_SKM', 'CATCH_SRC', 'AREA_SKM', 'AREA_SRC',
     'DISENV_CMS', 'DISAVG_CMS', 'DIS100_CMS', 'DIS_SRC', 'DOR',
     'geometry']
cols.remove(idx_name)
reservoirs = reservoirs[cols]

# reservoirs that will be modelled as reservoirs
mask_res = (reservoirs.DOR >= MIN_DOR) | reservoirs.AREA_SKM.isnull()
print('{0} reservoirs will be modelled as lakes'.format((~mask_res).sum()))

# save table of reservoirs as Excel
xls_file = PATH_OUT / 'glofas5_reservoirs_{0}.xlsx'.format(datetime.now().strftime('%Y%m%d'))
with pd.ExcelWriter(xls_file, engine='openpyxl') as writer:
    # Reservoirs in GLOFAS5 (as reservoirs)
    reservoirs[mask_res].drop('geometry', axis=1).to_excel(writer, sheet_name='as_reservoirs', float_format='%.4f')
    
    # Reservoirs modeled as lakes in GLOFAS5 (as lakes)
    reservoirs[~mask_res].drop('geometry', axis=1).to_excel(writer, sheet_name='as_lakes', float_format='%.4f')
print(f'Reservoir Excel table saved in : {xls_file}')
# Out:
# 220 reservoirs will be modelled as lakes
# Reservoir Excel table saved in : Z:\nahaUsers\casadje\GloFASv5\reservoirs\tables\glofas5_reservoirs_20250818.xlsx

# %% [markdown]
# ### TXT tables

# %%
# filter reservoirs to be modelled as reservoirs
# res = pd.read_excel(PATH_OUT / 'glofas5_reservoirs.xlsx', sheet_name='as_reservoirs', index_col='FID')
# res.sort_index(inplace=True)
res = reservoirs[mask_res].sort_index()

# table reservoir capacity
(res.CAP_MCM * 1e6).to_csv(
    PATH_OUT / 'reservoirs_glofas5_capacity_{0}.txt'.format(datetime.now().strftime('%Y%m%d')),
    sep='\t',
    header=None,
    float_format='%.0f'
)

# table average discharge
res.DISAVG_CMS.round(1).to_csv(
    PATH_OUT / 'reservoirs_glofas5_avg_inflow_{0}.txt'.format(datetime.now().strftime('%Y%m%d')),
    sep='\t',
    header=None
)

# table 100-year discharge
res.DIS100_CMS.round(1).to_csv(
    PATH_OUT / 'reservoirs_glofas5_100yr_inflow_{0}.txt'.format(datetime.now().strftime('%Y%m%d')),
    sep='\t',
    header=None
)

# table environmental flow
res.DISENV_CMS.round(3).to_csv(
    PATH_OUT / 'reservoirs_glofas5_env_flow_{0}.txt'.format(datetime.now().strftime('%Y%m%d')),
    sep='\t',
    header=None
)

# years of construction and demolition
res[['YEAR_DAM', 'REM_YEAR']].rename(columns={'YEAR_DAM': 'CONSTR_YEAR', 'REM_YEAR': 'DEMOL_YEAR'}).to_csv(
    PATH_OUT / 'reservoirs_glofas5_years_ {0}.csv'.format(datetime.now().strftime('%Y%m%d')),
)

# %% [markdown]
# ### NetCDF map

# %%
# load template
mapa = rxr.open_rasterio(PATH_GLOFAS5 / 'static_maps' / 'template_Global_03min.nc').squeeze().astype('int')
mapa.name = 'reservoirs'
mapa.close()

# remove all values
mapa[:,:] = 0

# %%
# assign IDs of lakes in GloFAS5
for ID, row in tqdm(res.iterrows(), total=len(res)):
    pixel = mapa.sel({'x': row.LisfloodX, 'y': row.LisfloodY}, method='nearest')
    mapa.loc[{'x': pixel.x.item(), 'y': pixel.y.item()}] = ID

# modify attributes
mapa.attrs['contributors'] = 'Juliana Disperati <juliana.disperati@ext.ec.europa.eu>'
mapa.attrs['creator'] = 'Jesús Casado Rodríguez <jesus.casado-rodriguez@ec.europa.eu>'
mapa.attrs['creator_name'] = 'casadje'
mapa.attrs['history'] = ('Created {0}'.format(datetime.now().strftime("%a %b %e %H:%M:%S %Y")))
mapa.attrs['history_of_appended_files'] = ''
mapa.attrs['institution'] = 'Joint Research Centre - European Commission'
mapa.attrs['references'] = 'https://www.globaldamwatch.org/grand'
mapa.attrs['long_name'] = 'reservoirs static map'
mapa.attrs['standard_name'] = 'reservoirs'

# define coordinate reference system
mapa = mapa.rio.write_crs('EPSG:4326')
# Out:
#   0%|          | 0/1490 [00:00<?, ?it/s]

# %%
# export NetCDF map
filename = PATH_OUT / 'reservoirs_glofas5_03min_{0}.nc'.format(datetime.now().strftime('%Y%m%d'))
# mapa.rio.to_raster(filename)
mapa.drop_vars(['spatial_ref', 'band']).rename({'x': 'lon', 'y': 'lat'}).to_netcdf(filename)

# %%
# export as point shapefile
res.to_file(PATH_OUT / 'reservoirs_glofas5_{0}.shp'.format(datetime.now().strftime('%Y%m%d')))
