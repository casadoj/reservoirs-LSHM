# %% [markdown]
# # Bivariate calibration
# ***
#
# **Autor:** Chus Casado<br>
# **Date:** 11-06-2024<br>
#
# **To do:**<br>
# * [ ] Clean observed time series
#
# **Questions:**<br>
# * [x] What's the relation between likelihood and KGE? Answer:
# $$Likelihood = 1 - KGE$$
# * [ ] Fit the $Q_{min}$ based on the inflow data. Hot to fit a GEV to minima.
# * [ ] Analyse the optimized parameters. Try to find a pattern related to reservoir use, size, catchment area...
#
# **Ideas:**<br>
# * SpotPy can not apply any optimization algorithm to a bivariable calibration. Instead, it includes different sampling methods (not optimization) such as Latin Hypercube and Monte Carlo. These two methods are good to explore the parameter space, but will not provide the global optimal parameters. In this notebook I compute the Pareto front of the outflow and storage KGE, and select as the optimal parameter set the one that is closer to the (1, 1) point. That means that I give equal importance to outflow and storage, and that the best parameter set is a Euclidean distance from the optimum value of (1, 1). If that approach is good, I could use an optimazation algorithm like SCE-UA to find the global optimum, provided that the target metric is the composition of the KGE values for storage and outflow:
# $$OF = \sqrt{{(1 - KGE_{outflow})^2 + (1 - KGE_{storage} )^2}}$$

# %%
import sys
sys.path.append('../../src/')

# %%
import os
os.environ['USE_PYGEOS'] = '0'
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import spotpy
from spotpy.objectivefunctions import kge
import yaml
from pathlib import Path
from tqdm.notebook import tqdm
import glob
# import cartopy.crs as ccrs
# import cartopy.feature as cf

# %%
from lisfloodreservoirs.calibration.bivariate_lisflood import bivariate_6pars
from lisfloodreservoirs.reservoirs.lisflood import Lisflood
from lisfloodreservoirs.utils.metrics import KGEmod, pareto_front
from lisfloodreservoirs.utils.plots import plot_iterations

# %% [markdown]
# ## Configuration

# %%
PATH_DATASETS = Path('Z:/nahaUsers/casadje/datasets/')

# results will be saved in this path
PATH_OUT = Path('../calibration/MC/6parameters/') #Path('../results/reservoirs/LISFLOOD/calibration/MC/6parameters/')
PATH_OUT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Calibration

# %%
# sequential mode
parallel = 'seq'

# SCEUA parameters
max_iter = 600
# complexes = 4
train_size = .7

# %% [markdown]
# ## Data

# %% [markdown]
# ### GloFAS

# %% [markdown]
# #### Reservoirs

# %%
# load shapefile of GloFAS reservoirs
reservoirs = gpd.read_file('../../GIS/reservoirs_analysis_US.shp')
reservoirs.set_index('ResID', drop=True, inplace=True)

print(f'{reservoirs.shape[0]} reservoirs in the shape file')
# Out:
# 94 reservoirs in the shape file

# %% [markdown]
# #### Time series

# %%
# read GloFAS time series
path = Path('../../data/reservoirs/GloFAS/long_run')
glofas_ts = {}
for file in tqdm(glob.glob(f'{path}/*.csv')):
    id = int(file.split('\\')[-1].split('.')[0].lstrip('0'))
    if id not in reservoirs.index:
        continue
    glofas_ts[id] = pd.read_csv(file, parse_dates=True, dayfirst=False, index_col='date')
    
print(f'{len(glofas_ts)} reservoirs in the GloFAS time series')

# convert storage time series into volume
for id, df in glofas_ts.items():
    df.storage *= reservoirs.loc[id, 'CAP'] * 1e6

# period of GloFAS simulation
start, end = glofas_ts[id].first_valid_index(), glofas_ts[id].last_valid_index()
# Out:
#   0%|          | 0/143 [00:00<?, ?it/s]
# 94 reservoirs in the GloFAS time series

# %% [markdown]
# ### ResOpsUS
# #### Time series

# %%
path_ResOps = Path(PATH_DATASETS / 'reservoirs' / 'ResOpsUS')

resops_ts = {}
for glofas_id in tqdm(reservoirs.index):
    # load timeseries
    grand_id = reservoirs.loc[glofas_id, 'GRAND_ID']
    series_id = pd.read_csv(path_ResOps / 'time_series_all' / f'ResOpsUS_{grand_id}.csv', parse_dates=True, index_col='date')
    # remove empty time series
    series_id = series_id.loc[start:end]#.dropna(axis=1, how='all')
    # remove duplicated index
    series_id = series_id[~series_id.index.duplicated(keep='first')]
    # save in dictionary
    resops_ts[glofas_id] = series_id

print(f'{len(resops_ts)} reservoirs in the ResOpsUS time series')
    
# convert storage from hm3 to m3
for id, df in resops_ts.items():
    df.storage *= 1e6
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]
# 94 reservoirs in the ResOpsUS time series

# %% [markdown]
# ## Markov chain sampling

# %%
# GloFAS reservoir
for ResID in tqdm(reservoirs.index):
    
    # file where the calibration results will be saved
    dbname = f'{PATH_OUT}/{ResID:03}_samples'
    if os.path.isfile(dbname + '.csv'):
        print(f'The file {dbname}.csv already exists.')
        continue
            
    ## TIME SERIES
    try:
        # observed time series
        obs = resops_ts[ResID][['storage', 'inflow', 'outflow']].copy()
        obs[obs < 0] = np.nan

        # define calibration period
        if obs.outflow.isnull().all():
            print(f'Reservoir {ResID} is missing outflow records')
            # continue
        elif obs.storage.isnull().all():
            print(f'Reservoir {ResID} is missing storage records')
            # continue
        else:
            start_obs = max([obs[var].first_valid_index() for var in ['storage', 'outflow']])
            end_obs = min([obs[var].last_valid_index() for var in ['storage', 'outflow']])
            cal_days = timedelta(days=np.floor((end_obs - start_obs).days * train_size))
            start_cal = end_obs - cal_days

        # define train and test time series
        x_train = glofas_ts[ResID].inflow[start_cal:end_obs]
        y_train = obs.loc[start_cal:end_obs, ['storage', 'outflow']]
        x_test = glofas_ts[ResID].inflow[start:start_cal]
        y_test = obs.loc[start_obs:start_cal, ['storage', 'outflow']]
        
    except:
        print(f'ERROR. The time series of reservoir {ResID} could not be set up')
        continue
        
    ## SET UP SPOTPY
    try:
        # extract GloFAS reservoir parameters
        Vc, Vtot, Qmin = reservoirs.loc[ResID, ['clim', 'CAP', 'minq']]
        Vtot *= 1e6
        Vc *= Vtot

        # initialize the calibration setup of the LISFLOOD reservoir routine
        setup = bivariate_6pars(x_train, y_train.storage, y_train.outflow,
                                Vc, Vtot, Qmin,
                                KGEmod)

        # define the sampling method
        mc = spotpy.algorithms.mc(setup, parallel=parallel, dbname=dbname, dbformat='csv', save_sim=False)
    except:
        print(f'ERROR. The SpotPY set up of reservoir {ResID} could not be done')

    ## LAUNCH SAMPLING
    try:
        # start the sampler
        mc.sample(max_iter)
    except:
        print(f'ERROR. While sampling the reservoir {ResID}')
        continue
        
    ### ANALYSE RESULTS
    
    try:
        # read CSV of results
        results = pd.read_csv(f'{dbname}.csv')
        results.index.name = 'iteration'
        parcols = [col for col in results.columns if col.startswith('par')]
        
        # plot pairplot of the combined likelihood
        results['likelihood'] = results[['like1', 'like2']].pow(2).sum(axis=1).pow(.5)
        sns.pairplot(results, vars=parcols, corner=True, hue='likelihood', palette='Spectral_r', plot_kws={'s': 12})
        plt.savefig(PATH_OUT / f'{ResID:03}_pairplot.jpg', dpi=300, bbox_inches='tight');
        
    except:
        print(f'ERROR while reading results form reservoir {ResID}')
        continue
        
    try:
        # compute the Pareto front and the best iteration
        front = pareto_front(results.like1, results.like2)
        best_iter = front.pow(2).sum(axis=1).pow(.5).idxmin()
        plot_iterations(results, front, best_iter, save=PATH_OUT / f'{ResID:03}_pareto_front.jpg')

        # select optimal parameters
        best_iter = results.like1.idxmin()
        parvalues = {col[3:]: float(results.loc[best_iter, col]) for col in parcols}

        # export optimal parameters
        with open(f'{PATH_OUT}/{ResID:03}_optimal_parameters.yml', 'w') as file:
            yaml.dump(parvalues, file)
    except:
        print(f'ERROR while searching for optimal parameters in reservoir {ResID}')
        continue
        
    try:
        # # declare the reservoir with the optimal parameters
        # Vn, Vf = [parvalues[var] * Vtot for var in ['FFn', 'FFf']]
        # Vn_adj = Vn + parvalues['alpha'] * (Vf - Vn)
        # Qn, Qf = [setup.inflow.quantile(parvalues[var]) for var in ['QQn', 'QQf']]
        # k = parvalues['k']
        # res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)
        
        # declare the reservoir with the optimal parameters
        Vf = parvalues['FFf'] * Vtot
        Vn = parvalues['alpha'] * Vf
        Vn_adj = Vn + parvalues['beta'] * (Vf - Vn)
        Qf = setup.inflow.quantile(parvalues['QQf'])
        Qn = parvalues['gamma'] * Qf
        k = parvalues['k']
        res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)

        # define time series
        start_obs = max([resops_ts[ResID][var].first_valid_index() for var in ['storage', 'outflow']])
        x = glofas_ts[ResID][start_obs:]
        y = resops_ts[ResID][start_obs:]

        # simulate the whole period and analyse
        sim = res.simulate(x.inflow, y.storage[start_obs], k=k)
        res.scatter(sim, y, norm=False, title=ResID, save=PATH_OUT / f'{ResID:03}_scatter.jpg')
        res.lineplot({'GloFAS': x, 'cal': sim}, y, save=PATH_OUT / f'{ResID:03}_lineplot.jpg')

    except:
        print(f'ERROR while simulating with optimal parameters in reservoir {ResID}')
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/007_samples.csv' created.
# 4 of 600, min objf=0.735107, max objf=0.81074, time remaining: 00:05:06
# 8 of 600, min objf=0.732252, max objf=0.845545, time remaining: 00:05:39
# 12 of 600, min objf=0.732252, max objf=1.01033, time remaining: 00:05:47
# 16 of 600, min objf=0.732252, max objf=1.01418, time remaining: 00:05:55
# 19 of 600, min objf=0.731455, max objf=1.01418, time remaining: 00:05:59
# 23 of 600, min objf=0.731455, max objf=1.01418, time remaining: 00:05:58
# 27 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:57
# 31 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:56
# 34 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:57
# 38 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:56
# 42 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:54
# 46 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:52
# 49 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:51
# 52 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:50
# 55 of 600, min objf=0.731455, max objf=1.05295, time remaining: 00:05:50
# 59 of 600, min objf=0.723474, max objf=1.05295, time remaining: 00:05:48
# 63 of 600, min objf=0.723474, max objf=1.05295, time remaining: 00:05:46
# 66 of 600, min objf=0.723474, max objf=1.05295, time remaining: 00:05:45
# 70 of 600, min objf=0.723474, max objf=1.05295, time remaining: 00:05:43
# 74 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:39
# 77 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:38
# 81 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:36
# 84 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:35
# 87 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:34
# 91 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:32
# 94 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:31
# 98 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:29
# 101 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:27
# 105 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:24
# 108 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:23
# 111 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:21
# 114 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:20
# 117 of 600, min objf=0.723474, max objf=1.09707, time remaining: 00:05:18
# 121 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:16
# 124 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:14
# 127 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:14
# 130 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:12
# 133 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:11
# 136 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:10
# 139 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:09
# 142 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:07
# 146 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:05
# 149 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:03
# 152 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:05:01
# 156 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:04:59
# 159 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:04:57
# 162 of 600, min objf=0.699538, max objf=1.09707, time remaining: 00:04:55
# 165 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:54
# 169 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:51
# 173 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:48
# 176 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:46
# 180 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:43
# 183 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:41
# 187 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:38
# 190 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:36
# 193 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:35
# 197 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:32
# 200 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:30
# 203 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:28
# 206 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:26
# 209 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:24
# 213 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:21
# 217 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:18
# 220 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:16
# 224 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:13
# 227 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:12
# 230 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:10
# 234 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:07
# 238 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:04
# 241 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:02
# 244 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:04:00
# 248 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:57
# 252 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:54
# 255 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:53
# 258 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:51
# 261 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:49
# 264 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:47
# 267 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:45
# 270 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:44
# 273 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:42
# 276 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:40
# 279 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:38
# 282 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:36
# 285 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:34
# 288 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:33
# 291 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:31
# 294 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:29
# 297 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:27
# 300 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:25
# 303 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:23
# 306 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:21
# 309 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:19
# 312 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:17
# 315 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:15
# 318 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:13
# 321 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:11
# 324 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:09
# 327 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:07
# 330 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:06
# 334 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:03
# 337 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:03:01
# 340 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:02:59
# 344 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:02:56
# 347 of 600, min objf=0.699538, max objf=1.13377, time remaining: 00:02:54
# 350 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:52
# 353 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:50
# 356 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:48
# 359 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:46
# 362 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:43
# 366 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:41
# 370 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:38
# 373 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:36
# 377 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:33
# 381 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:30
# 384 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:28
# 388 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:25
# 391 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:23
# 394 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:21
# 397 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:19
# 400 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:17
# 403 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:15
# 406 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:13
# 410 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:10
# 413 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:08
# 416 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:06
# 419 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:04
# 422 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:02
# 425 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:02:00
# 428 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:58
# 431 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:56
# 434 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:54
# 438 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:51
# 441 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:49
# 444 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:47
# 447 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:45
# 450 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:43
# 454 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:40
# 457 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:38
# 460 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:36
# 464 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:33
# 467 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:31
# 470 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:29
# 473 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:27
# 477 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:24
# 480 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:22
# 483 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:20
# 486 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:18
# 489 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:16
# 492 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:14
# 495 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:12
# 499 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:09
# 502 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:07
# 505 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:05
# 508 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:03
# 512 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:01:00
# 516 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:57
# 520 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:54
# 523 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:52
# 526 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:50
# 530 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:48
# 534 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:45
# 537 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:43
# 540 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:41
# 543 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:39
# 547 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:36
# 550 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:34
# 553 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:32
# 557 of 600, min objf=0.676599, max objf=1.13377, time remaining: 00:00:29
# 561 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:26
# 564 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:24
# 567 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:22
# 570 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:20
# 573 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:18
# 576 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:16
# 579 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:14
# 582 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:12
# 586 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:09
# 590 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:06
# 594 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:03
# 597 of 600, min objf=0.668867, max objf=1.13377, time remaining: 00:00:01
# 600 of 600, min objf=0.668867, max objf=1.13377, time remaining: 23:59:59
#
# *** Final SPOTPY summary ***
# Total Duration: 413.68 seconds
# Total Repetitions: 600
# Minimal objective value: 0.668867
# Corresponding parameter setting:
# FFf: 0.34207
# alpha: 0.626466
# beta: 0.755227
# QQf: 0.976037
# gamma: 0.965852
# k: 1.28978
# Maximal objective value: 1.13377
# Corresponding parameter setting:
# FFf: 0.982143
# alpha: 0.343345
# beta: 0.57947
# QQf: 0.820438
# gamma: 0.893692
# k: 1.87372
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/012_samples.csv' created.
# 3 of 600, min objf=0.317582, max objf=0.341508, time remaining: 00:05:01
# 7 of 600, min objf=0.316874, max objf=0.349223, time remaining: 00:05:40
# 10 of 600, min objf=0.316874, max objf=0.349223, time remaining: 00:06:08
# 13 of 600, min objf=0.316874, max objf=0.431854, time remaining: 00:06:12
# 16 of 600, min objf=0.313477, max objf=0.431854, time remaining: 00:06:18
# 20 of 600, min objf=0.313477, max objf=0.457931, time remaining: 00:06:14
# 24 of 600, min objf=0.313477, max objf=0.457931, time remaining: 00:06:10
# 27 of 600, min objf=0.313477, max objf=0.457931, time remaining: 00:06:11
# 30 of 600, min objf=0.313477, max objf=0.457931, time remaining: 00:06:13
# 33 of 600, min objf=0.313477, max objf=0.465418, time remaining: 00:06:13
# 36 of 600, min objf=0.313477, max objf=0.465418, time remaining: 00:06:12
# 39 of 600, min objf=0.313477, max objf=0.465418, time remaining: 00:06:12
# 42 of 600, min objf=0.313477, max objf=0.465418, time remaining: 00:06:12
# 45 of 600, min objf=0.311919, max objf=0.465418, time remaining: 00:06:12
# 48 of 600, min objf=0.311919, max objf=0.465418, time remaining: 00:06:12
# 52 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:07
# 56 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:05
# 59 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:05
# 62 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:05
# 65 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:04
# 68 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:03
# 71 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:02
# 74 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:01
# 77 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:06:00
# 80 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:59
# 83 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:57
# 86 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:55
# 90 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:52
# 93 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:50
# 96 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:47
# 100 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:44
# 103 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:42
# 106 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:40
# 109 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:38
# 112 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:36
# 115 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:33
# 119 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:29
# 122 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:27
# 125 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:26
# 129 of 600, min objf=0.311919, max objf=0.493168, time remaining: 00:05:23
# 132 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:21
# 135 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:18
# 139 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:15
# 142 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:13
# 145 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:11
# 149 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:08
# 152 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:06
# 155 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:04
# 158 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:05:02
# 162 of 600, min objf=0.311191, max objf=0.493168, time remaining: 00:04:59
# 166 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:56
# 169 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:54
# 173 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:51
# 176 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:49
# 179 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:47
# 183 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:44
# 186 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:42
# 190 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:39
# 193 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:37
# 196 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:35
# 199 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:33
# 202 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:31
# 205 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:29
# 209 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:26
# 212 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:24
# 215 of 600, min objf=0.311026, max objf=0.493168, time remaining: 00:04:22
# 218 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:21
# 221 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:19
# 224 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:17
# 227 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:15
# 230 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:13
# 233 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:11
# 236 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:09
# 239 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:07
# 242 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:05
# 245 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:04
# 248 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:02
# 251 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:04:00
# 254 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:58
# 257 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:56
# 261 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:53
# 264 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:51
# 268 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:48
# 271 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:46
# 274 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:44
# 277 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:42
# 280 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:40
# 284 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:37
# 287 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:35
# 290 of 600, min objf=0.311026, max objf=0.505333, time remaining: 00:03:33
# 294 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:30
# 298 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:27
# 301 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:25
# 304 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:23
# 307 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:21
# 310 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:19
# 313 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:17
# 316 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:15
# 320 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:12
# 324 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:09
# 328 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:07
# 331 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:04
# 334 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:03:02
# 338 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:59
# 341 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:57
# 344 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:55
# 348 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:52
# 352 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:50
# 355 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:48
# 359 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:45
# 362 of 600, min objf=0.311026, max objf=0.539513, time remaining: 00:02:43
# 366 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:40
# 370 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:37
# 373 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:35
# 377 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:32
# 380 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:30
# 383 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:28
# 386 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:26
# 389 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:24
# 392 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:22
# 395 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:20
# 399 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:17
# 402 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:15
# 405 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:13
# 408 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:11
# 411 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:09
# 414 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:07
# 417 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:05
# 420 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:03
# 424 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:02:00
# 427 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:58
# 430 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:56
# 433 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:54
# 436 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:52
# 439 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:50
# 442 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:48
# 445 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:46
# 448 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:44
# 451 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:42
# 454 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:40
# 457 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:38
# 460 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:36
# 463 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:34
# 466 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:32
# 469 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:30
# 472 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:28
# 475 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:26
# 478 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:24
# 481 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:22
# 484 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:20
# 487 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:18
# 490 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:16
# 493 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:14
# 496 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:12
# 499 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:10
# 502 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:08
# 505 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:06
# 508 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:03
# 511 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:01:01
# 514 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:59
# 517 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:57
# 520 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:55
# 523 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:53
# 526 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:51
# 529 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:49
# 532 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:47
# 535 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:45
# 538 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:43
# 541 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:41
# 544 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:39
# 547 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:36
# 550 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:34
# 553 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:32
# 556 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:30
# 559 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:28
# 562 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:26
# 565 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:24
# 568 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:22
# 571 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:20
# 574 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:18
# 577 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:16
# 580 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:13
# 583 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:11
# 586 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:09
# 589 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:07
# 592 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:05
# 595 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:03
# 598 of 600, min objf=0.311026, max objf=0.703301, time remaining: 00:00:01
#
# *** Final SPOTPY summary ***
# Total Duration: 424.97 seconds
# Total Repetitions: 600
# Minimal objective value: 0.311026
# Corresponding parameter setting:
# FFf: 0.355174
# alpha: 0.152734
# beta: 0.349172
# QQf: 0.105784
# gamma: 0.327788
# k: 2.45785
# Maximal objective value: 0.703301
# Corresponding parameter setting:
# FFf: 0.299209
# alpha: 0.408417
# beta: 0.49394
# QQf: 0.988478
# gamma: 0.9584
# k: 3.84627
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/014_samples.csv' created.
# 3 of 600, min objf=0.545051, max objf=0.822728, time remaining: 00:05:40
# 6 of 600, min objf=0.545051, max objf=0.83011, time remaining: 00:06:33
# 9 of 600, min objf=0.525123, max objf=0.83011, time remaining: 00:06:41
# 12 of 600, min objf=0.519527, max objf=0.852748, time remaining: 00:06:48
# 15 of 600, min objf=0.519527, max objf=0.852748, time remaining: 00:06:57
# 18 of 600, min objf=0.519527, max objf=0.852748, time remaining: 00:06:57
# 21 of 600, min objf=0.519527, max objf=0.947644, time remaining: 00:06:57
# 24 of 600, min objf=0.519527, max objf=0.947644, time remaining: 00:06:58
# 27 of 600, min objf=0.519527, max objf=0.947644, time remaining: 00:06:57
# 30 of 600, min objf=0.519527, max objf=0.947644, time remaining: 00:06:55
# 33 of 600, min objf=0.519527, max objf=0.947644, time remaining: 00:06:56
# 36 of 600, min objf=0.519527, max objf=0.947644, time remaining: 00:06:57
# 39 of 600, min objf=0.519527, max objf=0.994384, time remaining: 00:06:56
# 42 of 600, min objf=0.519527, max objf=0.994384, time remaining: 00:06:53
# 45 of 600, min objf=0.519527, max objf=0.994384, time remaining: 00:06:50
# 48 of 600, min objf=0.515862, max objf=0.994384, time remaining: 00:06:48
# 51 of 600, min objf=0.515862, max objf=0.994384, time remaining: 00:06:45
# 54 of 600, min objf=0.515862, max objf=0.994384, time remaining: 00:06:44
# 57 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:42
# 60 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:41
# 63 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:39
# 66 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:37
# 69 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:35
# 72 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:33
# 75 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:30
# 78 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:28
# 81 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:26
# 84 of 600, min objf=0.515862, max objf=1.08645, time remaining: 00:06:25
# ERROR. While sampling the reservoir 14
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/016_samples.csv' created.
# 3 of 600, min objf=0.716417, max objf=1.04286, time remaining: 00:05:43
# ERROR. While sampling the reservoir 16
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/017_samples.csv' created.
# 4 of 600, min objf=0.960047, max objf=4.40663, time remaining: 00:04:18
# 8 of 600, min objf=0.571837, max objf=4.54187, time remaining: 00:04:55
# 2001-11-14 00:00:00
# 13 of 600, min objf=0.571837, max objf=4.79236, time remaining: 00:04:43
# 2013-07-31 00:00:00
# 2012-10-06 00:00:00
# 17 of 600, min objf=0.571837, max objf=4.79236, time remaining: 00:04:46
# 2003-11-04 00:00:00
# 22 of 600, min objf=0.571837, max objf=4.79236, time remaining: 00:04:40
# 1998-09-11 00:00:00
# ERROR. While sampling the reservoir 17
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/018_samples.csv' created.
# 9 of 600, min objf=0.570647, max objf=1.28715, time remaining: 00:02:06
# 18 of 600, min objf=0.502675, max objf=1.65462, time remaining: 00:02:09
# 27 of 600, min objf=0.502675, max objf=1.65462, time remaining: 00:02:08
# 36 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:10
# 44 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:13
# 52 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:12
# 60 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:11
# 69 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:08
# 78 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:06
# 87 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:04
# 96 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:02
# 104 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:02:00
# 113 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:01:58
# 122 of 600, min objf=0.502675, max objf=1.72798, time remaining: 00:01:55
# 131 of 600, min objf=0.464514, max objf=1.72798, time remaining: 00:01:53
# 140 of 600, min objf=0.464514, max objf=1.72798, time remaining: 00:01:51
# 149 of 600, min objf=0.464514, max objf=1.72798, time remaining: 00:01:49
# 157 of 600, min objf=0.464514, max objf=1.73147, time remaining: 00:01:47
# 166 of 600, min objf=0.464514, max objf=1.73147, time remaining: 00:01:45
# 174 of 600, min objf=0.464514, max objf=1.73147, time remaining: 00:01:43
# 183 of 600, min objf=0.464514, max objf=1.73147, time remaining: 00:01:41
# 192 of 600, min objf=0.464514, max objf=1.73147, time remaining: 00:01:39
# 201 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:37
# 210 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:34
# 219 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:32
# 228 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:30
# 237 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:28
# 246 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:26
# 254 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:24
# 263 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:22
# 272 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:19
# 281 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:17
# 290 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:15
# 298 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:13
# 307 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:11
# 316 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:09
# 325 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:06
# 334 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:04
# 343 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:02
# 352 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:01:00
# 361 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:58
# 370 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:55
# 379 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:53
# 389 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:51
# 399 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:48
# 408 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:46
# 417 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:44
# 427 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:41
# 437 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:39
# 447 of 600, min objf=0.437106, max objf=1.73147, time remaining: 00:00:36
# 457 of 600, min objf=0.437106, max objf=1.75219, time remaining: 00:00:34
# 467 of 600, min objf=0.437106, max objf=1.75219, time remaining: 00:00:31
# 476 of 600, min objf=0.437106, max objf=1.75219, time remaining: 00:00:29
# 485 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:27
# 495 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:25
# 506 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:22
# 516 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:20
# 526 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:17
# 536 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:15
# 546 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:12
# 555 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:10
# 564 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:08
# 574 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:06
# 584 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:03
# 594 of 600, min objf=0.410002, max objf=1.75219, time remaining: 00:00:01
#
# *** Final SPOTPY summary ***
# Total Duration: 139.75 seconds
# Total Repetitions: 600
# Minimal objective value: 0.410002
# Corresponding parameter setting:
# FFf: 0.800016
# alpha: 0.683945
# beta: 0.082213
# QQf: 0.966295
# gamma: 0.230871
# k: 3.54821
# Maximal objective value: 1.75219
# Corresponding parameter setting:
# FFf: 0.209109
# alpha: 0.265382
# beta: 0.639357
# QQf: 0.915407
# gamma: 0.927241
# k: 1.95959
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/031_samples.csv' created.
# 3 of 600, min objf=0.662695, max objf=0.772684, time remaining: 00:05:28
# 6 of 600, min objf=0.611348, max objf=0.799433, time remaining: 00:06:15
# 9 of 600, min objf=0.590243, max objf=0.799433, time remaining: 00:06:29
# 12 of 600, min objf=0.590243, max objf=0.799433, time remaining: 00:06:31
# 16 of 600, min objf=0.590243, max objf=0.799433, time remaining: 00:06:32
# 19 of 600, min objf=0.590243, max objf=0.799433, time remaining: 00:06:30
# 22 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:32
# 25 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:33
# 29 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:28
# 32 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:26
# 35 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:26
# 38 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:25
# 41 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:22
# 44 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:21
# 47 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:20
# 50 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:22
# 53 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:21
# 56 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:19
# 60 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:14
# 64 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:11
# 67 of 600, min objf=0.58612, max objf=0.799433, time remaining: 00:06:09
# 70 of 600, min objf=0.584304, max objf=0.799433, time remaining: 00:06:07
# 74 of 600, min objf=0.584304, max objf=0.799433, time remaining: 00:06:04
# 77 of 600, min objf=0.584304, max objf=0.799433, time remaining: 00:06:04
# 80 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:06:04
# 83 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:06:03
# 87 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:59
# 90 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:57
# 94 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:53
# 98 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:50
# 102 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:46
# 105 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:43
# 108 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:42
# 111 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:40
# 115 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:37
# 118 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:35
# 121 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:34
# 124 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:32
# 127 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:29
# 131 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:26
# 134 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:24
# 138 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:20
# 142 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:17
# 146 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:14
# 149 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:11
# 153 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:08
# 156 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:06
# 159 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:04
# 163 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:05:01
# 166 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:04:59
# 169 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:04:57
# 172 of 600, min objf=0.582237, max objf=0.799433, time remaining: 00:04:55
# 176 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:52
# 179 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:50
# 182 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:48
# 185 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:46
# 188 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:44
# 192 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:41
# 196 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:37
# 200 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:35
# 203 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:33
# 206 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:30
# 209 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:28
# 212 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:26
# 215 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:24
# 218 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:22
# 221 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:20
# 224 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:18
# 227 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:16
# 230 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:14
# 233 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:12
# 236 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:10
# 239 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:08
# 242 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:06
# 245 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:04
# 249 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:04:01
# 252 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:59
# 255 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:57
# 258 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:56
# 261 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:53
# 264 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:51
# 267 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:49
# 271 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:46
# 274 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:44
# 278 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:41
# 281 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:39
# 284 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:37
# 287 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:35
# 290 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:33
# 293 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:31
# 296 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:29
# 299 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:27
# 303 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:24
# 307 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:21
# 311 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:19
# 314 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:16
# 318 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:14
# 322 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:11
# 325 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:09
# 328 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:07
# 331 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:05
# 334 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:03
# 337 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:03:01
# 341 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:02:58
# 345 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:02:55
# 349 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:02:52
# 353 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:02:49
# 356 of 600, min objf=0.578744, max objf=0.827219, time remaining: 00:02:47
# 360 of 600, min objf=0.571577, max objf=0.827219, time remaining: 00:02:44
# 363 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:42
# 366 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:40
# 369 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:38
# 372 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:36
# 376 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:33
# 379 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:31
# 382 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:29
# 386 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:26
# 389 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:24
# 393 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:21
# 396 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:19
# 399 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:17
# 403 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:14
# 407 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:11
# 411 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:09
# 415 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:06
# 418 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:04
# 421 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:02
# 424 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:02:00
# 428 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:57
# 431 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:55
# 434 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:53
# 437 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:51
# 441 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:48
# 445 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:45
# 448 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:43
# 451 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:41
# 454 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:39
# 457 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:37
# 461 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:34
# 465 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:32
# 468 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:30
# 471 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:28
# 474 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:26
# 477 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:24
# 480 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:22
# 483 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:20
# 486 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:18
# 489 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:16
# 492 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:14
# 495 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:12
# 498 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:10
# 501 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:08
# 504 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:06
# 507 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:04
# 510 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:02
# 513 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:01:00
# 516 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:58
# 519 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:56
# 522 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:54
# 525 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:52
# 528 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:50
# 531 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:48
# 534 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:45
# 537 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:43
# 540 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:41
# 543 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:39
# 546 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:37
# 549 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:35
# 552 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:33
# 555 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:31
# 558 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:29
# 562 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:26
# 565 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:24
# 568 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:22
# 571 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:20
# 574 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:18
# 577 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:15
# 581 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:13
# 585 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:10
# 588 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:08
# 591 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:06
# 594 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:04
# 597 of 600, min objf=0.571577, max objf=1.34147, time remaining: 00:00:01
#
# *** Final SPOTPY summary ***
# Total Duration: 421.66 seconds
# Total Repetitions: 600
# Minimal objective value: 0.571577
# Corresponding parameter setting:
# FFf: 0.672184
# alpha: 0.0125872
# beta: 0.425506
# QQf: 0.936702
# gamma: 0.0433132
# k: 4.51359
# Maximal objective value: 1.34147
# Corresponding parameter setting:
# FFf: 0.209568
# alpha: 0.362989
# beta: 0.250534
# QQf: 0.986144
# gamma: 0.969995
# k: 4.45947
# ******************************
#
# Initializing the  Monte Carlo (MC) sampler  with  600  repetitions
# Starting the MC algorithm with 600 repetitions...
# Initialize database...
# ['csv', 'hdf5', 'ram', 'sql', 'custom', 'noData']
# * Database file '..\calibration\MC\6parameters/032_samples.csv' created.
# 3 of 600, min objf=25.914, max objf=26.8522, time remaining: 00:05:29
# 6 of 600, min objf=25.914, max objf=27.0416, time remaining: 00:06:11
# 9 of 600, min objf=25.8354, max objf=27.9354, time remaining: 00:06:33
# 12 of 600, min objf=25.8354, max objf=27.9354, time remaining: 00:06:33
# 15 of 600, min objf=25.8354, max objf=27.9354, time remaining: 00:06:37
# 18 of 600, min objf=25.8354, max objf=27.9354, time remaining: 00:06:36
# 21 of 600, min objf=25.8354, max objf=27.9354, time remaining: 00:06:39
# 25 of 600, min objf=25.8354, max objf=27.9354, time remaining: 00:06:33
# 29 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:26
# 32 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:24
# 36 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:20
# 40 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:15
# 43 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:15
# 46 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:13
# 50 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:08
# 53 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:06
# 56 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:06
# 59 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:06:04
# 63 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:59
# 67 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:56
# 70 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:54
# 74 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:51
# 77 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:50
# 80 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:50
# 83 of 600, min objf=25.78, max objf=27.9517, time remaining: 00:05:48

# %% [markdown]
# ## Analyse results

# %%
for ResID in [12]:#tqdm(reservoirs.index):
    
    try:

# %%
ResID = 481 #507

# %%
        # file where the calibration results will be saved
        dbname = f'{PATH_OUT}/{ResID:03}_samples'

        # read CSV of results
        results = pd.read_csv(f'{dbname}.csv')
        results.index.name = 'iteration'
        parcols = [col for col in results.columns if col.startswith('par')]

        # compute the Pareto front and the best iteration
        front = pareto_front(results.like1, results.like2)
        best_iter = front.pow(2).sum(axis=1).pow(.5).idxmin()

# %%
        # select and export optimal parameters
        parvalues = {col[3:]: float(results.loc[best_iter, col]) for col in parcols}
        with open(f'{PATH_OUT}/{ResID:03}_optimal_parameters.yml', 'w') as file:
            yaml.dump(parvalues, file)

# %%
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.scatter(results.like1, results.like2, s=1, c='gray', label='iteration', alpha=.2)
    ax.scatter(*front.loc[best_iter, ['like1', 'like2']], c='steelblue', label='optimum', s=4)
    ax.plot(front.like1, front.like2, c='k', lw=1, ls=':', label='pareto front', zorder=0)
    # vmax = np.ceil(front[['like1', 'like2']].max().max() / .2) * .2 + .025
    vmax = None
    # # ticks = np.arange(0, vmax, .25)
    ax.set(xlim=(-.025, vmax),
           xlabel=r'$L_{outflow}$',
           # xticks=ticks,
           ylim=(-.025, vmax),
           ylabel=r'$L_{storage}$',
           # yticks=ax.get_xticks(),
          )
    ax.set_title(ResID)
    fig.legend(frameon=False, loc=1, bbox_to_anchor=[1.175, .7, .1, .2]);
    plt.savefig(PATH_OUT / f'{ResID:03}_pareto_front.jpg', dpi=300, bbox_inches='tight');

# %%
# observed time series
obs = resops_ts[ResID][['storage', 'inflow', 'outflow']].copy()
obs[obs < 0] = np.nan
        
# define train and test time series
start_obs = max([obs[var].first_valid_index() for var in ['storage', 'outflow']])
end_obs = min([obs[var].last_valid_index() for var in ['storage', 'outflow']])
cal_days = timedelta(days=np.floor((end_obs - start_obs).days * train_size))
start_cal = end_obs - cal_days

# define train and test time series
x_train = glofas_ts[ResID].inflow[start_cal:end_obs]
y_train = obs.loc[start_cal:end_obs, ['storage', 'outflow']]
x_test = glofas_ts[ResID].inflow[start:start_cal]
y_test = obs.loc[start:start_cal, ['storage', 'outflow']]

# %%
# extract GloFAS reservoir parameters
Vc, Vtot, Qmin = reservoirs.loc[ResID, ['clim', 'CAP', 'minq']]
Vtot *= 1e6
Vc *= Vtot

# initialize the calibration setup of the LISFLOOD reservoir routine
setup = bivariate_6pars(x_train, y_train.storage, y_train.outflow,
                        Vc, Vtot, Qmin,
                        KGEmod)

# %%
results[['KGE1', 'KGE2']] = np.nan
# idx = results[results.like2.isnull()].index[1]
for idx in tqdm(results.index):
    
    parvalues = {col[3:]: float(results.loc[idx, col]) for col in parcols}

    # declare the reservoir with the optimal parameters
    Vn, Vf = [parvalues[var] * Vtot for var in ['FFn', 'FFf']]
    Vn_adj = Vn + parvalues['alpha'] * (Vf - Vn)
    Qn, Qf = [setup.inflow.quantile(parvalues[var]) for var in ['QQn', 'QQf']]
    k = parvalues['k']
    res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)

    # simulate the whole period and analyse
    sim = res.simulate(x_train, y_train.storage[start_cal], k=k)

    results.loc[idx, 'KGE1'] = 1 - KGEmod(y_train.outflow, sim.outflow)[0]
    results.loc[idx, 'KGE2'] = 1 - KGEmod(y_train.storage, sim.storage)[0]

# %%
results[['KGE1', 'KGE2']].describe()

# %%
fig, ax = plt.subplots(figsize=(4, 4))
ax.scatter(results.KGE1, results.KGE2, s=1, c='gray', label='iteration', alpha=.2)
# vmax = np.ceil(front[['like1', 'like2']].max().max() / .2) * .2 + .025
# vmax = None
# ticks = np.arange(0, vmax, .25)
ax.set(xlim=(-.025, None),
       xlabel=r'$KGE_{outflow}$',
       # xticks=ticks,
       ylim=(-.025, None),
       ylabel=r'$KGE_{storage}$',
       # yticks=ax.get_xticks(),
      )
ax.set_title(ResID)
fig.legend(frameon=False, loc=1, bbox_to_anchor=[1.175, .7, .1, .2]);

# %%
fig, axes = plt.subplots(ncols=2, figsize=(8, 4))

for i, (ax, var) in enumerate(zip(axes, ['outflow', 'storage']), start=1):
    ax.scatter(results[f'KGE{i}'], results[f'like{i}'], s=1, c='gray', label='iteration', alpha=.2)
    ax.set(title=var,
           xlabel='KGE',
           # xlim=(None, 1.02),
           # ylim=(-.02, None),
          )
    if ax == axes[0]:
        ax.set_ylabel('likelihood')
    
# axes[0].axhline(1, ls=':', c='k', lw=.5)
# axes[0].axvline(0, ls=':', c='k', lw=.5);

# %%
# compute the Pareto front and the best iteration
front = pareto_front(1 - results.KGE1, 1 - results.KGE2)
front['d'] = (1 - front[['KGE1', 'KGE2']]).pow(2).sum(axis=1).pow(.5)
best_iter = front.d.idxmin()

# %%
front

# %%
fig, ax = plt.subplots(figsize=(4, 4))
ax.scatter(1 - results.KGE1, 1 - results.KGE2, s=1, c='gray', label='iteration', alpha=.2)
ax.scatter(*front.loc[best_iter, ['KGE1', 'KGE2']], c='steelblue', label='optimum', s=4)
ax.scatter(*front.loc[best_iter, ['KGE1', 'KGE2']], c='steelblue', label='optimum', s=4)
# ax.plot(front.KGE1, front.KGE2, c='k', lw=1, ls=':', label='pareto front', zorder=0)
# vmax = np.ceil(front[['KGE1', 'KGE2']].max().max() / .2) * .2 + .025
# vmax = None
# # ticks = np.arange(0, vmax, .25)
ax.set(xlim=(-.025, None),
       xlabel=r'$L_{outflow}$',
       # xticks=ticks,
       ylim=(-.025, None),
       ylabel=r'$L_{storage}$',
       # yticks=ax.get_xticks(),
      )
ax.set_title(ResID)
fig.legend(frameon=False, loc=1, bbox_to_anchor=[1.175, .7, .1, .2]);
plt.savefig(PATH_OUT / f'{ResID:03}_pareto_front.jpg', dpi=300, bbox_inches='tight');

# %%
results.loc[results.like2.isnull(), parcols].iloc[0]

# %%
        # select and export optimal parameters
        parvalues = {col[3:]: float(results.loc[best_iter, col]) for col in parcols}
        with open(f'{PATH_OUT}/{ResID:03}_optimal_parameters.yml', 'w') as file:
            yaml.dump(parvalues, file)

        # declare the reservoir with the optimal parameters
        Vn, Vf = [parvalues[var] * Vtot for var in ['FFn', 'FFf']]
        Vn_adj = Vn + parvalues['alpha'] * (Vf - Vn)
        Qn, Qf = [setup.inflow.quantile(parvalues[var]) for var in ['QQn', 'QQf']]
        k = parvalues['k']
        res = Lisflood(Vc, Vn, Vn_adj, Vf, Vtot, Qmin, Qn, Qf)

        # define time series
        start_obs = max([resops_ts[ResID][var].first_valid_index() for var in ['storage', 'outflow']])
        x = glofas_ts[ResID][start_obs:]
        y = resops_ts[ResID][start_obs:]

        # simulate the whole period and analyse
        sim = res.simulate(x.inflow, y.storage[start_obs], k=k)
        res.scatter(sim, y, norm=False, title=ResID, save=PATH_OUT / f'{ResID:03}_scatter.jpg')
        res.lineplot({'GloFAS': x, 'cal': sim}, y, save=PATH_OUT / f'{ResID:03}_lineplot.jpg')

    except:
        print(f'ERROR. {ResID}')
        continue

# %% [markdown]
# ***

# %%
    # extract GloFAS reservoir parameters
    Vc, Vtot, Qmin = reservoirs.loc[ResID, ['clim', 'CAP', 'minq']]
    Vtot *= 1e6
    Vc *= Vtot

    # initialize the calibration setup of the LISFLOOD reservoir routine
    setup = bivariate_6pars(x, y.storage, y.outflow,
                            Vc, Vtot, Qmin,
                            KGEmod)

# %%
    simulations = {}
    front[['KGE1', 'KGE2']] = np.nan
    for i in tqdm(front.index):
        Q, S = setup.simulation(results.loc[i, parcols])
        simulations[i] = {'outflow': Q, 'storage': S}
        front.loc[i, 'KGE1'] = KGEmod(y.outflow, Q)[0]
        front.loc[i, 'KGE2'] = KGEmod(y.storage, S)[0]

# %%
    # plot simulations in the pareto front
    fig, axes = plt.subplots(nrows=2, figsize=(12, 6), sharex=True)
    for i, (ax, var, unit) in enumerate(zip(axes, ['outflow', 'storage'], ['m3/s', 'm3']), start=1):
        ax.plot(y[var], c='k', lw=.5, label='obs', zorder=2)
        ax.plot(simulations[best_iter][var], c='steelblue', lw=1, label='best iteration', zorder=3)
        for s, dct in simulations.items():
            ax.plot(dct[var], c='gray', lw=.5, alpha=.2, label='pareto front')
        ax.set(title='{0} KGE={1:.2f}'.format(var, front.loc[best_iter, f'KGE{i}']),
               ylabel=unit)
    ax.set(xlim=(start_cal, end))
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles[:3], labels[:3], frameon=False, loc=8, ncol=3);
